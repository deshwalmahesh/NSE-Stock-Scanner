# %%
# ! pip install jugaad_data, nsetools
from jugaad_data.nse import stock_df
from nsetools import Nse

from datetime import date, datetime, timedelta
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
import mplfinance as fplt
import plotly.graph_objects as go

from multiprocessing import Pool

import requests
from bs4 import BeautifulSoup
import random

from os import listdir
from os.path import isfile, join

import json

import warnings

# %%
mypath = './data'
all_stocks = {}
_ = [all_stocks.update({f.split('_')[0]:f.split('_')[1].split('.')[0]}) for f in listdir(mypath) if isfile(join(mypath, f))]

# %%
drop = ['SERIES','PREV. CLOSE','VWAP','52W H','52W L','VOLUME','VALUE','NO OF TRADES']
current_date = date.today()
stocks = list(all_stocks.keys())
random.shuffle(stocks)

def get_stocks(name):
    try:
        df = stock_df(symbol=name, from_date = current_date - timedelta(days = 365), to_date = current_date, series="EQ").drop(drop,axis=1)
        df.to_csv(f'./data/{name}_{all_stocks[name]}_{str(current_date)}.csv',index=None)
    except Exception as e:
        pass


pool = Pool(41)
results = pool.map(get_stocks,stocks)
pool.close()
pool.join()

# %% [markdown]
# # Plotly

# %%
with open('./names/all_stocks.json') as f:
    x = json.load(f)
x
# Out:
# {'GENCON': 'Generic Engineering Construction and Projects Limited_2021-07-17.csv',
#  'RENUKA': 'Shree Renuka Sugars Ltd._2021-07-17.csv',
#  'TRF': 'TRF Ltd_2021-07-17.csv',
#  'ICICITECH': 'ICICI Prudential Mutual Fund_2021-07-17.csv',
#  'BEDMUTHA': 'Bedmutha Industries Limited_2021-07-17.csv',
#  'ICRA': 'ICRA Limited_2021-07-17.csv',
#  'RVHL': 'Ravinder Heights Limited_2021-07-17.csv',
#  'MUKANDENGG': 'Mukand Engineers Limited_2021-07-17.csv',
#  'GHCL': 'GHCL Ltd._2021-07-17.csv',
#  'GMMPFAUDLR': 'GMMPFAUDLR_2021-07-17.csv',
#  'GLOBOFFS': 'Global Offshore Services Ltd_2021-07-17.csv',
#  'KALYANKJIL': 'Kalyan Jewellers India Limited_2021-07-17.csv',
#  'KOTAKPSUBK': 'Kotak Mahindra Mutual Fund - Permitted_2021-07-17.csv',
#  'BHAGWATIHO': 'Bhagwati Banquets and Hotels Limited_2021-07-17.csv',
#  'KENNAMET': 'Kennametal India Limtied_2021-07-17.csv',
#  'LEMONTREE': 'Lemon Tree Hotels Limited_2021-07-17.csv',
#  'CUB': 'City Union Bank Ltd_2021-07-17.csv',
#  'NOIDATOLL': 'Noida Toll Bridge Company Ltd_2021-07-17.csv',
#  'BAJAJ-AUTO': 'Bajaj Auto Limited_2021-07-17.csv',
#  'PRETAILDVR': 'Pantaloon Retail (India) Limited_2021-07-17.csv',
#  'GILLANDERS': 'Gillanders Arbuthnot & Co. Ltd._2021-07-17.csv',
#  'ICICISENSX': 'ICICI Prudential Mutual Fund_2021-07-17.csv',
#  'STEELCITY': 'STEELCITY_2021-07-17.csv',
#  'PPAP': 'PPAP Automotive Limited_2021-07-17.csv',
#  'BASF': 'BASF India Ltd_2021-07-17.csv',
#  'DYNAMATECH': 'Dynamatic Technologies Ltd.,_2021-07-17.csv',
#  'AMARAJABAT': 'Amara Raja Batteries Ltd_2021-07-17.csv',
#  'IBREALEST': 'Indiabulls Real Estate Limited_2021-07-17.csv',
#  'JASH': 'JASH_2021-07-17.csv',
#  'NTL': 'Neueon Towers Limited_2021-07-17.csv',
#  'UTIAMC': 'UTI Asset Management Company Limited_2021-07-17.csv',
#  'RIIL': 'Reliance Industrial Infrastructure_2021-07-17.csv',
#  'BIRLAMONEY': 'Aditya Birla  Money Ltd_2021-07-17.csv',
#  'MMFL': 'M.M.Forgings Ltd._2021-07-17.csv',
#  'GODFRYPHLP': 'Godfrey Phillips India Ltd.,_2021-07-17.csv',
#  'TPLPLASTEH': 'TPLPLASTEH_2021-07-17.csv',
#  'TVSMOTOR': 'TVS Motor Company Ltd._2021-07-17.csv',
#  'AVADHSUGAR': 'AVADH SUGAR & ENERGY LIMITED_2021-07-17.csv',
#  'SHIL': 'Somany Home Innovation Limited_2021-07-17.csv',
#  'SHRIRAMEPC': 'Shriram EPC Limited_2021-07-17.csv',
#  'NAHARCAP': 'Nahar Capital & Financial Services Ltd._2021-07-17.csv',
#  'MLL': 'Mercator Lines Limited_2021-07-17.csv',
#  'GAIL': 'Gail (India) Ltd._2021-07-17.csv',
#  'VISASTEEL': 'Visa Steel Limited_2021-07-17.csv',
#  'MIRZAINT': 'Mirza International  Limited_2021-07-17.csv',
#  'KEYCORPSER': 'Keynote Corporate Services Limited_2021-07-17.csv',
#  'IDBIGOLD': 'IDBIGOLD_2021-07-17.csv',
#  'SEINV': 'S.E. Investments Limited_2021-07-17.csv',
#  'WHIRLPOOL': 'Whirlpool of India Ltd_2021-07-17.csv',
#  'CTE': 'Cambridge Technology Enterprises Ltd._2021-07-17.csv',
#  'PNBHOUSING': 'PNB Housing Finance Limited_2021-07-17.csv',
#  'GOLDBEES': 'GOLDBEES_2021-07-17.csv',
#  'BRIGADE': 'Brigade Enterprises Limited_2021-07-17.csv',
#  'JBMA': 'JBM Auto Limited_2021-07-17.csv',
#  'KSK': 'KSK Energy Ventures Limited_2021-07-17.csv',
#  'IIFL': 'IIFL FINANCE LIMITED _2021-07-17.csv',
#  'CADILAHC': 'Cadila Healthcare Ltd._2021-07-17.csv',
#  'VMART': 'V-Mart Retail Limited_2021-07-17.csv',
#  'DEN': 'DEN Networks Limited_2021-07-17.csv',
#  'SMLISUZU': 'SML ISUZU LIMITED_2021-07-17.csv',
#  'INDRAMEDCO': 'Indraprastha Medical Corporation Lt_2021-07-17.csv',
#  'WHEELS': 'WHEELS INDIA LTD_2021-07-17.csv',
#  'KSCL': 'Kaveri Seed Company Ltd_2021-07-17.csv',
#  'ZODJRDMKJ': 'Zodiac-JRD-MKJ Ltd._2021-07-17.csv',
#  'UNIENTER': 'UNIENTER_2021-07-17.csv',
#  'SCANDENT': 'Scandent Imaging Limited_2021-07-17.csv',
#  'MANGCHEFER': 'Mangalore Chemicals & Fertilisers L_2021-07-17.csv',
#  'SUBROS': 'Subros Ltd.,_2021-07-17.csv',
#  'HINDUNILVR': 'Hindustan Unilever Ltd.,_2021-07-17.csv',
#  'PBAINFRA': 'PBA INFRASTRUCTURE LTD._2021-07-17.csv',
#  'ROHITFERRO': 'Rohit Ferro-Tech Limited_2021-07-17.csv',
#  'OPTIEMUS': 'Optiemus Infracom Limited_2021-07-17.csv',
#  'SHREYAS': 'Shreyas Shipping And Logistics Limited_2021-07-17.csv',
#  'TATACOMM': 'Tata Communications Limited_2021-07-17.csv',
#  'ROSSELLIND': 'Rossell India Limited_2021-07-17.csv',
#  'HGS': 'Hinduja Global Solutions Limited_2021-07-17.csv',
#  'JMA': 'JMA_2021-07-17.csv',
#  'VIPULLTD': 'Vipul Limited_2021-07-17.csv',
#  'AXISBNKETF': 'AXISBNKETF_2021-07-17.csv',
#  'VISHAL': 'Vishal Fabrics Limited_2021-07-17.csv',
#  'BLBLIMITED': 'BLB Limited_2021-07-17.csv',
#  'ATUL': 'Atul Limited.,_2021-07-17.csv',
#  'MSTCLTD': 'MSTCLTD_2021-07-17.csv',
#  'TATASTLBSL': 'TATA STEEL BSL LIMITED_2021-07-17.csv',
#  'SANDESH': 'Sandesh Ltd._2021-07-17.csv',
#  'KOTAKGOLD': 'KOTAKGOLD_2021-07-17.csv',
#  'DHANI': 'Dhani Services Limited_2021-07-17.csv',
#  'ARSHIYA': 'Arshiya Limited_2021-07-17.csv',
#  'SHANKARA': 'Shankara Building Products Limited_2021-07-17.csv',
#  'ASIANTILES': 'ASIAN GRANITO INDIA LIMITED_2021-07-17.csv',
#  'LIBAS': 'LIBAS_2021-07-17.csv',
#  'MGEL': 'MGEL_2021-07-17.csv',
#  'VAIBHAVGBL': 'Vaibhav Global Ltd_2021-07-17.csv',
#  'LUMAXIND': 'Lumax Industries Ltd.,_2021-07-17.csv',
#  'CAPLIPOINT': 'CAPLIPOINT_2021-07-17.csv',
#  'ADANIGREEN': 'Adani Green Energy Limited_2021-07-17.csv',
#  'SHYAMTEL': 'Shyam Telecom Limited_2021-07-17.csv',
#  'KAMATHOTEL': 'Kamat Hotels (India) ltd._2021-07-17.csv',
#  'CARBORUNIV': 'Carborundum Universal Ltd.,_2021-07-17.csv',
#  'BHAGYANGR': 'BHAGYANGR_2021-07-17.csv',
#  'BALAJITELE': 'Balaji Telefilms Ltd._2021-07-17.csv',
#  'EVEREADY': 'Eveready Industries India Ltd._2021-07-17.csv',
#  'SAGCEM': 'Sagar Cements Ltd_2021-07-17.csv',
#  'PDUMJEPULP': 'Pudumjee Pulp & Paper Mills Limited_2021-07-17.csv',
#  'APOLLO': 'Apollo Micro Systems Limited_2021-07-17.csv',
#  'PNBGILTS': 'PNB Gilts Ltd_2021-07-17.csv',
#  'AHLEAST': 'Asian Hotels (East) Limited_2021-07-17.csv',
#  'ENIL': 'Entertainment Network (India) Ltd_2021-07-17.csv',
#  'RESPONIND': 'Responsive Industries Ltd_2021-07-17.csv',
#  'QGOLDHALF': 'QGOLDHALF_2021-07-17.csv',
#  'KHADIM': 'Khadim India Limited_2021-07-17.csv',
#  'NITINSPIN': 'Nitin Spinners Ltd._2021-07-17.csv',
#  'ENGINERSIN': 'Engineers India Ltd._2021-07-17.csv',
#  'LGBBROSLTD': 'L.g.Balkrishnan & Bros. Ltd._2021-07-17.csv',
#  'KINGFA': 'Kingfa Science & Technology (India) Ltd_2021-07-17.csv',
#  'PANTALOONR': 'Pantaloon Retail (India) Limited_2021-07-17.csv',
#  'AKSHOPTFBR': 'Aksh Optifibre Ltd._2021-07-17.csv',
#  'AMBER': 'Amber Enterprises India Limited_2021-07-17.csv',
#  'BEL': 'Bharat Electronics Ltd.,_2021-07-17.csv',
#  'VTL': 'Vardhman Textiles Limted_2021-07-17.csv',
#  'NEOGEN': 'Neogen Chemicals Limited_2021-07-17.csv',
#  'OISL': 'OCL Iron and Steel Limited_2021-07-17.csv',
#  'KAJARIACER': 'Kajaria Ceramics Ltd_2021-07-17.csv',
#  'SARDAEN': 'Sarda Energy & Minerals Ltd_2021-07-17.csv',
#  'HIMATSEIDE': 'Himatsingka Seide Ltd.,_2021-07-17.csv',
#  'SHARDACROP': 'Sharda Cropchem Limited_2021-07-17.csv',
#  'COMPUSOFT': 'Compucom Software Lt._2021-07-17.csv',
#  'S&SPOWER': 'S & S Power Switchgears Ltd.,_2021-07-17.csv',
#  'LASA': 'Lasa Supergenerics Limited_2021-07-17.csv',
#  'BANCOINDIA': 'Banco Products (India) Ltd.,_2021-07-17.csv',
#  'SJVN': 'SJVN LIMITED_2021-07-17.csv',
#  'HUDCO': 'Housing &Urban Development Corporation Ltd._2021-07-17.csv',
#  'KIRIINDUS': 'KIRI INDUSTRIES LIMITED_2021-07-17.csv',
#  'MMFSL': 'Money Matters Financial Services Limited_2021-07-17.csv',
#  'LUMAXTECH': 'Lumax Auto Technologies Ltd._2021-07-17.csv',
#  'BIL': 'Bhartiya International Ltd._2021-07-17.csv',
#  'BANKBARODA': 'Bank Of Baroda_2021-07-17.csv',
#  'JAYAGROGN': 'Jayant Agro-Organics Limited._2021-07-17.csv',
#  'MMTC': 'MMTC Ltd.,_2021-07-17.csv',
#  'KOTARISUG': 'KOTARISUG_2021-07-17.csv',
#  'ARVINDFASN': 'Arvind Fashions Limited_2021-07-17.csv',
#  'FEL': 'Future Enterprises Limited_2021-07-17.csv',
#  'HCL-INSYS': 'HCL Infosystems Ltd_2021-07-17.csv',
#  'GMRINFRA': 'GMR Infrastructure Limited_2021-07-17.csv',
#  'IVZINGOLD': 'IVZINGOLD_2021-07-17.csv',
#  'BALMLAWRIE': 'Balmer Lawrie & Co. Ltd.,_2021-07-17.csv',
#  'SCHAEFFLER': 'Schaeffler India Limited_2021-07-17.csv',
#  'PREMIERPOL': 'Premier Polyfilm Ltd._2021-07-17.csv',
#  'NAHARSPING': 'Nahar Spinning Mills Ltd.,_2021-07-17.csv',
#  'KARMAENG': 'Karma Energy Limited_2021-07-17.csv',
#  'RMCL': 'Radha Madhav Corporation Ltd._2021-07-17.csv',
#  'UNIVCABLES': 'Universal Cables Ltd.,_2021-07-17.csv',
#  'NAHARPOLY': 'Nahar Polyfilms Ltd._2021-07-17.csv',
#  'ANDHRACEMT': 'Andhra Cement Ltd.,_2021-07-17.csv',
#  'SOUTHBANK': 'South Indian Bank Ltd._2021-07-17.csv',
#  'HMVL': 'Hindustan Media Ventures Limited_2021-07-17.csv',
#  'BANKBEES': 'Reliance Mutual Fund-Permitted_2021-07-17.csv',
#  'AXISHCETF': 'AXISHCETF_2021-07-17.csv',
#  'DOLAT': 'Dolat Investments Ltd.,_2021-07-17.csv',
#  'SMARTLINK': 'Smartlink Holdings Limited_2021-07-17.csv',
#  'MAZDOCK': 'Mazagon Dock Shipbuilders Limited_2021-07-17.csv',
#  'LUXIND': 'LUX Industries Limited_2021-07-17.csv',
#  'KIMS': 'Krishna Institute of Medical Sciences Limited_2021-07-17.csv',
#  'PRISMCEM': 'Prism Cement Limited_2021-07-17.csv',
#  'ASHIANA': 'Ashiana Housing Limited_2021-07-17.csv',
#  'KOKUYOCMLN': 'Kokuyo Camlin Ltd_2021-07-17.csv',
#  'ARCHIES': 'Archies Ltd._2021-07-17.csv',
#  'WILLAMAGOR': 'William Magor & Company Limited_2021-07-17.csv',
#  'GET&D': 'GE T&D India Limited_2021-07-17.csv',
#  'TECHNOE': 'Techno Electric & Engineering Company Limited_2021-07-17.csv',
#  'SATIN': 'SATIN CREDITCARE NETWORK LIMITED_2021-07-17.csv',
#  'ESABINDIA': 'Esab India Ltd._2021-07-17.csv',
#  'JUBLINGREA': 'Jubilant Ingrevia Limited_2021-07-17.csv',
#  'RITES': 'RITES Limited_2021-07-17.csv',
#  'VISAKAIND': 'Visaka Industries Ltd.,_2021-07-17.csv',
#  'MAITHANALL': 'Maithan Alloys Limited_2021-07-17.csv',
#  'SHIVATEX': 'SHIVATEX_2021-07-17.csv',
#  'ICICIB22': 'ICICI Prudential Mutual Fund_2021-07-17.csv',
#  'MHRIL': 'Mahindra Holidays & Resorts India Limited_2021-07-17.csv',
#  'ELECTHERM': 'Electrotherm (India) Ltd_2021-07-17.csv',
#  'UNICHEMLAB': 'Unichem Laboratories Ltd.,_2021-07-17.csv',
#  'XPROINDIA': 'Xpro India Ltd._2021-07-17.csv',
#  'SKIPPER': 'Skipper Limited_2021-07-17.csv',
#  'ADANIPORTS': 'Adani Ports and Special Economic Zone Ltd_2021-07-17.csv',
#  'INDIANB': 'Indian Bank_2021-07-17.csv',
#  'COCHINSHIP': 'Cochin Shipyard Limited_2021-07-17.csv',
#  'CERA': 'Cera Sanitaryware Ltd._2021-07-17.csv',
#  'WOCKPHARMA': 'Wockhardt Ltd_2021-07-17.csv',
#  'SPENCERS': 'SPENCERS_2021-07-17.csv',
#  'SWSOLAR': 'Sterling and Wilson Solar Limited_2021-07-17.csv',
#  'ARMANFIN': 'Arman Financial Services Limited_2021-07-17.csv',
#  'TARMAT': 'Tarmat Limited_2021-07-17.csv',
#  'MOHOTAIND': 'Mohota Industries Limited_2021-07-17.csv',
#  'BERGEPAINT': 'Berger Paints India Ltd_2021-07-17.csv',
#  'SVPGLOB': 'SVP Global Ventures Limited_2021-07-17.csv',
#  'DWARKESH': 'Dwarikesh Sugar Industries Ltd._2021-07-17.csv',
#  'SANGHIIND': 'Sanghi Industries Ltd._2021-07-17.csv',
#  'MANXT50': 'MANXT50_2021-07-17.csv',
#  'HITECHCORP': 'Hitech Corporation Limited_2021-07-17.csv',
#  'PRECWIRE': 'Precision Wires India ltd.,_2021-07-17.csv',
#  'TIMETECHNO': 'Time Technoplast Limited_2021-07-17.csv',
#  'JHS': 'JHS Svendgaard Laboratories Ltd._2021-07-17.csv',
#  'RUSHIL': 'Rushil Decor Limited_2021-07-17.csv',
#  'ICICINXT50': 'ICICI Prudential Mutual Fund_2021-07-17.csv',
#  'BDL': 'Bharat Dynamics Limited_2021-07-17.csv',
#  'IFBIND': 'IFB Industries Limited_2021-07-17.csv',
#  'EMMBI': 'Emmbi Industries Limited_2021-07-17.csv',
#  'CELEBRITY': 'Celebrity Fashions Ltd._2021-07-17.csv',
#  'REDINGTON': 'Redington (India) ltd._2021-07-17.csv',
#  'NETFMID150': 'NETFMID150_2021-07-17.csv',
#  'ALLCARGO': 'Allcargo Logistics Ltd_2021-07-17.csv',
#  'VEDL': 'Vedanta Limited_2021-07-17.csv',
#  'MANAKALUCO': 'Manaksia Aluminium Company Limited_2021-07-17.csv',
#  'ASHAPURMIN': 'Ashapura Minechem Ltd_2021-07-17.csv',
#  'APOLLOPIPE': 'APOLLOPIPE_2021-07-17.csv',
#  'JUSTDIAL': 'Just Dial Limited_2021-07-17.csv',
#  'GKWLIMITED': 'GKWLIMITED_2021-07-17.csv',
#  'DCMNVL': 'DCM NOUVELLE LIMITED_2021-07-17.csv',
#  'AAVAS': 'AAVAS Financiers Limited_2021-07-17.csv',
#  'THEINVEST': 'THE INVESTMENT TRUST OF INDIA LIMITED_2021-07-17.csv',
#  'NESCO': 'Nesco Ltd_2021-07-17.csv',
#  'ASTEC': 'ASTEC LIFESCIENCES LIMITED_2021-07-17.csv',
#  'DALBHARAT': 'DALMIA BHARAT LIMITED_2021-07-17.csv',
#  'ASHOKA': 'Ashoka Buildcon Limited_2021-07-17.csv',
#  'ELECON': 'Elecon Engineering Co.Ltd.,_2021-07-17.csv',
#  'SOMICONVEY': 'SOMICONVEY_2021-07-17.csv',
#  'MADRASCEM': 'Madras Cements Limited_2021-07-17.csv',
#  'BLUECOAST': 'Blue Coast Hotels Ltd_2021-07-17.csv',
#  'VINDHYATEL': 'Vindhya Telelinks Ltd.,_2021-07-17.csv',
#  'GNFC': 'Gujarat Narmada Valley Fert.Co.Ltd_2021-07-17.csv',
#  'SILINV': 'SIL Investments Ltd_2021-07-17.csv',
#  'PNB': 'Punjab National Bank_2021-07-17.csv',
#  'PAEL': 'PAE LTd._2021-07-17.csv',
#  'NKIND': 'N.K.Industries Ltd._2021-07-17.csv',
#  'JTEKTINDIA': 'JTEKT India Limited_2021-07-17.csv',
#  'ASTRAL': 'ASTRAL LIMITED_2021-07-17.csv',
#  'TIL': 'TIL Ltd.,_2021-07-17.csv',
#  'AARON': 'Aaron Industries Limited_2021-07-17.csv',
#  'DIGISPICE': 'DIGISPICE TECHNOLOGIES LIMITED_2021-07-17.csv',
#  'SOUTHWEST': 'SOUTHWEST_2021-07-17.csv',
#  'PVR': 'PVR Ltd._2021-07-17.csv',
#  'BECTORFOOD': 'Mrs. Bectors Food Specialities Limited_2021-07-17.csv',
#  'BOROLTD': 'Borosil Limited_2021-07-17.csv',
#  'BALRAMCHIN': 'Balrampur Chini Mills Ltd._2021-07-17.csv',
#  'CHEMBOND': 'Chembond Chemicals Ltd._2021-07-17.csv',
#  'NSIL': 'Nalwa Sons Investment Ltd_2021-07-17.csv',
#  'UJJIVAN': 'Ujjivan Financial Services Limited_2021-07-17.csv',
#  'HITECHGEAR': 'The Hi-Tech Gears Limited_2021-07-17.csv',
#  'OMMETALS': 'OM Metals Infraprojects Limited_2021-07-17.csv',
#  'PRESSMN': 'Pressman Advertising Limited_2021-07-17.csv',
#  'SGL': 'STL Global Ltd_2021-07-17.csv',
#  'KEI': 'KEI Industries Ltd._2021-07-17.csv',
#  'YAARII': 'Yaarii Digital Integrated Services Limited_2021-07-17.csv',
#  'BIOFILCHEM': 'Biofil Chemicals & Pharmaceuticals_2021-07-17.csv',
#  'IBMFNIFTY': 'IBMFNIFTY_2021-07-17.csv',
#  'HAVELLS': 'Havells India Limited_2021-07-17.csv',
#  'ONEPOINT': 'One Point One Solutions Limited_2021-07-17.csv',
#  'ICICIBANK': 'ICICI Bank Ltd._2021-07-17.csv',
#  'RPSGVENT': 'RPSG VENTURES LIMITED_2021-07-17.csv',
#  'GANGAFORGE': 'GANGAFORGE_2021-07-17.csv',
#  'GEOJITFSL': 'Geojit Financial Services Limited_2021-07-17.csv',
#  'ACC': 'ACC Ltd_2021-07-17.csv',
#  'RPPINFRA': 'RPP INFRA PROJECTS LIMITED_2021-07-17.csv',
#  'MARINE': 'MARINE_2021-07-17.csv',
#  'APCOTEXIND': 'Apcotex Industries Limited_2021-07-17.csv',
#  'KSERAPRO': 'K Sera Sera Productions Limited_2021-07-17.csv',
#  'IVZINNIFTY': 'IVZINNIFTY_2021-07-17.csv',
#  'HDFCBANK': 'HDFC Bank Ltd._2021-07-17.csv',
#  'ORIENTABRA': 'Orient Abrasives Ltd._2021-07-17.csv',
#  'SANGHVIMOV': 'Sanghvi Movers Ltd._2021-07-17.csv',
#  'TATACOFFEE': 'Tata Coffee Ltd_2021-07-17.csv',
#  '20MICRONS': '20 Microns Limited_2021-07-17.csv',
#  'RATNAMANI': 'Ratnamani Metals & Tubes Ltd_2021-07-17.csv',
#  'GREENPLY': 'Greenply Industries Ltd_2021-07-17.csv',
#  'EIHAHOTELS': 'EIH Associated Hotels Ltd.,_2021-07-17.csv',
#  'DONEAR': 'Donear Industries Ltd_2021-07-17.csv',
#  'UBL': 'United Breweries Ltd._2021-07-17.csv',
#  'RUBYMILLS': 'Ruby Mills Ltd.,_2021-07-17.csv',
#  'PSB': 'PUNJAB & SIND BANK_2021-07-17.csv',
#  'RICOAUTO': 'RICO Auto Industries Ltd._2021-07-17.csv',
#  'NETFIT': 'NETFIT_2021-07-17.csv',
#  'ARIHANT': 'Arihant Foundations & Housing Ltd._2021-07-17.csv',
#  'AKASH': 'AKASH_2021-07-17.csv',
#  'INCREDIBLE': 'INCREDIBLE INDUSTRIES LIMITED_2021-07-17.csv',
#  'ARIHANTSUP': 'Arihant Superstructures Limited_2021-07-17.csv',
#  'ASIANPAINT': 'Asian Paints Ltd._2021-07-17.csv',
#  'TEJASNET': 'Tejas Networks Limited_2021-07-17.csv',
#  'RAILTEL': 'RailTel Corporation of India Limited_2021-07-17.csv',
#  'MRPL': 'Mangalore Refinery & Petrochemicals_2021-07-17.csv',
#  'LOKESHMACH': 'Lokesh Machines Limited_2021-07-17.csv',
#  'TAKE': 'Take Solutions Ltd_2021-07-17.csv',
#  'TORNTPOWER': 'TORRENT POWER LIMITED_2021-07-17.csv',
#  'SHARIABEES': 'Reliance Mutual Fund-Permitted_2021-07-17.csv',
#  'SAKHTISUG': 'Sakthi Sugars Ltd._2021-07-17.csv',
#  'KECL': 'KIRLOSKAR ELECTRIC COMPANY LTD._2021-07-17.csv',
#  'ACE': 'Action Construction Equipments Ltd._2021-07-17.csv',
#  'SHIVAMILLS': 'Shiva Mills Limited_2021-07-17.csv',
#  'FCONSUMER': 'Future Consumer Limited_2021-07-17.csv',
#  'FCL': 'Fineotex Chemical Limited_2021-07-17.csv',
#  'VARROC': 'Varroc Engineering Limited_2021-07-17.csv',
#  'SUVENPHAR': 'SUVEN PHARMACEUTICALS LIMITED_2021-07-17.csv',
#  'UPL': 'UPL Limited_2021-07-17.csv',
#  'ITI': 'ITI Limited (Indian Teleph.Ind.Ltd)_2021-07-17.csv',
#  'DBL': 'Dilip Buildcon Limited_2021-07-17.csv',
#  'ABB': 'ABB India Limited_2021-07-17.csv',
#  'MAGMA': 'Magma Fincorp  Limited_2021-07-17.csv',
#  'SUDARSCHEM': 'Sudarshan Chemical Indus. Ltd.,_2021-07-17.csv',
#  'ADANITRANS': 'Adani Transmission Limited_2021-07-17.csv',
#  'TTL': 'T T Ltd_2021-07-17.csv',
#  'LFIC': 'LFIC_2021-07-17.csv',
#  'BRITANNIA': 'Britannia Industries Ltd.,_2021-07-17.csv',
#  'PANACHE': 'Panache Innovations Limited_2021-07-17.csv',
#  'CENTURYTEX': 'Century Textiles & Industries Ltd.,_2021-07-17.csv',
#  'SINTEX': 'Sintex Industries Ltd_2021-07-17.csv',
#  'GOLDSHARE': 'GOLDSHARE_2021-07-17.csv',
#  'BLISSGVS': 'Bliss GVS Pharma Limited_2021-07-17.csv',
#  'AVENTIS': 'Aventis Pharma Limited_2021-07-17.csv',
#  'RAIN': 'Rain Industries Limited_2021-07-17.csv',
#  'NUCLEUS': 'Nucleus Software Exports Ltd_2021-07-17.csv',
#  'ICICIPRULI': 'ICICI Prudential Life Insurance Company Limited_2021-07-17.csv',
#  'GOLDTECH': 'Goldstone Technologies Ltd._2021-07-17.csv',
#  'POWERGRID': 'POWER GRID CORPORATION OF INDIA LIMITED_2021-07-17.csv',
#  'SHILPAMED': 'Shilpa Medicare Ltd._2021-07-17.csv',
#  'TIJARIA': 'TIJARIA POLYPIPES LIMITED_2021-07-17.csv',
#  'HARRMALAYA': 'Harrisons Malayalam Ltd.,_2021-07-17.csv',
#  'ROHLTD': 'Royal Orchid Hotels Ltd_2021-07-17.csv',
#  '63MOONS': '63 Moons Technologies Limited_2021-07-17.csv',
#  'ARVEE': 'Arvee Laboratories (India) Limited_2021-07-17.csv',
#  'SHIVAMAUTO': 'SHIVAM AUTOTECH LIMITED_2021-07-17.csv',
#  'TAINWALCHM': 'Tainwala Chemicals & Plastics Ltd_2021-07-17.csv',
#  'TIMKEN': 'Timken India Ltd_2021-07-17.csv',
#  'JUMPNET': 'JUMP NETWORKS LIMITED_2021-07-17.csv',
#  'SPARC': 'Sun Pharma Advanced Research Company Ltd._2021-07-17.csv',
#  'THEMISMED': 'Themis Medicare Ltd._2021-07-17.csv',
#  'MANAKCOAT': 'MANAKCOAT_2021-07-17.csv',
#  'MUTHOOTFIN': 'MUTHOOT FINANCE LIMITED_2021-07-17.csv',
#  'HTMEDIA': 'HT Media Ltd_2021-07-17.csv',
#  'NRAIL': 'NRAIL_2021-07-17.csv',
#  'KIRLOSENG': 'Kirloskar Oil Engines Limited_2021-07-17.csv',
#  'CESC': 'CESC Limited,_2021-07-17.csv',
#  'TEAMLEASE': 'TeamLease Services Limited_2021-07-17.csv',
#  'RUPA': 'RUPA & COMPANY LIMITED_2021-07-17.csv',
#  'INDORAMA': 'Indo Rama Synthetics (India) Ltd.,_2021-07-17.csv',
#  'LODHA': 'Macrotech Developers Limited_2021-07-17.csv',
#  'OBEROIRLTY': 'OBEROI REALTY LIMITED_2021-07-17.csv',
#  'JINDALSWHL': 'Jindal South West Holdings Limited_2021-07-17.csv',
#  'BOSCHLTD': 'Bosch Ltd_2021-07-17.csv',
#  'SHALBY': 'Shalby Limited_2021-07-17.csv',
#  'BHARATRAS': 'Bharat Rasayan Limited_2021-07-17.csv',
#  'DQE': 'DQ Entertainment (International) Limited_2021-07-17.csv',
#  'SHRADHA': 'SHRADHA_2021-07-17.csv',
#  'MAFANG': 'Mirae Asset Mutual Fund_2021-07-17.csv',
#  'PLASTIBLEN': 'Plastiblends India Ltd._2021-07-17.csv',
#  'OFSS': 'Oracle Financial Services Software Limited_2021-07-17.csv',
#  'SUNPHARMA': 'Sun Pharmaceutical Industries Ltd._2021-07-17.csv',
#  'ZUARIAGRO': 'Zuari Industries Limited_2021-07-17.csv',
#  'IFGLEXPOR': 'IFGL Refractories Limited_2021-07-17.csv',
#  'ALPSINDUS': 'Alps Industries Ltd._2021-07-17.csv',
#  'KILITCH': 'Kilitch Drugs (I) Ltd._2021-07-17.csv',
#  'SUMMITSEC': 'SUMMIT SECURITIES LTD._2021-07-17.csv',
#  'ZEELEARN': 'ZEE LEARN LIMITED_2021-07-17.csv',
#  'PAISALO': 'PAISALO DIGITAL LIMITED_2021-07-17.csv',
#  'HITACHIHOM': 'Hitachi Home and Life Solutions (India) Limited_2021-07-17.csv',
#  'NECCLTD': 'North Eastern Carrying Corporation Limited_2021-07-17.csv',
#  'NECLIFE': 'Nectar Lifesciences Limited_2021-07-17.csv',
#  'BSL': 'BSL Ltd.,_2021-07-17.csv',
#  'AXISTECETF': 'AXISTECETF_2021-07-17.csv',
#  'BCLIND': 'BCLIND_2021-07-17.csv',
#  'UFO': 'UFO Moviez India Limited_2021-07-17.csv',
#  'MAHINDCIE': 'Mahindra CIE Automotive Limited_2021-07-17.csv',
#  'VIKASLIFE': 'VIKAS LIFECARE LIMITED_2021-07-17.csv',
#  'HBANKETF': 'HDFC Mutual Fund_2021-07-17.csv',
#  'REPL': 'REPL_2021-07-17.csv',
#  'CROMPGREAV': 'Crompton Greaves Limited_2021-07-17.csv',
#  'RUCHI': 'RUCHI_2021-07-17.csv',
#  'IDEA': 'VODAFONE IDEA LIMITED_2021-07-17.csv',
#  'BALAXI': 'BALAXI_2021-07-17.csv',
#  'CPSEETF': 'Goldman Sachs Mutual Fund_2021-07-17.csv',
#  'EICHERMOT': 'Eicher Motors Ltd._2021-07-17.csv',
#  'RADICO': 'Radico Khaitan Ltd._2021-07-17.csv',
#  'TDPOWERSYS': 'TD Power Systems Ltd_2021-07-17.csv',
#  'CCL': 'CCL Products (India) Ltd._2021-07-17.csv',
#  'CENTRALBK': 'Central Bank of India_2021-07-17.csv',
#  'FINANTECH': 'Financial Technologies (India) Limited_2021-07-17.csv',
#  'TVSELECT': 'TVS Electronics Ltd._2021-07-17.csv',
#  'RAMCOSYS': 'Ramco Systems Ltd_2021-07-17.csv',
#  'TIMESGTY': 'Times Guaranty Ltd._2021-07-17.csv',
#  'RANASUG': 'Rana Sugars Ltd._2021-07-17.csv',
#  'MON100': 'MON100_2021-07-17.csv',
#  'PHOENIXLTD': 'The Phoenix Mills Ltd.,_2021-07-17.csv',
#  'ELGIEQUIP': 'Elgi Equipments Ltd.,_2021-07-17.csv',
#  'ARENTERP': 'Rajdarshan Industries Ltd.,_2021-07-17.csv',
#  'ASHIMASYN': 'Ashima Ltd_2021-07-17.csv',
#  'ABSLBANETF': 'Aditya Birla Sun Life Mutual Fund_2021-07-17.csv',
#  'ORIENTCEM': 'ORIENT CEMENT LIMITED_2021-07-17.csv',
#  'TATAMETALI': 'Tata Metaliks Ltd_2021-07-17.csv',
#  'INDLMETER': 'IMP Power Ltd._2021-07-17.csv',
#  'PITTILAM': 'Pitti Laminations Limited_2021-07-17.csv',
#  'DCMSHRIRAM': 'DCM Shriram Limited_2021-07-17.csv',
#  'ORIENTLTD': 'Orient Press ltd._2021-07-17.csv',
#  'LOGIXMICRO': 'Logix Microsystems Limited_2021-07-17.csv',
#  'IDFCFIRSTB': 'IDFC FIRST BANK LIMITED_2021-07-17.csv',
#  'SKFINDIA': 'SKF India Ltd._2021-07-17.csv',
#  'FORTIS': 'Fortis Healthcare Ltd_2021-07-17.csv',
#  'TRITURBINE': 'Triveni Turbine Limited_2021-07-17.csv',
#  'DRREDDY': "Dr. Reddy's Laboratories Ltd.,_2021-07-17.csv",
#  'BSELINFRA': 'BSEL Infrastructure Realty Ltd._2021-07-17.csv',
#  'MAGADSUGAR': 'MAGADSUGAR_2021-07-17.csv',
#  'UCALFUEL': 'Ucal Fuel Systems Ltd.,_2021-07-17.csv',
#  'ASTRAZEN': 'AstraZeneca Pharma India Ltd._2021-07-17.csv',
#  'PAPERPROD': 'The Paper Products Limited_2021-07-17.csv',
#  'KHANDSE': 'Khandwala Securities Ltd._2021-07-17.csv',
#  'SIMBHALS': 'Simbhaoli Sugars Ltd_2021-07-17.csv',
#  'AUSOMENT': 'AuSom Enterprise Limited_2021-07-17.csv',
#  'NETFGILT5Y': 'NETFGILT5Y_2021-07-17.csv',
#  'STARPAPER': 'Star Paper Mills Ltd._2021-07-17.csv',
#  'GLFL': 'Gujarat Lease Financing Limited,_2021-07-17.csv',
#  'WENDT': 'Wendt (India) Ltd.,_2021-07-17.csv',
#  'ESTER': 'Ester Industries Ltd.,_2021-07-17.csv',
#  'PGHH': 'Procter & Gamble Hygiene & Health Care Ltd._2021-07-17.csv',
#  'MADHAV': 'Madhav Marbles & Granites Ltd.,_2021-07-17.csv',
#  'CUBEXTUB': 'Cubex Tubings Ltd_2021-07-17.csv',
#  'DBCORP': 'D.B.Corp Limited_2021-07-17.csv',
#  'MAXHEALTH': 'Max Healthcare Institute Limited_2021-07-17.csv',
#  'MMP': 'MMP_2021-07-17.csv',
#  'CHOLAHLDNG': 'CHOLAMANDALAM FINANCIAL HOLDINGS LIMITED_2021-07-17.csv',
#  'STCINDIA': 'State Trading Corporation of India_2021-07-17.csv',
#  'PSL': 'PSL Limited_2021-07-17.csv',
#  'MARKSANS': 'Marksans Pharma Ltd._2021-07-17.csv',
#  'EIMCOELECO': 'EIMCO Elecon India Ltd.,_2021-07-17.csv',
#  'PRESTIGE': 'Prestige Estates Projects Limited_2021-07-17.csv',
#  'ANMOL': 'Anmol India Limited_2021-07-17.csv',
#  'ICICIGOLD': 'ICICIGOLD_2021-07-17.csv',
#  'IDFC': 'IDFC LIMITED_2021-07-17.csv',
#  'GUJFLUORO': 'Gujarat Fluorochemicals Limited_2021-07-17.csv',
#  'LICNETFGSC': 'LICNETFGSC_2021-07-17.csv',
#  'MACPOWER': 'MACPOWER_2021-07-17.csv',
#  'AMBUJACEM': 'Ambuja Cements Ltd._2021-07-17.csv',
#  'INDTERRAIN': 'Indian Terrain Fashions Limited_2021-07-17.csv',
#  'CAMLINFINE': 'Camlin Fine Sciences Ltd_2021-07-17.csv',
#  'PRAKASH': 'Prakash Industries Ltd.,_2021-07-17.csv',
#  'JISLDVREQS': 'Jain Irrigation Systems Ltd.,_2021-07-17.csv',
#  'CORALFINAC': 'Coral India Finance And Housing Ltd_2021-07-17.csv',
#  'DCMSRMCONS': 'DCM Shriram Consolidated Limited_2021-07-17.csv',
#  'BHARATGEAR': 'Bharat Gears Ltd.,_2021-07-17.csv',
#  'EMAMIREAL': 'EMAMI REALTY LIMITED_2021-07-17.csv',
#  'SPIC': 'Southern Petrochemical Industries Corporation Limited_2021-07-17.csv',
#  'APCL': 'Anjani Portland Cement Ltd._2021-07-17.csv',
#  'SPMLINFRA': 'SPML Infra Limited_2021-07-17.csv',
#  'PUNJABCHEM': 'Punjab Chemicals and Crop Protection Ltd._2021-07-17.csv',
#  'TRIGYN': 'Trigyn Technologies Ltd._2021-07-17.csv',
#  'IIFLSEC': 'IIFL Securities Limited_2021-07-17.csv',
#  'PFIZER': 'Pfizer Ltd.,_2021-07-17.csv',
#  'AUBANK': 'AU Small Finance Bank Limited_2021-07-17.csv',
#  'LINDEINDIA': 'Linde India Limited_2021-07-17.csv',
#  'ROSSARI': 'ROSSARI BIOTECH LIMITED_2021-07-17.csv',
#  'LICHSGFIN': 'Lic Housing Finance Ltd._2021-07-17.csv',
#  'RPOWER': 'Reliance Power Limited_2021-07-17.csv',
#  'MEGH': 'Meghmani Organics Limited_2021-07-17.csv',
#  'ALICON': 'Alicon Castalloy Limited_2021-07-17.csv',
#  'SABEVENTS': 'Sab Events & Governance Now Media Limited_2021-07-17.csv',
#  'XCHANGING': 'Xchanging Solutions Limited_2021-07-17.csv',
#  'UNIDT': 'United Drilling Tools Ltd.,_2021-07-17.csv',
#  'TATACHEM': 'Tata Chemicals Ltd_2021-07-17.csv',
#  'TV18BRDCST': 'TV18 Broadcast Ltd._2021-07-17.csv',
#  'ADORWELD': 'Ador Welding Ltd._2021-07-17.csv',
#  'PSPPROJECT': 'PSP Projects Limited_2021-07-17.csv',
#  'IVC': 'IL & FS Investment Managers Ltd._2021-07-17.csv',
#  'NITCO': 'Nitco Ltd._2021-07-17.csv',
#  'INDUSINDBK': 'IndusInd Bank Ltd._2021-07-17.csv',
#  'IOLCP': 'IOL Chemicals & Pharmaceuticals Ltd_2021-07-17.csv',
#  'BAJAJHIND': 'Bajaj Hindusthan Sugar Limited_2021-07-17.csv',
#  'SILLYMONKS': 'Silly Monks Entertainment Limited_2021-07-17.csv',
#  'IITL': 'Industrial Investment Trust Ltd.,_2021-07-17.csv',
#  'MIC': 'MIC Electronics Limited_2021-07-17.csv',
#  'LGBFORGE': 'LGB Forge Limited_2021-07-17.csv',
#  'WEIZFOREX': 'Weizmann Forex Limited_2021-07-17.csv',
#  'PSUBNKBEES': 'Reliance Mutual Fund-Permitted_2021-07-17.csv',
#  'ABAN': 'Aban  Offshore Ltd.,_2021-07-17.csv',
#  'NOVARTIND': 'Novartis India Limited._2021-07-17.csv',
#  'GODREJAGRO': 'Godrej Agrovet Limited_2021-07-17.csv',
#  'RAMASTEEL': 'Rama Steel Tubes Limited_2021-07-17.csv',
#  'AARVI': 'AARVI_2021-07-17.csv',
#  'FRETAIL': 'Future Retail Ltd._2021-07-17.csv',
#  'ZEENEWS': 'Zee News Limited_2021-07-17.csv',
#  'SUULD': 'SUULD_2021-07-17.csv',
#  'BHANDARI': 'BHANDARI_2021-07-17.csv',
#  'GEOJITBNPP': 'Geojit BNP Paribas Financial Services Limited_2021-07-17.csv',
#  'EMAMIINFRA': 'Emami Infrastructure Limited_2021-07-17.csv',
#  'PDSMFL': 'PDS MULTINATIONAL FASHIONS LIMITED_2021-07-17.csv',
#  'INEOSSTYRO': 'INEOS Styrolution India Limited_2021-07-17.csv',
#  'HBSL': 'HBSL_2021-07-17.csv',
#  'JINDALPOLY': 'Jindal Poly Films Ltd._2021-07-17.csv',
#  'BGRENERGY': 'BGR ENERGY SYSTEMS LIMITED_2021-07-17.csv',
#  'OMKARCHEM': 'OMKAR SPECIALITY CHEMICALS LIMITED_2021-07-17.csv',
#  'JPASSOCIAT': 'Jaiprakash Associates Limited_2021-07-17.csv',
#  'BIRLATYRE': 'BIRLATYRE_2021-07-17.csv',
#  'GROBTEA': 'GROBTEA_2021-07-17.csv',
#  'GOCLCORP': 'GOCL Corporation Limited_2021-07-17.csv',
#  'BALKRISIND': 'Balkrishna Industries Ltd.,_2021-07-17.csv',
#  'ATLANTA': 'Atlanta Limited_2021-07-17.csv',
#  'MCDHOLDING': 'McDowell Holdings Limited_2021-07-17.csv',
#  'FOSECOIND': 'Foseco India Ltd_2021-07-17.csv',
#  'ARTEMISMED': 'Artemis Medicare Services Limited_2021-07-17.csv',
#  'STEL': 'STEL Holdings\xa0Limited_2021-07-17.csv',
#  'PURVA': 'Puravankara Limited_2021-07-17.csv',
#  'AMTEKINDIA': 'Amtek India Limited_2021-07-17.csv',
#  'SITINET': 'Siti Networks Limited_2021-07-17.csv',
#  'DEWANHOUS': 'Dewan Housing Finance Corporation Limited_2021-07-17.csv',
#  'SPLIL': 'SPL INDUSTRIES LIMITED_2021-07-17.csv',
#  'LAURUSLABS': 'Laurus Labs Limited_2021-07-17.csv',
#  'MANALIPETC': 'Manali Petrochemicals Ltd.,_2021-07-17.csv',
#  'AMBIKCO': 'Ambika Cotton Mills Ltd._2021-07-17.csv',
#  'TRIDENT': 'Trident Ltd_2021-07-17.csv',
#  'NCPSESDL24': 'NCPSESDL24_2021-07-17.csv',
#  'HESTERBIO': 'Hester Biosciences Ltd_2021-07-17.csv',
#  'BPL': 'BPL Ltd.,_2021-07-17.csv',
#  'INFOMEDIA': 'Infomedia Press Limited_2021-07-17.csv',
#  'COSMOFILMS': 'Cosmo Films Ltd.,_2021-07-17.csv',
#  'GOKEX': 'Gokaldas Exports Ltd_2021-07-17.csv',
#  'INTEGRA': 'Integra Garments and Textiles Limited_2021-07-17.csv',
#  'SRTRANSFIN': 'Shriram Transport Finance Co. Ltd.,_2021-07-17.csv',
#  'SUNDARAM': 'Sundaram Multi Pap Ltd._2021-07-17.csv',
#  'EQ30': 'EQ30_2021-07-17.csv',
#  'SUNDARMHLD': 'SUNDARMHLD_2021-07-17.csv',
#  'PTC': 'PTC India Ltd_2021-07-17.csv',
#  'SANOFI': 'Sanofi India Ltd_2021-07-17.csv',
#  'SONACOMS': 'Sona BLW Precision Forgings Limited_2021-07-17.csv',
#  'KOTHARIPET': 'KOTHARIPET_2021-07-17.csv',
#  'ZEEL': 'Zee Entertainment Enterprises Ltd._2021-07-17.csv',
#  'KARDA': 'Karda Constructions Limited_2021-07-17.csv',
#  'MICROSEC': 'Microsec Financial Services Limited_2021-07-17.csv',
#  'SHARDAMOTR': 'Sharda Motor Industries Limited_2021-07-17.csv',
#  'ORIENTELEC': 'Orient Electric Limited_2021-07-17.csv',
#  'JSL': 'Jindal Stainless Limited_2021-07-17.csv',
#  'PARAGMILK': 'Parag Milk Foods Limited_2021-07-17.csv',
#  'ALPA': 'Alpa Laboratories Limited_2021-07-17.csv',
#  'INTELLECT': 'INTELLECT DESIGN ARENA LIMITED_2021-07-17.csv',
#  'CNOVAPETRO': 'CIL Nova Petrochemicals Limited_2021-07-17.csv',
#  'WEIZMANIND': 'Weizmann Limited.,_2021-07-17.csv',
#  'STOREONE': 'Store One Retail India Limited_2021-07-17.csv',
#  'DBREALTY': 'D B REALTY LIMITED_2021-07-17.csv',
#  'AXISBPSETF': 'AXISBPSETF_2021-07-17.csv',
#  'INDOTECH': 'Indo Tech Transformers Limited_2021-07-17.csv',
#  'VSSL': 'Vardhman Special Steels Ltd_2021-07-17.csv',
#  'SORILINFRA': 'SORIL Infra Resources Limited_2021-07-17.csv',
#  'DELTAMAGNT': 'DELTA MANUFACTURING LIMITED _2021-07-17.csv',
#  'TCPLPACK': 'TCPL Packaging Limited_2021-07-17.csv',
#  'WEALTH': 'Wealth First Portfolio Managers Limited_2021-07-17.csv',
#  'BOC': 'BOC India Limited_2021-07-17.csv',
#  'INDHOTEL': 'Indian Hotels Co. Ltd_2021-07-17.csv',
#  'HINDNATGLS': 'Hindusthan National Glass & Industr_2021-07-17.csv',
#  'SOTL': 'Savita Oil Technologies Limited_2021-07-17.csv',
#  'IVP': 'IVP Ltd.,_2021-07-17.csv',
#  'WORTH': 'Worth Investment & Trading Co Limited_2021-07-17.csv',
#  'DVL': 'Dhunseri Ventures Limited_2021-07-17.csv',
#  'CAPACITE': "Capacit'e Infraprojects Limited_2021-07-17.csv",
#  'DICIND': 'DIC India Ltd_2021-07-17.csv',
#  'NEULANDLAB': 'Neuland Laboratories Limited._2021-07-17.csv',
#  'ORIENTALTL': 'Oriental Trimex Limited_2021-07-17.csv',
#  'HEIDELBERG': 'HeidelbergCement  India Limited_2021-07-17.csv',
#  'ORIENTBELL': 'Orient Bell Limited_2021-07-17.csv',
#  'VETO': 'VETO SWITCHGEARS AND CABLES LIMITED_2021-07-17.csv',
#  'UNIPHOS': 'Uniphos Enterprises Limited._2021-07-17.csv',
#  'VLSFINANCE': 'VLS Finance Limited_2021-07-17.csv',
#  'MAHLIFE': 'Mahindra Lifespace Developers Ltd._2021-07-17.csv',
#  'TATAELXSI': 'Tata Elxsi Ltd_2021-07-17.csv',
#  'ITDCEM': 'ITD Cementation India Ltd_2021-07-17.csv',
#  'DOLLAR': 'Dollar Industries Limited_2021-07-17.csv',
#  'BSLNIFTY': 'BSLNIFTY_2021-07-17.csv',
#  'JBCHEPHARM': 'J.B. Chemicals & Pharmaceuticals Lt_2021-07-17.csv',
#  'GAMMNINFRA': 'Gammon Infrastructure Projects Limited_2021-07-17.csv',
#  'JUNIORBEES': 'Reliance Mutual Fund-Permitted_2021-07-17.csv',
#  'L&TFH': 'L&T FINANCE HOLDINGS LIMITED_2021-07-17.csv',
#  'BIRLAERIC': 'Birla Ericsson Optical Limited_2021-07-17.csv',
#  'ELECTCAST': 'Electrosteel Castings Ltd.,_2021-07-17.csv',
#  'GLOBALVECT': 'Global Vectra Helicorp Ltd._2021-07-17.csv',
#  'LIQUIDETF': 'LIQUIDETF_2021-07-17.csv',
#  'ICICIMCAP': 'ICICI Prudential Mutual Fund_2021-07-17.csv',
#  'RPGLIFE': 'RPG Life Sciences Limited_2021-07-17.csv',
#  'LICNFNHGP': 'LIC Mutual Fund_2021-07-17.csv',
#  'BSHSL': 'BSHSL_2021-07-17.csv',
#  'MAHABANK': 'Bank of maharashtra_2021-07-17.csv',
#  'NHPC': 'NHPC Limited_2021-07-17.csv',
#  'CARERATING': 'CARE Ratings Limited_2021-07-17.csv',
#  'VAIBHAVGEM': 'Vaibhav Gems Limited_2021-07-17.csv',
#  'MPHASIS': 'Mphasis Limited_2021-07-17.csv',
#  'BPCL': 'Bharat Petroleum Corpn. Ltd.,_2021-07-17.csv',
#  'PIONDIST': 'Pioneer Distilleries Ltd._2021-07-17.csv',
#  'ABFRL': 'Aditya Birla Fashion and Retail Limited_2021-07-17.csv',
#  'PETRONET': 'PETRONET LNG LTD._2021-07-17.csv',
#  'ANURAS': 'Anupam Rasayan India Limited_2021-07-17.csv',
#  'TEXMOPIPES': 'Texmo Pipes and Products Limited_2021-07-17.csv',
#  'UNIVASTU': 'UNIVASTU_2021-07-17.csv',
#  'ROMAN': 'Roman Tarmat Limited_2021-07-17.csv',
#  'GSFC': 'Gujarat State Fertilizers & Chem.Ltd_2021-07-17.csv',
#  'CRISIL': 'CRISIL Ltd._2021-07-17.csv',
#  'ROLTA': 'Rolta India Ltd.,_2021-07-17.csv',
#  'GOLDINFRA': 'Goldstone Infratech Limited_2021-07-17.csv',
#  'ONGC': 'Oil And Natural Gas Corporation Ltd_2021-07-17.csv',
#  'MINDACORP': 'Minda Corporation Limited_2021-07-17.csv',
#  'NELCO': 'Nelco Ltd_2021-07-17.csv',
#  'MIDHANI': 'Mishra Dhatu Nigam Limited_2021-07-17.csv',
#  'ABMINTLTD': 'ABMINTLTD_2021-07-17.csv',
#  'NETWORK18': 'Network 18 Media & Investments Limited_2021-07-17.csv',
#  'GPPL': 'Gujarat Pipavav Port Limited_2021-07-17.csv',
#  'RAJRATAN': 'Rajratan Global Wire Limited_2021-07-17.csv',
#  'KMSUGAR': 'K. M. Sugar Mills Ltd._2021-07-17.csv',
#  'CINEVISTA': 'Cinevista Limited_2021-07-17.csv',
#  'KEYFINSERV': 'KEYFINSERV_2021-07-17.csv',
#  'PHILIPCARB': 'Phillips Carbon Black Ltd.,_2021-07-17.csv',
#  'STARCEMENT': 'Star Cement Limited_2021-07-17.csv',
#  'IMPAL': 'INDIA MOTOR PARTS & ACCESSORIES LTD_2021-07-17.csv',
#  'NEYVELILIG': 'Neyveli Lignite Corporation Limited_2021-07-17.csv',
#  'HUHTAMAKI': 'HUHTAMAKI INDIA LIMITED_2021-07-17.csv',
#  'SNOWMAN': 'SNOWMAN LOGISTICS LIMITED_2021-07-17.csv',
#  'CUMMINSIND': 'Cummins India Ltd.,_2021-07-17.csv',
#  'MAHINDFORG': 'Mahindra Forgings Limited_2021-07-17.csv',
#  'UJAAS': 'Ujaas Energy Limited_2021-07-17.csv',
#  'SAKUMA': 'Sakuma Exports Ltd._2021-07-17.csv',
#  'BSOFT': 'BIRLASOFT LIMITED_2021-07-17.csv',
#  'MORARJEE': 'Morarjee Textiles Limited_2021-07-17.csv',
#  'MAHSEAMLES': 'Maharashtra Seamless Ltd._2021-07-17.csv',
#  'IRISDOREME': 'IRISDOREME_2021-07-17.csv',
#  'BARBEQUE': 'BARBEQUE-NATION HOSPITALITY LIMITED_2021-07-17.csv',
#  'WABAG': 'VA Tech Wabag Limited_2021-07-17.csv',
#  'MAHSCOOTER': 'Maharashtra Scooters Ltd.,_2021-07-17.csv',
#  'BESTAGRO': 'BEST AGROLIFE LIMITED_2021-07-17.csv',
#  'RML': 'Rane (Madras)  Ltd._2021-07-17.csv',
#  'WONDERLA': 'Wonderla Holidays Limited_2021-07-17.csv',
#  '3MINDIA': '3M India Ltd._2021-07-17.csv',
#  'GALLISPAT': 'Gallantt Ispat Limited_2021-07-17.csv',
#  'TTML': 'Tata Teleservices (Maharashtra) Ltd._2021-07-17.csv',
#  'ECLERX': 'eClerx Services Limited_2021-07-17.csv',
#  'APPAPER': 'The Andhra Pradesh Paper Mills Limited_2021-07-17.csv',
#  'SASKEN': 'Sasken Technologies Limited_2021-07-17.csv',
#  'GDL': 'GATEWAY DISTRIPARKS LTD._2021-07-17.csv',
#  'DEEPAKNTR': 'DEEPAKNTR_2021-07-17.csv',
#  'KAUSHALYA': 'Kaushalya Infrastructure Development Corporation Ltd_2021-07-17.csv',
#  'SHEMAROO': 'SHEMAROO ENTERTAINMENT LIMITED_2021-07-17.csv',
#  'INDIGOPNTS': 'Indigo Paints Limited_2021-07-17.csv',
#  'KUANTUM': 'Kuantum Papers Limited_2021-07-17.csv',
#  'SHREDIGCEM': 'Shree Digvijay Cement Co. Ltd.,_2021-07-17.csv',
#  'EIHOTEL': 'EIH Ltd_2021-07-17.csv',
#  'DCM': 'DCM Ltd.,_2021-07-17.csv',
#  'NDTV': 'New Delhi Television Limited_2021-07-17.csv',
#  'JAMNAAUTO': 'Jamna Auto Industries Ltd.,_2021-07-17.csv',
#  'SEYAIND': 'Seya Industries Ltd_2021-07-17.csv',
#  'ALCHEM': 'Alchemist Limited_2021-07-17.csv',
#  'AVANTIFEED': 'AVANTIFEED_2021-07-17.csv',
#  'MAGNUM': 'MAGNUM VENTURES LIMITED_2021-07-17.csv',
#  'NTPC': 'NTPC Limited_2021-07-17.csv',
#  'TREJHARA': 'Trejhara Solutions Limited_2021-07-17.csv',
#  'ALOKINDS': 'ALOKINDS_2021-07-17.csv',
#  'SUVEN': 'Suven Life Sciences Ltd._2021-07-17.csv',
#  'CEREBRAINT': 'Cerebra Integrated Technologies Ltd._2021-07-17.csv',
#  'APOLLOHOSP': 'Apollo Hospitals Enterprises Ltd.,_2021-07-17.csv',
#  'NBIFIN': 'NBIFIN_2021-07-17.csv',
#  'JAGSNPHARM': 'Jagsonpal Pharmaceuticals Limited,_2021-07-17.csv',
#  'OMAXE': 'OMAXE LIMITED_2021-07-17.csv',
#  'GRSE': 'Garden Reach Shipbuilders & Engineers Limited_2021-07-17.csv',
#  'SWELECTES': 'Swelect Energy Systems Limited_2021-07-17.csv',
#  'CONTROLPR': 'Control Print (India) Ltd._2021-07-17.csv',
#  'ASAHISONG': 'Asahi Songwon Colors Ltd._2021-07-17.csv',
#  'NAVKARCORP': 'Navkar Corporation Limited_2021-07-17.csv',
#  'CLSEL': 'CLSEL_2021-07-17.csv',
#  'CROMPTON': 'Crompton Greaves Consumer Electricals Limited_2021-07-17.csv',
#  'ZICOM': 'Zicom Electronic Security Systems Limited_2021-07-17.csv',
#  'CALSOFT': 'California Software Co. Ltd._2021-07-17.csv',
#  'KOTAKBANK': 'Kotak Mahindra Bank Ltd._2021-07-17.csv',
#  'VENUSREM': 'Venus Remedies Ltd._2021-07-17.csv',
#  'HUBTOWN': 'Hubtown Limited_2021-07-17.csv',
#  'GSCLCEMENT': 'Gujarat Sidhee Cement Limited.,_2021-07-17.csv',
#  'FAGBEARING': 'FAG Bearings India Limited_2021-07-17.csv',
#  'WSIND': 'W.S. Industries (India) Ltd.,_2021-07-17.csv',
#  'OIL': 'Oil India Limited_2021-07-17.csv',
#  'EBBETF0430': 'EBBETF0430_2021-07-17.csv',
#  'IZMO': 'IZMO Limited_2021-07-17.csv',
#  'VRLLOG': 'VRL Logistics Limited_2021-07-17.csv',
#  'SHAREINDIA': 'Share India Securities Limited_2021-07-17.csv',
#  'SHK': 'S H Kelkar and Company Limited_2021-07-17.csv',
#  'IBWSL': 'Indiabulls Wholesale Services Limited_2021-07-17.csv',
#  'LAKSHVILAS': 'Lakshmi Vilas Bank Limited_2021-07-17.csv',
#  'ALANKIT': 'Alankit Limited_2021-07-17.csv',
#  'CREST': 'CREST VENTURES LIMITED_2021-07-17.csv',
#  'PITTIENG': 'PITTI ENGINEERING LIMITED_2021-07-17.csv',
#  'RKFORGE': 'ramkrishna forgings Ltd._2021-07-17.csv',
#  'FAIRCHEMOR': 'Fairchem Organics Limited_2021-07-17.csv',
#  'NESTLEIND': 'Nestle India Ltd._2021-07-17.csv',
#  'GODHA': 'Godha Cabcon & Insulation Limited_2021-07-17.csv',
#  'POKARNA': 'Pokarna Ltd._2021-07-17.csv',
#  'SUPPETRO': 'Supreme Petrochem Ltd._2021-07-17.csv',
#  'SESHAPAPER': 'Seshasayee Paper & Boards Ltd.,_2021-07-17.csv',
#  'SHYAMCENT': 'SHYAMCENT_2021-07-17.csv',
#  'RBL': 'Rane Brake Lining Limited_2021-07-17.csv',
#  'MAX': 'Max India Limited_2021-07-17.csv',
#  'SONASTEER': 'Sona Koyo Steering Systems Limited_2021-07-17.csv',
#  'RCOM': 'Reliance Communications Limited_2021-07-17.csv',
#  'GENUSPAPER': 'GENUS PAPER & BOARDS LIMITED_2021-07-17.csv',
#  'GARFIBRES': 'GARWARE TECHNICAL FIBRES LIMITED_2021-07-17.csv',
#  'AHMEDFORGE': 'Ahmednagar Forgings Limited_2021-07-17.csv',
#  'NBVENTURES': 'NBVENTURES_2021-07-17.csv',
#  'VIPIND': 'V.I.P. Industries Ltd.,_2021-07-17.csv',
#  'ARVSMART': 'Arvind SmartSpaces Limited_2021-07-17.csv',
#  'KOTAKBKETF': 'KOTAKBKETF_2021-07-17.csv',
#  'HIRECT': 'Hind Rectifiers Ltd.,_2021-07-17.csv',
#  'DGCONTENT': 'Digicontent Limited_2021-07-17.csv',
#  'DIXON': 'Dixon Technologies (India) Limited_2021-07-17.csv',
#  'SFL': 'Sheela Foam Limited_2021-07-17.csv',
#  'RAIREKMOH': 'Raisaheb Rekhchand Mohota Spg & Wvg Mills Ltd_2021-07-17.csv',
#  'WIPRO': 'Wipro  Ltd.,_2021-07-17.csv',
#  'LUPIN': 'Lupin Ltd_2021-07-17.csv',
#  'SIMPLEXINF': 'Simplex Infrastructures Limited_2021-07-17.csv',
#  'KOTHARIPRO': 'Kothari Products Ltd._2021-07-17.csv',
#  'BALAMINES': 'Balaji Amines Ltd._2021-07-17.csv',
#  'TORNTPHARM': 'Torrent Pharmaceuticals Ltd._2021-07-17.csv',
#  'CAPTRUST': 'CAPTRUST_2021-07-17.csv',
#  'TIRUMALCHM': 'Thirumalai Chemicals Ltd.,_2021-07-17.csv',
#  'SHRENIK': 'Shrenik Limited_2021-07-17.csv',
#  'WELSPUNIND': 'Welspun India Ltd_2021-07-17.csv',
#  'MTNL': 'Mahanagar Telephone Nigam Ltd.,_2021-07-17.csv',
#  'PATINTLOG': 'Patel Integrated Logistics Ltd_2021-07-17.csv',
#  'MATRIMONY': 'Matrimony.com Limited_2021-07-17.csv',
#  'MAWANASUG': 'Mawana Sugars Ltd_2021-07-17.csv',
#  'COFORGE': 'COFORGE LIMITED_2021-07-17.csv',
#  'TIINDIA': 'Tube Investments of India Ltd_2021-07-17.csv',
#  'AGROPHOS': 'AGROPHOS_2021-07-17.csv',
#  'SINTERCOM': 'SINTERCOM_2021-07-17.csv',
#  'SAFARI': 'SAFARI_2021-07-17.csv',
#  'OMAXAUTO': 'Omax Autos Ltd.,_2021-07-17.csv',
#  'CLNINDIA': 'Clariant Chemicals (India) Limited_2021-07-17.csv',
#  'REPCOHOME': 'Repco Home Finance Limited_2021-07-17.csv',
#  'WESTLIFE': 'Westlife Development Ltd_2021-07-17.csv',
#  'LYPSAGEMS': 'Lypsa Gems & Jewellery Limited_2021-07-17.csv',
#  'VGUARD': 'V-Guard Industries Ltd._2021-07-17.csv',
#  'KWALITY': 'Kwality Dairy (India) Limited_2021-07-17.csv',
#  'SUPREMEENG': 'Supreme Engineering Limited_2021-07-17.csv',
#  'HINDUJAVEN': 'Hinduja Ventures Limited_2021-07-17.csv',
#  'GRAPHITE': 'Graphite India Ltd._2021-07-17.csv',
#  'SUBEXLTD': 'SUBEXLTD_2021-07-17.csv',
#  'VISHNU': 'Vishnu Chemicals Limited_2021-07-17.csv',
#  'NATHSEED': 'Nath Seeds Limited_2021-07-17.csv',
#  'MOLDTECH': 'MOLDTECH_2021-07-17.csv',
#  'MOREPENLAB': 'Morepen Laboratories Ltd._2021-07-17.csv',
#  'GARDENSILK': 'Garden Silk Mills Limited_2021-07-17.csv',
#  'CGPOWER': 'CG Power and Industrial Solutions Limited_2021-07-17.csv',
#  'FLFL': 'Future Lifestyle Fashions Limited_2021-07-17.csv',
#  'ADVANIHOTR': 'Advani Hotels & Resorts (India) Ltd._2021-07-17.csv',
#  'NETFDIVOPP': 'NETFDIVOPP_2021-07-17.csv',
#  'HISARMETAL': 'HISARMETAL_2021-07-17.csv',
#  'RVNL': 'Rail Vikas Nigam Limited_2021-07-17.csv',
#  'BHARATWIRE': 'Bharat Wire Ropes Limited_2021-07-17.csv',
#  'FLUOROCHEM': 'Gujarat Fluorochemicals Limited_2021-07-17.csv',
#  'DLINKINDIA': 'D-Link (India) Ltd_2021-07-17.csv',
#  'SALASAR': 'Salasar Techno Engineering Limited_2021-07-17.csv',
#  'HPL': 'HPL Electric & Power Limited_2021-07-17.csv',
#  'NAM-INDIA': 'NIPPON LIFE INDIA ASSET MANAGEMENT LIMITED_2021-07-17.csv',
#  'SAIL': 'Steel Authority of India Ltd.,_2021-07-17.csv',
#  'SOLARA': 'SOLARA ACTIVE PHARMA SCIENCES LIMITED_2021-07-17.csv',
#  'TCIEXP': 'TCI Express Limited_2021-07-17.csv',
#  'EMAMILTD': 'Emami Ltd_2021-07-17.csv',
#  'PARSVNATH': 'Parsvnath Developers Ltd._2021-07-17.csv',
#  'INDOSTAR': 'IndoStar Capital Finance Limited_2021-07-17.csv',
#  'HEROMOTOCO': 'Hero MotoCorp Limited_2021-07-17.csv',
#  'MARATHON': 'Marathon Nextgen Realty Ltd_2021-07-17.csv',
#  'AURIONPRO': 'Aurionpro Solutions Ltd._2021-07-17.csv',
#  'SYNGENE': 'Syngene International Limited_2021-07-17.csv',
#  'ISMTLTD': 'ISMT Limited_2021-07-17.csv',
#  'PRAKASHCON': 'Prakash Constrowell Limited_2021-07-17.csv',
#  'NATCOPHARM': 'Natco Pharma Ltd._2021-07-17.csv',
#  'AYMSYNTEX': 'AYM Syntex Limited_2021-07-17.csv',
#  'SHREERAMA': 'Shree Rama Multi-tech Ltd._2021-07-17.csv',
#  'DALMIASUG': 'Dalmia Bharat Sugar and Industries Ltd_2021-07-17.csv',
#  'JUBILANT': 'Jubilant Life Sciences Limited_2021-07-17.csv',
#  'NRBBEARING': 'NRB Bearings Ltd._2021-07-17.csv',
#  'MANINDS': 'Man Industries (India) Ltd_2021-07-17.csv',
#  'SHREEPUSHK': 'Shree Pushkar Chemicals & Fertilisers Limited_2021-07-17.csv',
#  'MAHASTEEL': 'Mahamaya Steel Industries Limited_2021-07-17.csv',
#  'INDUSTOWER': 'INDUS TOWERS LIMITED_2021-07-17.csv',
#  'NPBET': 'NPBET_2021-07-17.csv',
#  'TCIFINANCE': 'TCI Finance Limited_2021-07-17.csv',
#  'TVSSRICHAK': 'TVS Srichakra Ltd.,_2021-07-17.csv',
#  'UTTAMSTL': 'Uttam Galva Steels Ltd._2021-07-17.csv',
#  '5PAISA': '5paisa Capital Limited_2021-07-17.csv',
#  'VADILALIND': 'Vadilal Industries Ltd.,_2021-07-17.csv',
#  'ONWARDTEC': 'Onward Technologies Ltd._2021-07-17.csv',
#  'WSTCSTPAPR': 'West Coast Paper Mills Limited_2021-07-17.csv',
#  'NH': 'Narayana Hrudayalaya Limited_2021-07-17.csv',
#  'MODISNME': 'Modison Metals Ltd_2021-07-17.csv',
#  'JBFIND': 'JBF Industries Ltd.,_2021-07-17.csv',
#  'PIRHEALTH': 'Piramal Healthcare Limited_2021-07-17.csv',
#  'TECHNOFAB': 'Technofab Engineering Limited_2021-07-17.csv',
#  'ISFT': 'Intrasoft Technologies Limited_2021-07-17.csv',
#  'GINNIFILA': 'Ginni Filaments Ltd._2021-07-17.csv',
#  'ASHOKLEY': 'Ashok Leyland Ltd.,_2021-07-17.csv',
#  'ANIKINDS': 'Anik Industries Limited_2021-07-17.csv',
#  'IBPOW': 'Indiabulls Power Limited_2021-07-17.csv',
#  'TEXINFRA': 'Texmaco Infrastructure & Holdings Ltd_2021-07-17.csv',
#  'REVATHI': 'Revathi Equipment Ltd._2021-07-17.csv',
#  'IDFNIFTYET': 'IDFNIFTYET_2021-07-17.csv',
#  'EXCELINFO': 'Excel Infoways Limited_2021-07-17.csv',
#  'MTEDUCARE': 'MT EDUCARE LIMITED_2021-07-17.csv',
#  'INSPIRISYS': 'Inspirisys Solutions Limited_2021-07-17.csv',
#  'PAGEIND': 'Page Industries Ltd._2021-07-17.csv',
#  'NAUKRI': 'Info Edge(India) Ltd._2021-07-17.csv',
#  'SHRIRAMCIT': 'Shriram-City Union Finance Ltd._2021-07-17.csv',
#  'BAFNAPH': 'BAFNAPH_2021-07-17.csv',
#  'PALASHSECU': 'Palash Securities Limited_2021-07-17.csv',
#  'ESCORTS': 'Escorts Limited,_2021-07-17.csv',
#  'SPANDANA': 'Spandana Sphoorty Financial Limited_2021-07-17.csv',
#  'APLAPOLLO': 'APL Apollo Tubes Limited_2021-07-17.csv',
#  'NATNLSTEEL': 'National Steel & Agro Industries Ltd._2021-07-17.csv',
#  'IGARASHI': 'Igarashi Motors India Ltd._2021-07-17.csv',
#  'ZEEMEDIA': 'Zee Media Corporation Limited_2021-07-17.csv',
#  'AFFLE': 'Affle (India) Limited_2021-07-17.csv',
#  'SHYAMMETL': 'Shyam Metalics and Energy Limited_2021-07-17.csv',
#  'MAXIND': 'MAXIND_2021-07-17.csv',
#  'PROINDIA': 'PROINDIA_2021-07-17.csv',
#  'SUMIT': 'SUMIT_2021-07-17.csv',
#  'SMCGLOBAL': 'SMC Global Securities Limited_2021-07-17.csv',
#  'FELDVR': 'Future Enterprises Limited_2021-07-17.csv',
#  'MOTILALOFS': 'Motilal Oswal Financial Services Limited_2021-07-17.csv',
#  'DEEPINDS': 'DEEPINDS_2021-07-17.csv',
#  'BAGFILMS': 'B.A.G. Films & Media Ltd_2021-07-17.csv',
#  'PIPAVAVDOC': 'Pipavav Defence and Offshore Engineering Company Limited_2021-07-17.csv',
#  'GFLLIMITED': 'GFL LIMITED_2021-07-17.csv',
#  'CIMMCO': 'Cimmco Birla Limited_2021-07-17.csv',
#  'RCF': 'Rashtriya Chemicals & Fertilizers Limited_2021-07-17.csv',
#  'GESHIP': 'Great Eastern Shipping Co. Ltd.,_2021-07-17.csv',
#  'DCBBANK': 'DCB Bank Limited_2021-07-17.csv',
#  'BIRLACABLE': 'Birla Cable Limited_2021-07-17.csv',
#  'NFL': 'National Fertilizers Ltd.,_2021-07-17.csv',
#  'HLEGLAS': 'HLE GLASCOAT LIMITED_2021-07-17.csv',
#  'NXTDIGITAL': 'NXTDIGITAL LIMITED _2021-07-17.csv',
#  'INDOWIND': 'Indowind Energy Ltd._2021-07-17.csv',
#  'NIACL': 'The New India Assurance Company Limited_2021-07-17.csv',
#  'RAMKY': 'Ramky Infrastructure Limited_2021-07-17.csv',
#  'METALFORGE': 'Metalyst Forgings Limited_2021-07-17.csv',
#  'LICNETFN50': 'LIC Mutual Fund_2021-07-17.csv',
#  'KIL': 'Kamdhenu Ispat Limited_2021-07-17.csv',
#  'TOKYOPLAST': 'Tokyo Plast International Ltd._2021-07-17.csv',
#  'INDIACEM': 'India Cements Ltd.,_2021-07-17.csv',
#  'RSSOFTWARE': 'R S Software India Ltd._2021-07-17.csv',
#  'BANDHANBNK': 'Bandhan Bank Limited_2021-07-17.csv',
#  'KKCL': 'Kewal Kiran Clothing Ltd._2021-07-17.csv',
#  'BHUSANSTL': 'Bhushan Steel Limited_2021-07-17.csv',
#  'AGARIND': 'Agarwal Industrial Corporation Limited_2021-07-17.csv',
#  'WSI': 'W S Industries (I) Limited_2021-07-17.csv',
#  'TATASTLLP': 'TATA STEEL LONG PRODUCTS LIMITED_2021-07-17.csv',
#  'OILCOUNTUB': 'Oil Country Tubular Ltd._2021-07-17.csv',
#  'NOCIL': 'NOCIL Ltd_2021-07-17.csv',
#  'PREMEXPLN': 'PREMEXPLN_2021-07-17.csv',
#  'CENTUM': 'Centum Electronics Ltd_2021-07-17.csv',
#  'AIRAN': 'Airan Limited_2021-07-17.csv',
#  'KICL': 'Kalyani Investment Company Limited_2021-07-17.csv',
#  'ANDHRAPAP': 'ANDHRA PAPER LIMITED_2021-07-17.csv',
#  'KALECONSUL': 'Kale Consultants Limited_2021-07-17.csv',
#  'GLENMARK': 'Glenmark Pharmaceuticals ltd_2021-07-17.csv',
#  'TREEHOUSE': 'Tree House Education & Accessories Limited_2021-07-17.csv',
#  'CONSOFINVT': 'CONSOFINVT_2021-07-17.csv',
#  'LYKALABS': 'Lyka Labs Ltd.,_2021-07-17.csv',
#  'SIRCA': 'SIRCA_2021-07-17.csv',
#  'ALKEM': 'Alkem Laboratories Limited_2021-07-17.csv',
#  'BIRLACORPN': 'Birla Corporation Ltd._2021-07-17.csv',
#  'ENDURANCE': 'Endurance Technologies Limited_2021-07-17.csv',
#  'UFLEX': 'Uflex Limited_2021-07-17.csv',
#  'FLEXITUFF': 'FLEXITUFF VENTURES INTERNATIONAL LIMITED_2021-07-17.csv',
#  'HINDZINC': 'Hindustan Zinc Ltd.,_2021-07-17.csv',
#  'ORICONENT': 'ORICONENT_2021-07-17.csv',
#  'CHEMCON': 'Chemcon Speciality Chemicals Limited_2021-07-17.csv',
#  'INGERRAND': 'Ingersoll-Rand (India) Ltd._2021-07-17.csv',
#  'DNAMEDIA': 'Diligent Media Corporation Limited_2021-07-17.csv',
#  'SUPREMEIND': 'Supreme Industries Ltd.,_2021-07-17.csv',
#  'VOLTAS': 'Voltas Ltd.,_2021-07-17.csv',
#  'RBLBANK': 'RBL Bank Limited_2021-07-17.csv',
#  'MAHESHWARI': 'MAHESHWARI_2021-07-17.csv',
#  'PFOCUS': 'Prime Focus Limited_2021-07-17.csv',
#  'SPICEJET': 'SpiceJet Limited_2021-07-17.csv',
#  'INOXLEISUR': 'Inox Leisure Limited_2021-07-17.csv',
#  'MALUPAPER': 'Malu Paper Mills Limited_2021-07-17.csv',
#  'SETFGOLD': 'SETFGOLD_2021-07-17.csv',
#  'KRIDHANINF': 'Kridhan Infra Limited_2021-07-17.csv',
#  'MERCK': 'Merck Limited_2021-07-17.csv',
#  'MASFIN': 'MAS Financial Services Limited_2021-07-17.csv',
#  'VERTOZ': 'VERTOZ_2021-07-17.csv',
#  'INOXWIND': 'Inox Wind Limited_2021-07-17.csv',
#  'DEEPENR': 'DEEP ENERGY RESOURCES LIMITED_2021-07-17.csv',
#  'SUNCLAYLTD': 'Sundaram Clayton Ltd._2021-07-17.csv',
#  'NCC': 'NCC Limited_2021-07-17.csv',
#  'SUMICHEM': 'SUMITOMO CHEMICAL INDIA LIMITED_2021-07-17.csv',
#  'ANANTRAJ': 'Anant Raj Limited_2021-07-17.csv',
#  'MCLEODRUSS': 'McLeod Russel India Limited_2021-07-17.csv',
#  'TMRVL': 'The Mandhana Retail Ventures Limited_2021-07-17.csv',
#  'SOBHA': 'Sobha Limited_2021-07-17.csv',
#  'ABBOTINDIA': 'Abbott India Ltd._2021-07-17.csv',
#  'GVKPIL': 'GVK Power & Infrastructure Limited_2021-07-17.csv',
#  'COLPAL': 'Colgate-Palmolive (India) Ltd.,_2021-07-17.csv',
#  'SMSLIFE': 'SMS Lifesciences India Ltd_2021-07-17.csv',
#  'INFIBEAM': 'INFIBEAM AVENUES LIMITED_2021-07-17.csv',
#  'MINDAIND': 'Minda Industries Ltd._2021-07-17.csv',
#  'SSWL': 'Steel Strips & Wheels Ltd_2021-07-17.csv',
#  'AVTNPL': 'AVT Natural Products Ltd._2021-07-17.csv',
#  'ORCHPHARMA': 'Orchid Pharma Limited_2021-07-17.csv',
#  'IMFA': 'Indian Metals & Ferro Alloys Limited_2021-07-17.csv',
#  'BKMINDST': 'BKM INDUSTRIES LIMITED_2021-07-17.csv',
#  'AAKASH': 'AAKASH_2021-07-17.csv',
#  'GIPCL': 'Gujarat Industries Power Co. Ltd_2021-07-17.csv',
#  'ACCURACY': 'ACCURACY_2021-07-17.csv',
#  'KIOCL': 'KIOCL Limited_2021-07-17.csv',
#  'HORIZONINF': 'Horizon Infrastructure Limited_2021-07-17.csv',
#  'SARLAPOLY': 'Sarla Performance Fibers Ltd_2021-07-17.csv',
#  'NDL': 'Nandan Denim Limited_2021-07-17.csv',
#  'AEGISCHEM': 'AEGISCHEM_2021-07-17.csv',
#  'BROOKS': 'BROOKS LABORATORIES LIMITED_2021-07-17.csv',
#  'LXCHEM': 'Laxmi Organic Industries Limited_2021-07-17.csv',
#  'ROML': 'ROML_2021-07-17.csv',
#  'ANKITMETAL': 'Ankit Metal  & Power Limited_2021-07-17.csv',
#  'SCHAND': 'S Chand And Company Limited_2021-07-17.csv',
#  'VIPCLOTHNG': 'VIP Clothing Limited_2021-07-17.csv',
#  'SANDHAR': 'Sandhar Technologies Limited_2021-07-17.csv',
#  'TAJGVK': 'Taj GVK Hotels & Resorts Ltd._2021-07-17.csv',
#  'WELPROJ': 'Welspun Projects Limited_2021-07-17.csv',
#  'GATI': 'Gati Limited_2021-07-17.csv',
#  'SBIN': 'State Bank Of India,_2021-07-17.csv',
#  'JMFINANCIL': 'JM Financial Limited_2021-07-17.csv',
#  'PREMIER': 'Premier Limited_2021-07-17.csv',
#  'RTNINDIA': 'RATTANINDIA ENTERPRISES LIMITED_2021-07-17.csv',
#  'GRAVITA': 'GRAVITA INDIA LIMITED_2021-07-17.csv',
#  'TVTODAY': 'T.V.Today Network Limited_2021-07-17.csv',
#  'HOVS': 'HOV Services Limited_2021-07-17.csv',
#  'ALEMBICLTD': 'Alembic  Ltd_2021-07-17.csv',
#  'VENKEYS': 'VENKEYS_2021-07-17.csv',
#  'KARURVYSYA': 'Karur Vysya Bank Ltd._2021-07-17.csv',
#  'GALLANTT': 'Gallantt Metal Limited_2021-07-17.csv',
#  'DHANUKA': 'Dhanuka Agritech Ltd._2021-07-17.csv',
#  'MADHUCON': 'Madhucon Projects Ltd._2021-07-17.csv',
#  'MBSWITCH': 'M AND B Switchgears Limited_2021-07-17.csv',
#  'RAYMOND': 'Raymond Limited_2021-07-17.csv',
#  'AHLWEST': 'Asian Hotels (West) Ltd_2021-07-17.csv',
#  'GULFOILLUB': 'Gulf Oil Lubricants India Limited_2021-07-17.csv',
#  'ENKEI': 'Enkei Castalloy Limited_2021-07-17.csv',
#  'AGCNET': 'AGC Networks Limited_2021-07-17.csv',
#  'NATIONALUM': 'National Aluminium Co. Ltd.,_2021-07-17.csv',
#  'AHLADA': 'AHLADA_2021-07-17.csv',
#  'EUROMULTI': 'Euro Multivision Limited_2021-07-17.csv',
#  'SHREYANIND': 'Shreyans Industries Limited.,_2021-07-17.csv',
#  'PRIVISCL': 'PRIVI SPECIALITY CHEMICALS LIMITED_2021-07-17.csv',
#  'MUNJALSHOW': 'Munjal Showa Ltd.,_2021-07-17.csv',
#  'JSWISPL': 'JSW ISPAT SPECIAL PRODUCTS LIMITED_2021-07-17.csv',
#  'RELINFRA': 'Reliance Infrastructure Ltd_2021-07-17.csv',
#  'MOM100': 'Motilal Oswal Mutual Fund_2021-07-17.csv',
#  'ADANIPOWER': 'Adani Power Limited_2021-07-17.csv',
#  'IEX': 'Indian Energy Exchange Limited_2021-07-17.csv',
#  'CSBBANK': 'CSB Bank Limited_2021-07-17.csv',
#  'NETF': 'NETF_2021-07-17.csv',
#  'DCAL': 'Dishman Carbogen Amcis Limited_2021-07-17.csv',
#  'BORORENEW': 'BOROSIL RENEWABLES LIMITED_2021-07-17.csv',
#  'GAYAHWS': 'GAYATRI HIGHWAYS LTD_2021-07-17.csv',
#  'RAMCOIND': 'Ramco Industries Ltd_2021-07-17.csv',
#  'DANGEE': 'Dangee Dums Limited_2021-07-17.csv',
#  'TTKPRESTIG': 'TTK Prestige Ltd._2021-07-17.csv',
#  'INDIAGLYCO': 'India Glycols Ltd_2021-07-17.csv',
#  'MANAKSTEEL': 'MANAKSTEEL_2021-07-17.csv',
#  'MAXVIL': 'Max Ventures and Industries Limited_2021-07-17.csv',
#  'AUTOLITIND': 'Autolite (India) Limited_2021-07-17.csv',
#  'CLEDUCATE': 'CL Educate Limited_2021-07-17.csv',
#  'SALSTEEL': 'S.A.L. Steel Ltd._2021-07-17.csv',
#  'MERCATOR': 'Mercator Limited_2021-07-17.csv',
#  'LAOPALA': 'La Opala RG Ltd._2021-07-17.csv',
#  'ORIENTREF': 'Orient Refractories Ltd._2021-07-17.csv',
#  'GENESYS': 'Genesys International Corporation Ltd._2021-07-17.csv',
#  'GPTINFRA': 'GPT Infraprojects limited_2021-07-17.csv',
#  'NETFNIF100': 'Nippon India Mutual Fund_2021-07-17.csv',
#  'GARWALLROP': 'Garware Wall Ropes Limited_2021-07-17.csv',
#  'SETF10GILT': 'SETF10GILT_2021-07-17.csv',
#  'SCHNEIDER': 'SCHNEIDER ELECTRIC INFRASTRUCTURE LIMITED_2021-07-17.csv',
#  'LALPATHLAB': 'Dr. Lal Pathlabs Limited_2021-07-17.csv',
#  'SAKAR': 'SAKAR_2021-07-17.csv',
#  'PATSPINLTD': 'Patspin India Ltd._2021-07-17.csv',
#  'HINDPETRO': 'Hindustan Petroleum Corporation Ltd_2021-07-17.csv',
#  'NITIRAJ': 'NITIRAJ_2021-07-17.csv',
#  'DPTL': 'Dhunseri Petrochem & Tea Limited_2021-07-17.csv',
#  'TGBHOTELS': 'TGB Banquets and Hotels Limited_2021-07-17.csv',
#  'BATAINDIA': 'Bata India Limited_2021-07-17.csv',
#  'COROMANDEL': 'Coromandel International Limited_2021-07-17.csv',
#  'SPYL': 'Shekhawati Poly-Yarn Limited_2021-07-17.csv',
#  'DELTACORP': 'Delta Corp Limited_2021-07-17.csv',
#  'GMDCLTD': 'Gujarat Mineral Development Corpora_2021-07-17.csv',
#  'CHOLAFIN': 'Cholamandalam Investment and Finance Company Ltd_2021-07-17.csv',
#  'ASPINWALL': 'ASPINWALL_2021-07-17.csv',
#  'MAYURUNIQ': 'Mayur Uniquoters ltd._2021-07-17.csv',
#  'CEBBCO': 'COMMERCIAL ENGINEERS & BODY BUILDERS CO. LIMITED_2021-07-17.csv',
#  'BHAGYAPROP': 'Bhagyanagar Properties Ltd_2021-07-17.csv',
#  'SRF': 'SRF Ltd.,_2021-07-17.csv',
#  'KEC': 'KEC International Ltd._2021-07-17.csv',
#  'HBLPOWER': 'HBL Power Systems Ltd._2021-07-17.csv',
#  'BBL': 'Bharat Bijlee Ltd.,_2021-07-17.csv',
#  'NIPPOBATRY': 'Indo National Limited_2021-07-17.csv',
#  'JYOTHYLAB': 'JYOTHY LABS LIMITED_2021-07-17.csv',
#  'CAREERP': 'Career Point Limited_2021-07-17.csv',
#  ...}

# %%
class AnalyseStocks:
    def __init__(self, data_path:str = './data'):
        '''
        args:
            path: Path where all the stock files are saved
        '''
        self.path = data_path
        self.eligible = {}
        
        with open('./names/all_stocks.json') as f:
            self.all_stocks = json.load(f)
   

    def _get_all_stocks(self):
        '''
        Get all the names of stocks and dictonary of filenames by their ID given by NSE
        args:
            path: PAth where all the stock files are saved
        out: Dictonary of {NSE_ID: Name_of_file}
        '''
        
        for f in listdir(self.path):
            if isfile(join(self.path, f)):
                split = f.split('_')
                self.all_stocks[split[0]] = split[1]+'_'+split[2]
                      
        
    def open_stock(self,name:str):
        '''
        Open the Individual stock based on it's Official Term
        args:
            name: Name / ID given to the stock. Example, Infosys is "INFY"
        returns: DataFrame of that stock
        '''
        return pd.read_csv(join(self.path,name+'_'+self.all_stocks[name]))
    

    def is_eligible(self, df, mv = 44, names:tuple = ('DATE','OPEN','CLOSE','LOW','HIGH')):
        '''
        Find the Positive Stocks which are about to rise on the Moving average line
        args:
            df: DataFrame
            mv: Moving Average to Consider
            names: Tuple of column names showing ('DATE','OPEN','CLOSE','LOW','HIGH')
        '''
        Date, Open, Close, Low, High = names
        Average = f'{str(mv)}-SMA'
        stocks = df.sort_index(ascending=False, )
        stocks[Average] = stocks[Close].rolling(mv, min_periods = 1).mean()
        
#         val = stocks.iloc[-1,:].values
#         if (val[5] > val [1]) and (0 <= (val[3] - val[-1]) <= val[5] - val[1]):
#             self.eligible[val[-2]] = round(val[3] - val[-1],2)
        
        last_traded = stocks.iloc[-1,:].values
        if (last_traded[Close] > last_traded[Open]) and (last_traded[Open] > last_traded[Average]) and (0 <= (last_traded[Low] - last_traded[Average]) <= last_traded[Close] - last_traded[Open]):
            self.eligible[last_traded['SYMBOL']] = round(last_traded[Low] - last_traded[Average],2)
            
            
            return self.eligible 
        return False
    
    
    def save_new_eligible_for_week(self):
        '''
        Save all Eligible stocks for the current week
        '''
        for key in self.all_stocks.keys():
            self.is_eligible(self.open_stock(key))

        eligible = {k: v for k, v in sorted(AS.eligible.items(), key=lambda item: item[1])}
        with open(f'./week_by_week_eligible/{str(x)}.json', 'w') as f:
            json.dump(eligible,f)
        
        return eligible
    
    
    def get_recent_eligible(self, path = './week_by_week_eligible/'):
        '''
        Get Most Recent Stocks updated
        path: Path of json file 
        '''
        files = []
        for f in listdir(path):
            if isfile(join(path, f)):
                files.append(join(path,f))
        files.sort()
        eligible = files[0]
        delta = date.today() - date.fromisoformat(eligible.split('/')[-1].split('.')[0])
        
        if delta.days >= 10:
            warnings.warn('This dats is older than 10 days. Please fetch a new Data')
        
        else:    
            with open(eligible) as f:
                eligible = json.load(f)
            return eligible
            
    
    
    def plot_candlesticks(self,df, names = ('DATE','OPEN','CLOSE','LOW','HIGH'), mv = 44):
        '''
        Plot a candlestick on a given dataframe
        args:
            df: DataFrame
            names: Tuple of column names showing ('DATE','OPEN','CLOSE','LOW','HIGH')
            mv: Moving Average
        '''
        stocks = df.copy()
        Date, Open, Close, Low, High = names
        
        if not f'{str(mv)}-SMA' in stocks.columns:
            stocks.sort_index(ascending=False, inplace = True)
            stocks[f'{str(mv)}-SMA'] = stocks[Close].rolling(mv, min_periods = 1).mean()

        candle = go.Figure(data = [go.Candlestick(x = stocks[Date], name = 'Trade',
                                                       open = stocks[Open], 
                                                       high = stocks[High], 
                                                       low = stocks[Low], 
                                                       close = stocks[Close]),

                                  go.Scatter(name=f'{str(mv)} MA',x=stocks[Date], y=stocks[f'{str(mv)}-SMA'], 
                                             line=dict(color='blue', width=1)),])

        candle.update_xaxes(
            title_text = 'Date',
            rangeslider_visible = True,
            rangeselector = dict(
                buttons = list([
                    dict(count = 1, label = '1M', step = 'month', stepmode = 'backward'),
                    dict(count = 6, label = '6M', step = 'month', stepmode = 'backward'),
                    dict(count = 1, label = 'YTD', step = 'year', stepmode = 'todate'),
                    dict(count = 1, label = '1Y', step = 'year', stepmode = 'backward'),
                    dict(step = 'all')])))

        candle.update_layout(autosize = True,
                             title = {'text': f"{stocks['SYMBOL'][0]} | {all_stocks[stocks['SYMBOL'][0]]}",'y':0.97,'x':0.5,
                                      'xanchor': 'center','yanchor': 'top'},
                             margin=dict(l=30,r=30,b=30,t=30,pad=2),
                             paper_bgcolor="lightsteelblue",)

        candle.update_yaxes(title_text = 'Price in Rupees', tickprefix = u"\u20B9" ) # Rupee symbol
        candle.show()

# %%
if (last_traded[Close] > last_traded[Open]) and (last_traded[Open] > last_traded[Average]) and (0 <= (last_traded[Low] - last_traded[Average]) <= last_traded[Close] - last_traded[Open]):
            self.eligible[last_traded['SYMBOL']] = round(last_traded[Low] - last_traded[Average],2)
        
if (val[5] > val [1]) and (0 <= (val[3] - val[-1]) <= val[5] - val[1]):
            self.eligible[val[-2]] = round(val[3] - val[-1],2)

# %%
AS.open_stock('MRF')
# Out:
#            DATE      OPEN      HIGH       LOW      LTP     CLOSE SYMBOL
# 0    2021-07-16  81950.00  82710.00  81354.90  82184.4  82449.85    MRF
# 1    2021-07-15  82806.00  83254.95  81116.00  81400.0  81445.20    MRF
# 2    2021-07-14  83000.00  83356.95  82380.60  82700.0  82806.05    MRF
# 3    2021-07-13  80439.95  83450.00  80001.10  83300.0  83115.80    MRF
# 4    2021-07-12  80300.00  80480.20  79880.00  80189.2  80187.10    MRF
# ..          ...       ...       ...       ...      ...       ...    ...
# 246  2020-07-23  64793.55  64793.55  63100.00  63400.0  63357.35    MRF
# 247  2020-07-22  65590.00  65590.00  64255.80  64498.0  64407.75    MRF
# 248  2020-07-21  65800.00  65900.00  65250.25  65522.0  65621.10    MRF
# 249  2020-07-20  65500.00  65849.50  64720.10  65150.0  65042.80    MRF
# 250  2020-07-17  63998.95  65870.85  63382.70  65800.0  65360.55    MRF
#
# [251 rows x 7 columns]

# %%
AS = AnalyseStocks()
AS.get_recent_eligible()
# Out:
# {'KHANDSE': 0.15,
#  'ITC': 0.2,
#  'ORIENTALTL': 0.4,
#  'TIRUPATIFL': 0.55,
#  'MOTHERSUMI': 0.7,
#  '3PLAND': 0.75,
#  'UNICHEMLAB': 0.85,
#  'MUNJALAU': 0.85,
#  'AARVEEDEN': 1.0,
#  'KEYFINSERV': 1.1,
#  'KOTHARIPET': 1.15,
#  'MOTOGENFIN': 1.35,
#  'SILGO': 1.5,
#  'STERTOOLS': 1.65,
#  'BALAJITELE': 2.15,
#  'THEINVEST': 2.2,
#  'UNIDT': 2.7,
#  'BPL': 3.05,
#  'DBL': 3.15,
#  'HMVL': 3.2,
#  'GIPCL': 4.05,
#  'ADVANIHOTR': 4.1,
#  'SATIN': 4.4,
#  'SEYAIND': 4.7,
#  'HINDOILEXP': 4.95,
#  'ABSLBANETF': 5.3,
#  'VADILALIND': 5.7,
#  'SUNDARMHLD': 5.8,
#  'PRECWIRE': 5.85,
#  'MANINDS': 5.9,
#  'DFMFOODS': 6.8,
#  'LUMAXTECH': 7.2,
#  'IOLCP': 7.35,
#  'SMSPHARMA': 7.55,
#  'INDSWFTLAB': 9.25,
#  'JINDRILL': 10.3,
#  'KSL': 11.1,
#  'SEQUENT': 12.15,
#  'SRHHYPOLTD': 13.45,
#  'HARITASEAT': 15.55,
#  'ASPINWALL': 15.8,
#  'GSPL': 16.8,
#  'BORORENEW': 18.75,
#  'ORIENTELEC': 20.95,
#  'HAVELLS': 30.65,
#  'GLENMARK': 31.2,
#  'GLAXO': 32.35,
#  'OCCL': 34.35,
#  'SHAREINDIA': 43.25,
#  'UBL': 47.9,
#  'ANUP': 70.95,
#  'TCIEXP': 96.95,
#  'CYIENT': 115.6,
#  'GILLETTE': 170.4,
#  'SUNCLAYLTD': 219.1}

# %%
# s = list(s)
AS.plot_candlesticks(AS.open_stock(s[54]))
# Out:
# <div>                            <div id="758f34ad-30c3-4258-ac35-adb71d3f5f8e" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("758f34ad-30c3-4258-ac35-adb71d3f5f8e")) {                    Plotly.newPlot(                        "758f34ad-30c3-4258-ac35-adb71d3f5f8e",                        [{"close":[1618.1,1624.0,1627.95,1598.65,1601.85,1604.35,1578.85,1585.6,1597.5,1579.35,1557.3,1552.7,1583.95,1554.0,1554.55,1581.05,1670.9,1647.45,1610.1,1662.95,1639.25,1686.25,1705.05,1763.0,1788.5,1816.65,1887.75,1867.6,1887.15,1860.55,1807.1,1735.6,1698.9,1715.65,1731.15,1705.3,1703.2,1716.45,1707.4,1659.95,1648.2,1700.5,1707.85,1722.05,1694.5,1668.65,1628.75,1622.85,1623.4,1608.85,1629.95,1668.4,1639.6,1626.65,1649.95,1656.5,1648.9,1629.75,1595.2,1657.05,1676.4,1671.7,1669.65,1663.2,1668.5,1670.85,1664.75,1633.8,1620.85,1658.9,1625.3,1645.5,1651.15,1631.45,1681.75,1700.25,1667.45,1664.75,1711.3,1660.85,1666.25,1668.3,1665.35,1599.0,1612.7,1636.1,1672.95,1766.5,1757.95,1749.0,1721.05,1767.85,1730.55,1760.55,1814.9,1895.6,1994.2,2206.55,2105.7,2025.4,2071.35,2069.15,2033.75,2183.55,2200.8,2512.7,2664.9,2661.4,2678.8,2652.85,2593.25,2630.85,2660.25,2641.95,2659.8,2618.35,2658.55,2649.5,2652.2,2673.6,2685.8,2693.6,2640.8,2650.3,2666.4,2660.45,2666.8,2652.75,2653.2,2673.85,2699.85,2958.7,3218.95,3367.65,3138.35,3166.7,3202.2,3617.7,3796.0,3684.7,3619.55,3719.0,3765.5,3825.4,3781.55,3775.6,3768.75,3669.1,3571.8,3585.0,3586.0,3569.9,3548.35,3470.2,3501.2,3544.8,3539.55,3563.65,3564.2,3520.75,3485.65,3487.9,3426.75,3371.15,3362.65,3326.6,3223.9,3264.55,3138.15,3114.7,3125.9,3131.7,3131.9,3189.1,3075.85,3020.3,3100.05,3081.3,3060.4,3099.9,3221.3,3157.85,3211.9,3170.75,2944.95,3118.05,2989.5,3001.0,2871.95,2878.6,2975.05,2996.35,2997.75,3002.75,3281.7,3189.3,3127.75,3138.45,3088.25,3100.0,3116.3,3187.85,3291.9,3147.95,3150.45,3103.05,3099.75,3061.85,3081.6,3101.05,3188.9,3169.45,3215.35,3241.85,3436.75,3450.75,3540.9,3566.9,3667.65,3702.9,3608.25,3865.7,3773.15,3741.7,3620.1,3585.5,3551.35,3524.25,3481.15,3480.3,3467.4,3425.6,3397.7,3404.95,3364.5,3479.15,3504.3,3439.15,3443.7,3416.1,3400.0,3431.15,3410.7,3390.15,3416.5,3438.4,3479.5,3691.15,3716.6,3590.65,3884.1],"high":[1625.0,1630.0,1644.65,1635.95,1616.0,1620.0,1604.3,1595.0,1608.95,1619.0,1586.55,1570.15,1605.95,1639.6,1575.0,1589.9,1699.0,1700.0,1655.1,1740.0,1699.0,1699.0,1718.0,1858.5,1800.0,1848.0,1900.0,1910.95,1909.0,1906.0,1875.0,1829.55,1844.0,1740.0,1773.2,1772.35,1744.0,1775.0,1730.0,1729.95,1698.7,1724.0,1730.0,1735.2,1736.65,1719.0,1690.0,1674.95,1662.0,1648.45,1650.0,1688.65,1688.4,1682.4,1674.4,1677.05,1674.0,1662.75,1665.0,1698.0,1683.9,1690.0,1689.0,1672.35,1680.0,1681.3,1683.5,1680.0,1687.8,1688.95,1669.65,1659.0,1660.0,1642.15,1730.0,1717.0,1695.0,1696.65,1773.85,1800.0,1709.0,1685.0,1679.7,1720.0,1663.0,1654.75,1678.0,1786.0,1848.0,1790.0,1764.9,1849.0,1840.0,1771.2,1829.85,1900.0,2036.75,2239.95,2250.0,2190.0,2085.0,2120.0,2098.95,2280.0,2350.0,2590.0,2700.0,2770.0,2775.75,2740.0,2648.4,2750.0,2700.1,2744.0,2680.05,2693.9,2665.0,2679.55,2688.8,2688.8,2717.0,2799.0,2789.8,2675.15,2686.65,2682.0,2673.95,2691.7,2680.0,2727.65,2726.95,3180.0,3255.0,3479.8,3449.0,3286.0,3390.0,3824.8,3890.0,3792.25,3765.0,3756.0,3900.0,3848.0,3906.1,3809.65,3800.0,3844.0,3739.75,3601.0,3627.25,3665.8,3688.8,3599.0,3575.0,3553.0,3678.0,3588.0,3600.05,3670.0,3568.75,3650.0,3581.2,3465.5,3427.75,3425.85,3376.95,3296.0,3279.3,3267.0,3162.15,3164.65,3165.0,3219.75,3219.95,3151.1,3144.05,3100.0,3120.05,3135.0,3344.95,3204.0,3245.0,3262.95,3152.8,3190.0,3122.6,3035.0,2978.0,2985.0,3000.0,3010.0,3068.0,3045.0,3603.3,3375.0,3200.0,3160.05,3200.0,3147.95,3155.0,3204.0,3315.4,3300.0,3278.05,3178.2,3195.0,3250.0,3119.15,3131.95,3220.0,3218.3,3248.95,3317.4,3541.0,3518.2, ...

# %% [markdown]
# # MPL

# %%
df = stocks.copy()
df.sort_index(ascending=False, inplace = True)
df['44-SMA'] = df['PREV. CLOSE'].rolling(44, min_periods = 1).mean()

df1 = df.copy()
df1.set_index('DATE',drop=True,inplace=True)
df1.rename(columns={'OPEN':'Open','HIGH':'High','LOW':'Low', 'PREV. CLOSE':'Close', 'VOLUME':'Volume'},inplace=True)

fplt.plot(df1,type='candle', style='charles', title=df['SYMBOL'][0], ylabel='Price (RS.)', volume=True, ylabel_lower='Shares\nTraded', 
          show_nontrading=True,mav=44,figscale=1.5,)

# %%
current_date = date.today()

not_suit = []
suit = []
for i in uni:
    try:
        stock_df(symbol=i, from_date = current_date - timedelta(days = 1), to_date = current_date, series="EQ")
        suit.append(i)
    except:
        not_suit.append(i)

# %%
len(suit), len(not_suit)

# %% [markdown]
# # Code

# %%
class Investing:
    def __init__(self, loss_capacity, profit_greed, rolling_mean=44):
        self.risk = loss_capacity # per share
        self.profit = profit_greed
        self.rm = rolling_mean
        
    def find_eligible_stocks(self):
        '''
        Find all shares which are on the gaining edge of rolling mean
        '''
        pass
    
    def get_purchase_history():
        '''
        Get shares already purchased for the 10 days period
        '''
        pass
    
    def formula(self):
        '''
        1:2 trading
        ENTRY = LAST Day MAX + Delta
        StopLoss = Min of the last 2 DAY_MIN
        ENTRY - StopLoss
        
        '''
        entry = last_day_highest + delta
        diff = abs(Entry - min([last,second_last]))
        total_stocks = int(self.risk / diff)
        target = entry + (diff * 2)

# %%
stock_df(symbol='SBIN', from_date = current_date - timedelta(days = 365), to_date = current_date, series="EQ")
# Out:
#           DATE SERIES    OPEN    HIGH     LOW  PREV. CLOSE     LTP   CLOSE  \
# 0   2021-07-16     EQ  432.00  432.50  427.45       431.70  430.60  430.00
# 1   2021-07-15     EQ  432.70  432.95  429.65       431.05  431.65  431.70
# 2   2021-07-14     EQ  429.00  432.30  426.40       429.10  431.20  431.05
# 3   2021-07-13     EQ  430.00  431.80  428.30       427.45  428.85  429.10
# 4   2021-07-12     EQ  426.50  430.25  424.60       423.75  427.60  427.45
# ..         ...    ...     ...     ...     ...          ...     ...     ...
# 247 2020-07-22     EQ  195.70  196.75  190.10       194.40  192.15  192.00
# 248 2020-07-21     EQ  192.45  196.20  191.50       190.75  194.50  194.40
# 249 2020-07-20     EQ  190.00  193.25  188.75       188.20  190.55  190.75
# 250 2020-07-17     EQ  186.80  189.50  185.00       186.25  189.50  188.20
# 251 2020-07-16     EQ  185.00  186.95  181.65       183.80  186.00  186.25
#
#        VWAP   52W H   52W L    VOLUME         VALUE  NO OF TRADES SYMBOL
# 0    429.67  441.95  175.50   8713863  3.744069e+09         86998   SBIN
# 1    431.53  441.95  175.50  11030732  4.760107e+09        126999   SBIN
# 2    429.74  441.95  175.50  12767351  5.486703e+09        157944   SBIN
# 3    429.95  441.95  175.50  12831125  5.516711e+09        116776   SBIN
# 4    427.88  441.95  175.50  12886781  5.513982e+09        130234   SBIN
# ..      ...     ...     ...       ...           ...           ...    ...
# 247  192.70  359.55  149.45  62276770  1.200100e+10        265443   SBIN
# 248  194.00  359.55  149.45  59286092  1.150176e+10        274154   SBIN
# 249  191.29  359.55  149.45  45680606  8.738356e+09        232252   SBIN
# 250  186.87  373.80  149.45  47035751  8.789710e+09        214673   SBIN
# 251  184.69  373.80  149.45  46549518  8.597017e+09        222270   SBIN
#
# [252 rows x 15 columns]
