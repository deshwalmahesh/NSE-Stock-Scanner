# %%
'065676'
# Out:
# '065676'

# %% [markdown]
# # Imports

# %%
import backtrader
from helpers.datahandler import *
from helpers.investing import *
from helpers.journal_handler import *

# %% [markdown]
# # Defaults

# %%
pd.set_option('display.max_rows', 100)



In = Investing()

private_key = join(expanduser('~'),'Documents','client_secret.json')
JH = JournalHandler(private_key)

journal = JH.get_journal('Finance Journal')
# Out:
# ---------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------

# %% [markdown]
# # Work

# %%
budget = 3000

df = In.get_recent_info(nifty = 100, **{'mvs':[20,50,100,200]})
df = df[(df['Overbought'] == False) & (df['Ichi Count'] > 0) & 
        (df['Over 50-SMA'] == True) & (df['Over 100-SMA'] == True) & (df['Over 200-SMA'] == True) &
       (df['Momentum ADX'] > 25) & 
        (df['LTP'] <= budget)]

df
# Out:
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
#          Date        Name      Index  Over 20-SMA  Over 50-SMA  Over 100-SMA  \
# 1  2021-08-05  ABBOTINDIA  Nifty 100         True         True          True
# 3  2021-06-08  ADANIGREEN  Nifty 100         True         True          True
# 6  2021-08-05       ALKEM  Nifty 100         True         True          True
# 15 2021-08-05  BAJAJFINSV   Nifty 50         True         True          True
# 16 2021-08-05  BAJAJHLDNG  Nifty 100         True         True          True
# 18 2021-08-05  BERGEPAINT  Nifty 100        False         True          True
# 28 2021-08-05         DLF  Nifty 100         True         True          True
# 29 2021-08-05       DABUR  Nifty 100        False         True          True
# 30 2021-08-05    DIVISLAB   Nifty 50         True         True          True
# 34 2021-08-05       GLAND  Nifty 100         True         True          True
# 35 2021-08-05    GODREJCP  Nifty 100         True         True          True
# 37 2021-08-05     HCLTECH   Nifty 50         True         True          True
# 43 2021-08-05    HINDALCO   Nifty 50         True         True          True
# 49 2021-08-05  ICICIPRULI  Nifty 100         True         True          True
# 59 2021-08-05    JUBLFOOD  Nifty 100         True         True          True
# 62 2021-08-05          LT   Nifty 50         True         True          True
# 66 2021-08-05      MARICO  Nifty 100        False         True          True
# 68 2021-08-05  MUTHOOTFIN  Nifty 100         True         True          True
# 71 2021-08-05   NESTLEIND   Nifty 50         True         True          True
# 74 2021-08-05  PIDILITIND  Nifty 100        False         True          True
# 92 2021-08-05  TORNTPHARM  Nifty 100         True         True          True
# 94 2021-08-05  ULTRACEMCO   Nifty 50         True         True          True
# 95 2021-08-05         UBL  Nifty 100         True         True          True
# 98 2021-08-05       WIPRO   Nifty 50         True         True          True
#
#     Over 200-SMA  Overbought  Oversold  Momentum ADX  Ichi Count  \
# 1           True       False     False     53.190041           2
# 3           True       False     False     26.176970           2
# 6           True       False     False     35.559301           2
# 15          True       False     False     45.574360           2
# 16          True       False     False     35.445399           2
# 18          True       False     False     27.393756           2
# 28          True       False     False     32.080216           2
# 29          True       False     False     30.430866           2
# 30          True       False     False     48.660560           2
# 34          True       False     False     46.188277           2
# 35          True       False     False     44.867028           2
# 37          True       False     False     28.912083           2
# 43          True       False     False     34.265195           2
# 49          True       False     False     34.017470           2
# 59          True       False     False     41.204842           2
# 62          True       False     False     26.991227           2
# 66          True       False     False     42.196571           1
# 68          True       False     False     34.506615           2
# 71          True       False     False     29.243732           2
# 74          True       False     False     38.219515           2
# 92          True       False     False     38.210093           2
# 94          True       False     False     45.543830           2
# 95          True       False     False     36.657224           1
# 98          True       False     False     36.183237           2
#
#            1 Candle          2 Candles          3 Candles
# 1          Red Doji            Unknown            Unknown
# 3       Unknown Red            Unknown            Unknown
# 6     Shooting Star            Unknown            Unknown
# 15      Unknown Red            Unknown            Unknown
# 16         Red Doji            Unknown            Unknown
# 18      Unknown Red            Unknown            Unknown
# 28         Red Doji            Unknown            Unknown
# 29      Unknown Red            Unknown            Unknown
# 30      Unknown Red            Unknown  Reverse V Pattern
# 34    Unknown Green  Bullish Engulfing            Unknown
# 35      Unknown Red            Unknown            Unknown
# 37    Unknown Green            Unknown            Unknown
# 43      Unknown Red            Unknown  Reverse V Pattern
# 49      Unknown Red  Bearish Engulfing  Reverse V Pattern
# 59          Bearish            Unknown            Unknown
# 62    Unknown Green            Unknown  Reverse V Pattern
# 66      Unknown Red            Unknown            Unknown
# 68      Unknown Red            Unknown  Reverse V Pattern
# 71       Green Doji            Unknown            Unknown
# 74      Unknown Red            Unknown            Unknown
# 92      Unknown Red            Unknown            Unknown
# 94      Unknown Red            Unknown  Reverse V Pattern
# 95      Unknown Red            Unknown            Unknown
# 98  Inverted Hammer            Unknown            Unknown

# %%
df = In.show_full_stats(10000,100, diff = None, nifty='nifty_50')

df = df[(df['Expected Change %'] <=15) & (df['RSI']<70) & (df['Ichi']>0)]
df
# Out:
# /home/admin1/Desktop/ML Study/Finance/helpers/investing.py:201: UserWarning: You are risking 1.0% of your total PORTFOLIO. Going Like this, you'll lose Rs 1661.7360000000008 in 15 Trades. Try keeping it less than 1.1% @ Rs 110.0.
#   warnings.warn(f"You are risking {round(max_loss/budget,2)*100}% of your total PORTFOLIO. Going Like this, you'll lose Rs {max_loss*15} in 15 Trades. Try keeping it less than 1.1% @ Rs {round(budget*0.011,2)}.")
# /home/admin1/Desktop/ML Study/Finance/helpers/investing.py:217: UserWarning: Risk should be atleast 110.78 for you to afford KOTAKBANK
#   warnings.warn(f"Risk should be atleast {r} for you to afford {name}")
# /home/admin1/Desktop/ML Study/Finance/helpers/investing.py:201: UserWarning: You are risking 1.0% of your total PORTFOLIO. Going Like this, you'll lose Rs 1887.2099999999978 in 15 Trades. Try keeping it less than 1.1% @ Rs 110.0.
#   warnings.warn(f"You are risking {round(max_loss/budget,2)*100}% of your total PORTFOLIO. Going Like this, you'll lose Rs {max_loss*15} in 15 Trades. Try keeping it less than 1.1% @ Rs {round(budget*0.011,2)}.")
# /home/admin1/Desktop/ML Study/Finance/helpers/investing.py:217: UserWarning: Risk should be atleast 125.81 for you to afford EICHERMOT
#   warnings.warn(f"Risk should be atleast {r} for you to afford {name}")
#         DATE    OPEN     HIGH     LOW    CLOSE   52W H   52W L    SYMBOL  \
# 0 2021-08-05   208.6   216.75   206.9   215.25   239.2  163.35       ITC
# 8 2021-08-05  1467.1  1507.05  1457.4  1484.85  1641.0  993.00  HDFCBANK
#
#    Diff  Rising  Ichi        RSI        ATR Triple Candle      Double Candle  \
# 0  0.49   False     1  65.246002   4.142857       Unknown  Bullish Engulfing
# 8  3.96   False     1  55.516389  28.242857       Unknown            Unknown
#
#    Recent Candle     Index  Expected Change %  Max Config Risk
# 0  Unknown Green  Nifty 50               9.61            94.37
# 8  Unknown Green  Nifty 50               9.16            69.41
