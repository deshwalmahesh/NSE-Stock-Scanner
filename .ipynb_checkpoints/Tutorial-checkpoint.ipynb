# %% [markdown]
# # <font color='red'>STOCK MARKET IS VERY RISKY UNTIL YOU DO IT PROPERLY. PLEASE DO NOT TAKE TRADES JUST BECAUSE THIS TOOL GIVES YOU THE NAME. APPLY YOUR OWN LEARNINGS, CREATE YOUR OWN STRATEGY, ASSESS RISK & TRADE THE PLAN.</font>

# %%
'065676'
# Out:
# '065676'

# %% [markdown]
# # Imports, Defaults and Initializations
# Clicking on the below cell is mandatory. Click on the cell below and press `Shift + Enter`. To run any cell, use the same keyboard shortcut.

# %%
# import backtrader
from helpers.datahandler import *
from helpers.investing import *
from helpers.journal_handler import *
from helpers.intraday import *
from helpers.nse_data import *
from helpers.backtest import *


pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 25)


In = Investing(check_fresh = True) # Investing or Swing trading analysis
Intra = IntraDay() # Intraday strategies and analysis
ISS = IntradayStockSelection() # helps in stocks selection for Intraday in terms of which stocks you "MIGHT" look at
NSE = NSEData() # Get NSE Live data
MS = MarketSentiment() # Get Live Market Sentiment TICK, TRIN and 52W high/ low stocks
BT = Backtest()

# In.update_new_listings() # Good to run once in a while say after every 1 month
# In.update_fresh_nifty_indices()
# In.update_FnO()
# Out:
# Checking Fresh Data.....

# %%
with open(join(expanduser('~'),'Downloads','Intra.txt')) as f:
    x = f.readlines()[0].split(',')
    x = [a.split(':')[1] for a in x]

    
abc = []
for name in x:
    name = name.replace('_','-')
    if name not in In.data['f&o']:
        print(name)
    else:
        abc.append(name)
abc.append('M&M')
# Out:
# VBL
# NIITLTD
# BDL
# FORTIS
# CEATLTD
# VTL
# M-M

# %%
# m,r,s = ISS.stocks_attributes(abc, 400)

sorted(m.items(),key = lambda x: x[1], reverse = True)
# Out:
# [('FEDERALBNK', 0.01568627450980396),
#  ('HINDALCO', 0.01558497011101625),
#  ('TATAMOTORS', 0.014150943396226355),
#  ('JSWSTEEL', 0.013609850939727868),
#  ('SUNTV', 0.013089005235602094),
#  ('INDIGO', 0.013073855288014606),
#  ('HAL', 0.013033968664910868),
#  ('HINDPETRO', 0.01293759512937601),
#  ('AXISBANK', 0.012757058208434964),
#  ('TATACHEM', 0.012076038597099492),
#  ('VOLTAS', 0.011906378740549676),
#  ('BHARTIARTL', 0.01188528119886311),
#  ('HAVELLS', 0.011668681983071453),
#  ('RAMCOCEM', 0.01145596770123646),
#  ('ICICIBANK', 0.011285417000160003),
#  ('M&M', 0.010683589043296795),
#  ('GRASIM', 0.010600375234521604),
#  ('TECHM', 0.010588793922127342),
#  ('WIPRO', 0.010500190912562048),
#  ('MCDOWELL-N', 0.009142962689324059),
#  ('DABUR', 0.008777788378971516),
#  ('BERGEPAINT', 0.008703866135888328),
#  ('ITC', 0.008697696285848721)]

# %%
with open('F&O.txt','w') as f:
    for name in In.data['f&o']:
        f.write(name+'\n')

# %% [markdown]
# # Journal
# Make a journal in Google Drive for each trade you take to analyse. **It is a not so simple process and need to connect with Google API so if you're not comfortable with it, just skip it**

# %%
private_key = join(expanduser('~'),'Documents','client_secret.json') # Personal for each user. Mine is stored in /home/Documents
JH = JournalHandler(private_key)

journal = JH.get_journal('Finance Journal') # My Google Sheet jornam has name "Finance Journal"

JH.total_pl(journal) # total Profit and Loss up until now
# Out:
# ---------------------------------------------------------------------------
#
# ---------------------------------------------------------------------------
# -1693.15

# %% [markdown]
# # <font color='teal'>Swing Strategies </font>
# # Tweak parameters by reading the Docstring
# ## Basic Details
# Basic Details about stocks such as Momentum, Ichimoku, 1-2-3 candles pattern etc

# %%
budget = 40000

df = In.get_recent_info(nifty = 500, **{'mvs':[20,50,100,200]})
df.head(2) # show first 2 values
# Out:
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
#         Date     Name      LTP      Index CCI Signal RSI Signal MACD Signal  \
# 0 2021-10-11  3MINDIA  25720.0  Nifty 500  No Signal  No Signal   No Signal
# 1 2021-10-11      ABB   1830.6  Nifty 500  No Signal  No Signal   No Signal
#
#    Over 20-SMA  Over 50-SMA  Over 100-SMA  Over 200-SMA  Momentum ADX  \
# 0         True         True          True          True     25.271955
# 1        False         True          True          True     19.421299
#
#    Ichi Count     1 Candle 2 Candles 3 Candles
# 0           2   Green Doji   Unknown   Unknown
# 1           1  Unknown Red   Unknown   Unknown

# %% [markdown]
# ## Breakout
# Stocks that might breakout. Includes only those stocks which are above 50 days SMA, have atleast `n` number of touches within the `p%` of the recent candle. Just look at these stocks manually. Change the parameters to control the number of stocks to scan.

# %%
In.tight_consolidation_stocks(stocks = 'nifty_500', diff = 0.007, min_count = 5, lookback_period = 10) # There should be atleast 5 candles touching the +- 0.75% of the line within 7 days
# Out:
# {'GODREJIND': 8,
#  'RATNAMANI': 8,
#  'RAJESHEXPO': 7,
#  'BHARTIARTL': 6,
#  '3MINDIA': 6,
#  'INOXLEISUR': 6,
#  'TATAMOTORS': 5,
#  'RADICO': 5,
#  'IOC': 5,
#  'UCOBANK': 5,
#  'HINDPETRO': 5,
#  'DLF': 5,
#  'ORIENTELEC': 5,
#  'KSB': 5,
#  'ANURAS': 5,
#  'BAJAJHLDNG': 5}

# %% [markdown]
# ## 44-SMA
# If you find a `Green` candle taking support on 44 days `Simple Moving Average` line and stock is in uptrend, you can take the trade and set Risk to Reward ratio as 1:2

# %%
budget = 40000 # Total Budget
risk = 400 # Risk per trade
df = In.show_full_stats(budget = budget,risk=risk, diff = 150, nifty='nifty_200') # Show only stocks undder your budget and  whose recent candle's lowest is not more than 151 rupees above the moving average line
df[(df['RSI Value'] < 70) & (df['CCI Value'] < 200)]
# Out:
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
# 14      Rising High     0  16.436006            Unknown            Unknown
# 0   Undeterministic     0   6.891401            Unknown            Unknown
# 16  Undeterministic     1  11.774392            Unknown            Unknown
# 17  Undeterministic     1   7.370808            Unknown            Unknown
# 19      Rising High     0   7.628121            Unknown            Unknown
# 11  Undeterministic     0  14.056547            Unknown            Unknown
# 7   Undeterministic     0  58.475666            Unknown            Unknown
# 10  Undeterministic     1  18.090394            Unknown            Unknown
# 20  Undeterministic     0  22.081816            Unknown            Unknown
# 3   Undeterministic     0  12.004664            Unknown            Unknown
# 9   Undeterministic     1  17.750795          V Pattern            Unknown
# 1       Rising High     1  37.168386            Unknown            Unknown
# 8       Rising High     0  42.711006  Reverse V Pattern            Unknown
#
#       Recent Candle      Index  Expected Change %  Max Config Risk
# 6     Unknown Green   Nifty 50              13.94           398.39
# 5     Unknown Green  Nifty 200              10.05           396.31
# 4     Unknown Green  Nifty 200              22.99           386.11
# 18  Inverted Hammer   Nifty 50               7.18           397.90
# 14       Green Doji  Nifty 200              15.58           381.72
# 0        Green Doji   Nifty 50               6.67           398.45
# 16       Green Doji  Nifty 100               7.78           399.25
# 17    Unknown Green  Nifty 200              17.04           392.63
# 19    Unknown Green  Nifty 200              14.03           399.02
# 11    Unknown Green  Nifty 100              18.69           398.72
# 7        Green Doji  Nifty 100              11.09           356.98
# 10       Green Doji  Nifty 100              11.10           396.46
# 20       Green Doji   Nifty 50               8.39           377.73
# 3   Inverted Hammer  Nifty 200              15.10           394.00
# 9     Unknown Green  Nifty 200              18.85           392.42
# 1        Green Doji   Nifty 50               9.02           394.53
# 8     Unknown Green   Nifty 50               6.95           398.21

# %% [markdown]
# ## Golden Crossover
# When 44 days `SMA` Crosses 200 days `SMA` from below and you find a `Green` candle within 15 days taking support on `44` days line set Risk to Reward ratio as 1:5

# %%
for name in In.data['nifty_200']:
    df = In.open_downloaded_stock(name)
    if In.has_golden_crossover(df,lookback=21):
        print(name)
# Out:
# ZEEL
# ITC
# INDUSTOWER
# ESCORTS
# KOTAKBANK

# %% [markdown]
# ## RSI Signal: Oversold / Overbought Stocks
# Buy when RSI is less than 30 sell when greater than 70

# %%
for name in In.data['nifty_500']:
    df = In.open_downloaded_stock(name)
    if In.get_RSI(df,signal_only=True) == "Buy":
        print(name)

# %% [markdown]
# ## MACD Signal
# It is the strategy when MACD (Blue) Line cuts the Signal (Red) line from below then it is a buy signal. When the blue line cuts from upside down, it is sell signal

# %%
for name in In.data['nifty_50']:
    df = In.open_downloaded_stock(name)
    if In.macd_signal(df) == 'Buy':
        print(name)
# Out:
# INFY
# ICICIBANK
# GRASIM
# ADANIPORTS
# DRREDDY
# TATACONSUM
# LT

# %% [markdown]
# ## CCI Signal : Rally
# **Faster than MACD Signal works closely with Stochastic RSI**
#
# When CCI values comes from below  -100 to above -100, buy signal and when it comes from above +100 to below +100, sell signal

# %%
for name in In.data['nifty_500']:
    df = In.open_downloaded_stock(name)
    if In.get_CCI(df, signal_only = True) == 'Buy':
        print((name, In.get_index(name)))
# Out:
# ('HCLTECH', 'Nifty 50')
# ('AIAENG', 'Nifty 500')
# ('CADILAHC', 'Nifty 100')
# ('ULTRACEMCO', 'Nifty 50')
# ('EMAMILTD', 'Nifty 200')
# ('QUESS', 'Nifty 500')
# ('CIPLA', 'Nifty 50')
# ('GILLETTE', 'Nifty 500')
# ('NILKAMAL', 'Nifty 500')
# ('SHREECEM', 'Nifty 50')
# ('MAXHEALTH', 'Nifty 500')

# %% [markdown]
# # Stochastic Oscillator
# 1. Buy when the fast line cuts the slow line from below in an OVERSOLD zone ( both are below 20). Wait for both lines to go above Oversold and then buy. Recent candle closing must be above 200-MA
#
# 2. Sell when both lines reaches Overbought region (above 70) and fast line crosses slow from above. Wait for both lines to go below the threshold

# %%
for name in In.data['nifty_500']:
    if In.Stochastic(In.open_downloaded_stock(name), signal_only = True) == "Buy":
        print(name, In.get_index(name))

# %% [markdown]
# # <font color='teal'>Intraday Strategies</font>
# # See documentations for Intraday strategies

# %% [markdown]
# ## Narrow Range (Stock Selection)
# If recent candle's range is lowest among `X` other days then the future candle might break it's low/high

# %%
for name in In.data['nifty_500']:
    if Intra.NR_strategy(name, range_ = 20):
        print(Intra.prob_by_percent_change(symbol = [name], index = None, time_period = 10, change_percent=0.07),In.get_index(name,'all'))
# Out:
# {'HAL': {'Long Probability': 0.9, 'Short Probability': 0.7}} ['Nifty 200', 'NIFTY PSE']
# {'ENGINERSIN': {'Long Probability': 0.5, 'Short Probability': 0.8}} ['Nifty 500']
# {'INDIGO': {'Long Probability': 0.7, 'Short Probability': 0.9}} ['Nifty 100', 'NIFTY INDIA CONSUMPTION', 'NIFTY INFRASTRUCTURE']
# {'AARTIIND': {'Long Probability': 0.6, 'Short Probability': 0.8}} ['Nifty 200', 'NIFTY COMMODITIES']
# {'ALKEM': {'Long Probability': 0.3, 'Short Probability': 0.9}} ['Nifty 200', 'NIFTY PHARMA', 'NIFTY HEALTHCARE INDEX']
# {'BAJAJHLDNG': {'Long Probability': 0.8, 'Short Probability': 0.8}} ['Nifty 100']
# {'ABBOTINDIA': {'Long Probability': 0.6, 'Short Probability': 0.9}} ['Nifty 500', 'NIFTY PHARMA', 'NIFTY MNC']
# {'ICIL': {'Long Probability': 1.0, 'Short Probability': 0.9}} ['Nifty 500']

# %% [markdown]
# ## Whole Number Open (Stock Selection + Strategy)
# When Open == Low / High in Whole number as `xxx.00` within 15 minutes

# %%
Intra.whole_number_strategy(nifty = 200, min_val=101, max_val=5000, print_results = True)
# Out:
# Long :
#  Name - Change - ATR - Change% - Remaining Move - Index:
#
# ('COROMANDEL', 14.4, 27.77, '1.73%', -0.48, 'Nifty 200')
#
# ('ENDURANCE', 38.9, 64.73, '2.36%', -0.4, 'Nifty 200')
#
# Short :
#  Name - Change - ATR - Change% - Remaining Move - Index:
#
# ('HDFCAMC', 53.25, 61.9, '1.84%', -0.14, 'Nifty 100')
#
# ('INFY', 45.05, 43.16, '2.48%', 0.04, 'Nifty 50')
#
# ('HEROMOTOCO', 83.05, 49.88, '2.93%', 0.66, 'Nifty 50')
#
# ('MINDTREE', 472.95, 198.66, '9.9%', 1.38, 'Nifty 200')

# %% [markdown]
# ## `%` Change probability (Stock Selection)
# Gives the stock names which have the highest probability of providing you `x%` in intraday atleast on both long or short side based on the previous `N` days record

# %%
# Gives you top 10 stocks from Nifty 500 which have the highest probability of giving atleast 0.99% on your investment based on the Long/Buy position. Data is based on past 60 trading days
# Test it for different time duration, index, % change and Long / Short criteria based on overall market trend
Intra.prob_by_percent_change(symbol = None, index = 200, time_period = 20, change_percent=0.099, sort_by='Long Probability', top_k = 10)

# %% [markdown]
# ## ATR
# If stock has crossed it's ATR on either side, it might reverse or if it hasn't, there is still a chance to move

# %%
df = Intra.ATR_strategy(index = 'NIFTY 200', possible_reversal=False) # if possible_reversal is true, it'll just reverse the order of remaining move %
df.head(20)
# Out:
#          symbol  pChange     open  dayHigh   dayLow  lastPrice  \
# 18          SRF     2.20  2223.00  2258.80  2176.00    2257.80
# 43    POWERGRID     0.98   196.25   197.35   194.80     196.25
# 39      YESBANK     1.11    13.60    13.75    13.50      13.65
# 63   TORNTPOWER     0.34   498.30   502.95   493.40     500.00
# 30     ASHOKLEY     1.50   137.80   139.30   136.45     138.65
# 70          PFC     0.21   141.25   142.20   139.80     140.75
# 51      RBLBANK     0.64   190.00   191.80   188.10     190.15
# 36     ADANIENT     1.17  1601.95  1616.00  1584.20    1608.35
# 29   TATAMOTORS     1.60   491.75   499.50   485.75     494.70
# 54   CUMMINSIND     0.54   886.00   897.35   875.40     887.90
# 31   ADANIGREEN     1.50  1190.00  1203.95  1173.10    1196.80
# 33    LICHSGFIN     1.31   437.25   441.55   434.50     441.05
# 49       RECLTD     0.81   155.10   156.50   153.20     154.85
# 53          BEL     0.59   205.85   207.00   203.30     206.00
# 155       ABFRL    -1.43   252.60   255.85   248.00     248.90
# 57   APOLLOTYRE     0.47   227.50   229.25   224.40     226.75
# 122    HDFCBANK    -0.61  1671.80  1681.95  1660.85    1663.70
# 48   IDFCFIRSTB     0.82    48.90    49.55    48.45      49.05
# 69      ESCORTS     0.24  1445.00  1459.10  1425.15    1441.75
# 45   SRTRANSFIN     0.88  1451.55  1467.70  1441.15    1451.30
#
#      absolute_change         ATR  remaining move %
# 18              2.20  817.383353             -0.94
# 43              0.98    5.829198             -0.75
# 39              1.11    0.540545             -0.72
# 63              0.34   17.522094             -0.72
# 30              1.50    5.180154             -0.71
# 70              0.21    4.795754             -0.70
# 51              0.64    6.387192             -0.70
# 36              1.17   58.475666             -0.70
# 29              1.60   24.709053             -0.69
# 54              0.54   34.191445             -0.67
# 31              1.50   48.664944             -0.65
# 33              1.31   12.439297             -0.65
# 49              0.81    5.378774             -0.65
# 53              0.59    7.254307             -0.65
# 155             1.43   12.729827             -0.64
# 57              0.47    8.531942             -0.64
# 122             0.61   30.782710             -0.64
# 48              0.82    1.736571             -0.63
# 69              0.24   53.763059             -0.63
# 45              0.88   43.575417             -0.63

# %% [markdown]
# # <font color='Teal'>Live Data</font>
#
#
# ## Market Sentiment: TICK, TRIN (Arm's Index) & 52W High-Low touching shares

# %%
MS.get_live_sentiment()
# Out:
# {'Latest Updated on': '29/10/2021 16:14:59',
#  'Up': 641,
#  'Down': 996,
#  'TICK': -355,
#  'Volume Up': 1200.6,
#  'Volume Down': 1549.78,
#  'TRIN': 0.831,
#  '52W High': 31,
#  '52W Low': 32}

# %% [markdown]
# ## [Volatility Index: VIX](https://www.motilaloswal.com/blog-details/6-things-that-the-Volatility-Index-(VIX)-indicates-to-you../1929)

# %%
NSE.get_VIX()
# Out:
# Current VIX: 17.7600

# %% [markdown]
# ## MMI: [Market Mood Index](https://www.tickertape.in/market-mood-index)
#
# Please click on the link above to get the values. All credits to [Ticker Tape Website](https://www.tickertape.in/)

# %%
get_mmi(raw = True) # True means a simple Json shows current, last week, last month MMI
# Out:
# {'currentValue': 25.944794016900715,
#  'date': '2021-11-01T08:18:03.554Z',
#  'indicator': 25.944794016900715,
#  'lastDay': {'indicator': 24.068052834307046,
#   'date': '2021-10-29T00:00:00.000Z',
#   'nifty': 17671.65},
#  'lastWeek': {'indicator': 41.37274915457675,
#   'date': '2021-10-25T00:00:00.000Z',
#   'nifty': 18125.4},
#  'lastMonth': {'indicator': 42.583611823452785,
#   'date': '2021-09-29T00:00:00.000Z',
#   'nifty': 17711.3},
#  'nifty': 17846.45}

# %% [markdown]
# ## Current Index Performance
# Includes Nifty, Thematic and Sectoral indices and show `Top-N` sorted by change %

# %%
NSE.current_indices_status(10,int = 15) # Live as of market is open. works post market also
# Out:
#                      index  percentChange                   key  variation
# 8                INDIA VIX           6.44  BROAD MARKET INDICES       1.09
# 24          NIFTY PSU BANK          -5.22      SECTORAL INDICES    -153.35
# 35  NIFTY50 PR 2X LEVERAGE          -3.89      STRATEGY INDICES    -382.85
# 34  NIFTY50 TR 2X LEVERAGE          -3.89      STRATEGY INDICES    -519.20
# 26            NIFTY REALTY          -3.77      SECTORAL INDICES     -19.45
# 22             NIFTY METAL          -3.44      SECTORAL INDICES    -197.35
# 15              NIFTY BANK          -3.34      SECTORAL INDICES   -1365.40
# 48              NIFTY CPSE          -3.34      THEMATIC INDICES     -79.30
# 45    NIFTY200 MOMENTUM 30          -2.92      STRATEGY INDICES    -612.50
# 25      NIFTY PRIVATE BANK          -2.83      SECTORAL INDICES    -596.35

# %%
NSE.open_nse_index('NIFTY ENERGY',) # Returns performance of stocks in a given index

# %%
In.stock_current_index_performance('HAVELLS') # All the eligible indices (and their current performance) where this stock belongs to. Some stocks might not belong aywhere
# Out:
#                       index  percentChange                   key  variation
# 2                 NIFTY 100          -1.97  BROAD MARKET INDICES    -361.95
# 28  NIFTY CONSUMER DURABLES          -1.66      SECTORAL INDICES    -475.95
# 47  NIFTY INDIA CONSUMPTION          -1.43      THEMATIC INDICES    -102.00

# %% [markdown]
# # <font color='teal'>Back Testing</font>
# # Back Testing Stratagies to get the best Win %, Max Return Investment etc
# Pass in the parameters dict for all. Check Docstring of each individual function for how a strategy works in buying or selling.

# %% [markdown]
# ## CCI
# `BT.backtest('cci', stocks=['DIVISLAB'])` , for individual stock data performance to tell how much a stock would have gained or lost

# %%
cci_parameters = {'buying_thresh':-100, 'selling_thresh':100, 'window':20, 'cols':('OPEN','CLOSE','LOW','HIGH', 'DATE')} # check documentation of BT.cci()

# Using the CCI strategy, Return top gaining stocks which have traded atleast 365 recent days and are currently in nifty-500
BT.backtest('cci', min_days = 365, top_n=45, stocks = 'nifty_500', **cci_parameters)
# Out:
#             win%  wins  losses    ROI  \
# ALEMBICLTD   1.0    10       0   5.83
# TIINDIA      1.0     7       0   8.74
# BASF         1.0     7       0   6.74
# MFSL         1.0     7       0   5.13
# MARICO       1.0     7       0   2.95
# PIDILITIND   1.0     7       0   2.49
# IEX          1.0     6       0   9.50
# CYIENT       1.0     6       0   7.76
# AMBUJACEM    1.0     6       0   6.66
# CANFINHOME   1.0     6       0   6.15
# ACC          1.0     6       0   4.98
# VAIBHAVGBL   1.0     6       0   3.96
# LALPATHLAB   1.0     6       0   3.68
# INDIGO       1.0     5       0   8.43
# AFFLE        1.0     5       0   8.12
# JKCEMENT     1.0     5       0   5.73
# RADICO       1.0     5       0   5.14
# JKLAKSHMI    1.0     5       0   4.11
# GMRINFRA     1.0     5       0   3.39
# CERA         1.0     5       0   3.16
# SBILIFE      1.0     5       0   2.50
# DCMSHRIRAM   1.0     4       0  10.24
# BEL          1.0     4       0  10.07
# GSFC         1.0     4       0   9.83
# BRIGADE      1.0     4       0   8.73
# BALRAMCHIN   1.0     4       0   8.57
# CENTURYTEX   1.0     4       0   8.05
# TEAMLEASE    1.0     4       0   7.66
# STARCEMENT   1.0     4       0   7.65
# BHARATRAS    1.0     4       0   7.34
# UJJIVAN      1.0     4       0   7.12
# BEML         1.0     4       0   6.71
# SHRIRAMCIT   1.0     4       0   6.50
# BALKRISIND   1.0     4       0   6.42
# KAJARIACER   1.0     4       0   5.18
# TTKPRESTIG   1.0     4       0   5.16
# IGL          1.0     4       0   4.95
# FLUOROCHEM   1.0     4       0   4.71
# INTELLECT    1.0     4       0   4.64
# SANOFI       1.0     4       0   4.55
# JAMNAAUTO    1.0     4       0   4.16
# ICICIPRULI   1.0     4       0   4.14
# ASTRAZEN     1.0     4       0   3.86
# PETRONET     1.0     4       0   3.77
# RECLTD       1.0     4       0   2.67
#
#                                                           p&l  \
# ALEMBICLTD  [1.8500000000000014, 2.049999999999997, 3.9500...
# TIINDIA     [5.699999999999989, 1.8999999999999773, 26.0, ...
# BASF        [14.75, 17.200000000000045, 370.0, 73.40000000...
# MFSL        [17.0, 71.39999999999998, 6.899999999999977, 2...
# MARICO      [6.25, 12.850000000000023, 1.4499999999999886,...
# PIDILITIND  [36.549999999999955, 57.700000000000045, 130.0...
# IEX         [17.100000000000023, 3.8000000000000114, 14.59...
# CYIENT      [22.5, 41.0, 113.94999999999999, 2.79999999999...
# AMBUJACEM   [12.400000000000006, 21.850000000000023, 6.100...
# CANFINHOME  [13.350000000000023, 37.30000000000001, 27.0, ...
# ACC         [130.0, 25.0, 100.0, 97.0, 51.950000000000045,...
# VAIBHAVGBL  [56.299999999999955, 23.0, 12.099999999999909,...
# LALPATHLAB  [67.0, 91.0, 66.79999999999995, 140.3499999999...
# INDIGO         [169.5, 75.75, 243.1500000000001, 92.75, 77.0]
# ASTRAZEN                          [8, 28, 1, 5]    4     4  678
# PETRONET                       [43, 23, 22, 18]    4     4  678
# RECLTD                          [54, 7, 20, 29]    4     4  678

# %% [markdown]
# ## MA
# Moving Average Strategy

# %%
BT.backtest('ma',stocks='nifty_50',top_n=25)
# Out:
#             win%  wins  losses   ROI  \
# BAJAJFINSV  0.88     7       1  6.59
# TATAMOTORS  0.88     7       1  6.20
# TITAN       0.69     9       4  3.81
# TATASTEEL   0.64     7       4  3.31
# COALINDIA   0.62     5       3  3.63
# WIPRO       0.62     5       3  2.42
# LT          0.62     5       3  2.01
# TATACONSUM  0.61    11       7  2.87
# INFY        0.58     7       5  2.28
# GRASIM      0.57     4       3  3.11
# ONGC        0.56     5       4  2.49
# HCLTECH     0.56     5       4  0.92
# ASIANPAINT  0.55     6       5  2.08
# SBIN        0.55     6       5  1.83
# ICICIBANK   0.55     6       5  1.74
# TCS         0.53     9       8  1.79
# HINDALCO    0.50     7       7  2.66
# ULTRACEMCO  0.50     7       7  2.21
# HINDUNILVR  0.50     7       7  2.09
# HDFCLIFE    0.50     7       7  1.94
# DRREDDY     0.50     7       7  1.76
# HDFCBANK    0.50     7       7  0.77
# BAJFINANCE  0.50     6       6  2.08
# SBILIFE     0.50     6       6  1.99
# JSWSTEEL    0.50     6       6  1.44
#
#                                                           p&l  \
# BAJAJFINSV  [578.4929999999995, 430.2379999999994, 780.0, ...
# TATAMOTORS  [20.29800000000003, 18.974999999999994, 11.143...
# TITAN       [-19.100000000000136, 63.18249999999989, 42.78...
# TATASTEEL   [32.238000000000056, -38.75, -38.3499999999999...
# COALINDIA   [20.497000000000014, 15.721000000000004, -6.94...
# WIPRO       [-12.800000000000011, 15.920000000000016, 13.7...
# LT          [83.57999999999993, -26.850000000000136, -50.8...
# TATACONSUM  [12.536999999999978, 10.845500000000044, -11.2...
# INFY        [-34.89999999999998, -20.40000000000009, -17.6...
# GRASIM      [73.53050000000007, -15.950000000000045, -79.7...
# ONGC        [16.218500000000006, 10.149000000000001, -7.15...
# HCLTECH     [-28.0, 66.96349999999984, -78.54999999999995,...
# ASIANPAINT  [85.56999999999994, -36.799999999999955, 144.3...
# SBIN        [12.039500000000032, -4.400000000000034, 31.07...
# ICICIBANK   [19.899999999999977, -10.25, -15.25, 23.879999...
# TCS         [204.51499999999987, -46.94999999999982, 156.6...
# HINDALCO    [13.432500000000005, -10.099999999999994, -9.4...
# ULTRACEMCO  [363.971, -164.85000000000036, -84.89999999999...
# HINDUNILVR  [-28.90000000000009, -70.0, 118.10650000000032...
# HDFCLIFE    [37.89999999999998, 39.89999999999998, 54.0549...
# DRREDDY     [206.76099999999997, -66.94999999999982, -106....
# HDFCBANK    [-36.25, -32.80000000000018, 69.65000000000009...
# BAJFINANCE  [138.9020000000005, 312.9000000000001, 288.947...
# SBILIFE     [21.889999999999986, 36.416999999999916, 92.73...
# JSWSTEEL    [22.88499999999999, -6.600000000000023, -13.5,...
#
#                                                      buy_date  \
# BAJAJFINSV  [2019-02-25 00:00:00, 2019-05-10 00:00:00, 201...
# TCS         [62, 3, 14, 3, 42, 12, 8, 4, 73, 1, 12, 7, 35,...   17    17  678
# HINDALCO     [12, 7, 13, 37, 13, 11, 4, 5, 2, 6, 2, 15, 6, 1]   14    14  678
# ULTRACEMCO  [12, 17, 3, 29, 12, 15, 27, 42, 13, 3, 0, 58, ...   14    14  678
# HINDUNILVR  [15, 63, 43, 19, 7, 26, 18, 7, 21, 7, 14, 83, ...   14    14  678
# HDFCLIFE    [57, 10, 45, 79, 12, 20, 12, 9, 28, 1, 5, 34, ...   14    14  678
# DRREDDY      [49, 2, 1, 8, 9, 67, 7, 0, 14, 15, 5, 50, 23, 1]   14    14  678
# HDFCBANK     [2, 7, 2, 8, 3, 56, 20, 6, 18, 6, 11, 6, 63, 23]   15    14  678
# BAJFINANCE         [13, 3, 14, 6, 19, 25, 0, 10, 5, 7, 22, 7]   12    12  678
# SBILIFE          [1, 24, 20, 59, 6, 2, 47, 12, 21, 27, 0, 22]   13    12  678
# JSWSTEEL          [59, 0, 8, 1, 3, 17, 17, 12, 28, 14, 6, 31]   12    12  678

# %% [markdown]
# ## RSI

# %%
BT.backtest('rsi',stocks='nifty_500', top_n = 30)
# Out:
#             win%  wins  losses    ROI  \
# EPL          1.0     2       0  42.49
# ALKYLAMINE   1.0     2       0  41.71
# GMMPFAUDLR   1.0     2       0  33.26
# EIHOTEL      1.0     2       0  29.79
# DIVISLAB     1.0     2       0  29.66
# ALKEM        1.0     2       0  28.03
# BSE          1.0     2       0  26.05
# ATUL         1.0     2       0  24.61
# BERGEPAINT   1.0     2       0  22.42
# TORNTPHARM   1.0     2       0  19.98
# DRREDDY      1.0     2       0  19.25
# BLUESTARCO   1.0     2       0  17.47
# ICICIGI      1.0     2       0  17.43
# ESCORTS      1.0     2       0  15.63
# HONAUT       1.0     2       0  15.00
# LEMONTREE    1.0     2       0  14.94
# VINATIORGA   1.0     2       0  14.78
# HAL          1.0     2       0  13.99
# HINDUNILVR   1.0     2       0  10.26
# MARUTI       1.0     2       0  10.11
# BRITANNIA    1.0     2       0  10.08
# GODREJPROP   1.0     2       0   9.32
# CEATLTD      1.0     2       0   7.28
# THYROCARE    1.0     2       0   4.91
# RELIANCE     1.0     2       0   4.90
# POLYMED      1.0     1       0  67.77
# JSL          1.0     1       0  56.76
# ADANIGREEN   1.0     1       0  52.96
# JUBLFOOD     1.0     1       0  52.69
# WOCKPHARMA   1.0     1       0  52.28
#
#                                                  p&l  \
# EPL           [24.80000000000001, 98.30000000000001]
# ALKYLAMINE               [17.399999999999977, 783.0]
# GMMPFAUDLR              [1750.0, 242.10000000000036]
# EIHOTEL                   [21.099999999999994, 37.0]
# DIVISLAB                 [1264.3999999999999, 342.0]
# ALKEM                   [1038.7, 244.05000000000018]
# BSE                       [70.0, 203.29999999999995]
# ATUL        [170.69999999999982, 1600.0500000000002]
# BERGEPAINT               [146.0, 107.55000000000007]
# TORNTPHARM               [669.0, 181.94999999999982]
# DRREDDY                 [1269.5, 149.89999999999964]
# BLUESTARCO  [129.20000000000005, 131.70000000000005]
# ICICIGI             [1235.0, 1402.0]   [1516.55, 1580.0]  [279, 148]    2
# ESCORTS              [652.0, 1267.0]     [871.9, 1347.0]   [72, 251]    2
# HONAUT            [23400.0, 26397.9]  [24667.0, 32600.0]    [37, 54]    2
# LEMONTREE               [38.9, 41.4]        [40.3, 52.0]    [59, 56]    2
# VINATIORGA        [1843.65, 1949.35]    [2245.0, 2108.7]    [52, 58]    2
# HAL                  [722.25, 784.0]      [855.0, 862.0]    [19, 80]    2
# HINDUNILVR         [1950.0, 2034.05]    [2063.0, 2330.0]   [33, 126]    2
# MARUTI              [6579.0, 7060.0]    [7760.0, 7258.0]   [73, 100]    2
# BRITANNIA           [3048.0, 3480.0]    [3434.9, 3751.0]   [97, 174]    2
# GODREJPROP           [897.9, 1422.0]     [990.0, 1546.0]   [70, 121]    2
# CEATLTD            [1070.75, 1394.0]  [1218.85, 1425.45]    [27, 89]    2
# THYROCARE     [570.0, 928.5, 1199.0]     [572.65, 999.4]  [120, 105]    3
# RELIANCE            [1434.9, 2041.8]    [1453.7, 2193.4]   [90, 225]    2
# POLYMED                      [227.1]             [381.0]       [114]    1
# JSL                          [27.75]              [43.5]        [22]    1
# ADANIGREEN                   [125.0]             [191.2]        [34]    1
# JUBLFOOD                    [1395.0]            [2130.0]       [162]    1
# WOCKPHARMA                  [449.85]            [685.05]        [58]    1
#
#            sells days
# EPL            2  678
# ALKYLAMINE     2  678
# GMMPFAUDLR     2  678
# EIHOTEL        2  678
# DIVISLAB       2  678
# ALKEM          2  678
# BSE            2  677
# ATUL           2  678
# BERGEPAINT     2  678
# TORNTPHARM     2  678
# DRREDDY        2  678
# BLUESTARCO     2  678
# ICICIGI        2  678
# ESCORTS        2  678
# HONAUT         2  678
# LEMONTREE      2  678
# VINATIORGA     2  678
# HAL            2  678
# HINDUNILVR     2  678
# MARUTI         2  678
# BRITANNIA      2  678
# GODREJPROP     2  678
# CEATLTD        2  678
# THYROCARE      2  678
# RELIANCE       2  678
# POLYMED        1  678
# JSL            1  678
# ADANIGREEN     1  613
# JUBLFOOD       1  678
# WOCKPHARMA     1  678

# %% [markdown]
# ## MACD

# %%
BT.backtest('macd', top_n=5, stocks=['BAJFINANCE','SHREECEM',"COALINDIA"]) # Individual stocks. If no sells have been made, it'll be empty

# %% [markdown]
# ## Stochastic Oscillator
# Faster signal than MACD. Pass in the paramerters to change results and modify to your ease

# %%
BT.backtest('stochastic_osc',stocks='nifty_500', top_n = 15)

# %% [markdown]
# # <font color='teal'>Risk Management</font>

# %%
# You have a total budget of 40K, and a risk apetite of rs 400 per trade
# You can set manual such as # entry = 3980.1, stop_loss=3780.5

# %%
In.get_particulars('NIITLTD',40000,400,entry = 366,stop_loss=344)
# Out:
# {'Buying Price': 366,
#  'Stop-Loss %': 6.01,
#  'Target %': 15.03,
#  'Quantity': 18,
#  'Stop-Loss Price': 344,
#  'Trigger Price': 421.0,
#  'investment_required': 6588,
#  'Risk Per Share': 22,
#  'Profit Per Share': 55.0,
#  'Max loss on this config': 396,
#  'Max Gain on this config': 990.0,
#  'Index': []}
