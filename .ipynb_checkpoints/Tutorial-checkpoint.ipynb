# %% [markdown]
# # <font color='red'>STOCK MARKET IS VERY RISKY UNTIL YOU DO IT PROPERLY. PLEASE DO NOT TAKE TRADES JUST BECAUSE THIS TOOL GIVES YOU THE NAME. APPLY YOUR OWN LEARNINGS, CREATE YOUR OWN STRATEGY, ASSESS RISK & TRADE THE PLAN.</font>

# %%
'065676'
# Out:
# '065676'

# %%
df = pd.read_csv(join(expanduser('~'),'Downloads',"cm08OCT2021bhav.csv"))
all_stocks = df.loc[df["SERIES"] == 'EQ','SYMBOL'].values.tolist()
# for name in all_stocks:
#     if name not in In.data['all_stocks']:
#         print(name)
        
In.data['registered_stocks'] = all_stocks
In.update_data(In.data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_7250/381510623.py in <module>
#       6
#       7 In.data['registered_stocks'] = all_stocks
# ----> 8 In.update_data(In.data)
#
# ~/Desktop/ML Study/Finance/helpers/datahandler.py in update_data(self, updated_data, path, file)
#      74         with open(join(path,file), 'w') as f:
#      75             json.dump(updated_data,f)
# ---> 76
#      77
#      78     def open_live_stock_data(self,name:str):
#
# ~/anaconda3/envs/finance/lib/python3.7/json/__init__.py in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     177     # could accelerate with writelines in some versions of Python, at
#     178     # a debuggability cost
# --> 179     for chunk in iterable:
#     180         fp.write(chunk)
#     181
#
# ~/anaconda3/envs/finance/lib/python3.7/json/encoder.py in _iterencode(o, _current_indent_level)
#     429             yield from _iterencode_list(o, _current_indent_level)
#     430         elif isinstance(o, dict):
# --> 431             yield from _iterencode_dict(o, _current_indent_level)
#     432         else:
#     433             if markers is not None:
#
# ~/anaconda3/envs/finance/lib/python3.7/json/encoder.py in _iterencode_dict(dct, _current_indent_level)
#     403                 else:
#     404                     chunks = _iterencode(value, _current_indent_level)
# --> 405                 yield from chunks
#     406         if newline_indent is not None:
#     407             _current_indent_level -= 1
#
# ~/anaconda3/envs/finance/lib/python3.7/json/encoder.py in _iterencode(o, _current_indent_level)
#     436                     raise ValueError("Circular reference detected")
#     437                 markers[markerid] = o
# --> 438             o = _default(o)
#     439             yield from _iterencode(o, _current_indent_level)
#     440             if markers is not None:
#
# ~/anaconda3/envs/finance/lib/python3.7/json/encoder.py in default(self, o)
#     177
#     178         """
# --> 179         raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                         f'is not JSON serializable')
#     181
#
# TypeError: Object of type Series is not JSON serializable

# %%
import requests
# x = NSE.get_live_nse_data(url = f"https://www1.nseindia.com/products/dynaContent/common/productsSymbolMapping.jsp?symbol={symbol}&segmentLink=3&symbolCount=1&series=EQ&dateRange=24month&fromDate=&toDate=&dataType=PRICEVOLUMEDELIVERABLE")
# url = f"https://www.nseindia.com/api/historical/cm/equity?symbol={symbol}&series=[%22EQ%22]&from=9-10-2020&to=9-10-2021"
url = "https://www1.nseindia.com/ArchieveSearch?h_filetype=eqbhav&date=08-10-2021&section=EQ"
x = NSE.get_live_nse_data(url)
x.content
# Out:
# b'<p class="archive_title">Bhavcopy for the period for 08-10-2021 </p>\n<table border="0" cellspacing="0" cellpadding="0">\n<tr>\n<td>\n<a href=/content/historical/EQUITIES/2021/OCT/cm08OCT2021bhav.csv.zip target=new>cm08OCT2021bhav.csv.zip</a><br>\n</td></tr>\n</table>\n</td></tr>\n</table>\n'

# %%
In.open_downloaded_stock('INFY')
# Out:
#           DATE     OPEN     HIGH      LOW    CLOSE   52W H    52W L SYMBOL
# 0   2021-10-08  1705.25  1731.50  1698.40  1723.85  1788.0  1018.05   INFY
# 1   2021-10-07  1687.00  1704.20  1676.65  1691.00  1788.0  1018.05   INFY
# 2   2021-10-06  1702.10  1709.00  1670.00  1673.55  1788.0  1018.05   INFY
# 3   2021-10-05  1671.00  1702.95  1663.00  1692.80  1788.0  1018.05   INFY
# 4   2021-10-04  1672.50  1688.00  1665.40  1678.75  1788.0  1018.05   INFY
# ..         ...      ...      ...      ...      ...     ...      ...    ...
# 404 2020-02-24   800.10   811.60   792.15   795.85   847.0   615.10   INFY
# 405 2020-02-20   803.25   806.10   793.85   797.00   847.0   615.10   INFY
# 406 2020-02-19   800.00   804.85   796.15   800.45   847.0   615.10   INFY
# 407 2020-02-18   785.00   799.05   783.65   797.65   847.0   615.10   INFY
# 408 2020-02-17   790.30   793.45   783.30   789.45   847.0   615.10   INFY
#
# [409 rows x 8 columns]

# %% [markdown]
# # Imports, Defaults and Initializations
# Clicking on the below cell is mandatory. Click on the cell below and press `Shit + Enter`. To run any cell, use the same keyboard shortcut.

# %%
# import backtrader
from helpers.datahandler import *
from helpers.investing import *
from helpers.journal_handler import *
from helpers.intraday import *
from helpers.nse_data import *
from helpers.backtest import *


pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 25)

In = Investing(check_fresh = False) # Investing or Swing trading analysis
Intra = IntraDay() # Intraday strategies and analysis
NSE = NSEData() # Get NSE Live data
MS = MarketSentiment() # Get Live Market Sentiment TICK, TRIN and 52W high/ low stocks
BT = Backtest()

# %% [markdown]
# # Journal
# Make a journal in Google Drive for each trade you take to analyse. **It is a not so simple process and need to connect with Google API so if you're not comfortable with it, just skip it**

# %%
private_key = join(expanduser('~'),'Documents','client_secret.json') # Personal for each user. Mine is stored in /home/Documents
JH = JournalHandler(private_key)

journal = JH.get_journal('Finance Journal') # My Google Sheet jornam has name "Finance Journal"

JH.total_pl(journal) # total Profit and Loss up until now
# Out:
# These stocks have crossed 21 days limit. Sell them at 1:1.5 or 1:1 or at Market Price
# ICICIBANK bought on 2021-09-01 00:00:00
#
# ---------------------------------------------------------------------------
#
# Trailing Stop Loss:
#
# TCS bought on: 2021-10-06 00:00:00,
#
# ---------------------------------------------------------------------------
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/pandas/core/frame.py:3607: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._set_item(key, value)
# 330.01

# %% [markdown]
# # <font color='teal'>Swing Strategies </font>
# # Tweak parameters by reading the Docstring
# ## Basic Details
# Basic Details about stocks such as Momentum, Ichimoku, 1-2-3 candles pattern etc

# %%
budget = 40000

df = In.get_recent_info(nifty = 100, **{'mvs':[20,50,100,200]})
df.head(2) # show first 2 values
# Out:
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
#         Date        Name      LTP      Index CCI Signal RSI Signal  \
# 0 2021-10-08         ACC   2240.9  Nifty 100  No Signal  No Signal
# 1 2021-10-08  ABBOTINDIA  21796.9  Nifty 100  No Signal  No Signal
#
#   MACD Signal  Over 20-SMA  Over 50-SMA  Over 100-SMA  Over 200-SMA  \
# 0   No Signal        False        False          True          True
# 1   No Signal         True         True          True          True
#
#    Momentum ADX  Ichi Count     1 Candle 2 Candles 3 Candles
# 0     27.446038           0  Unknown Red   Unknown   Unknown
# 1     27.883746           3  Unknown Red   Unknown   Unknown

# %% [markdown]
# ## Breakout
# Stocks that might breakout. Includes only those stocks which are above 50 days SMA, have atleast `n` number of touches within the `p%` of the recent candle. Just look at these stocks manually. Change the parameters to control the number of stocks to scan.

# %%
In.tight_consolidation_stocks(stocks = 'nifty_200', diff = 0.0075, min_count = 5, lookback_period = 7) # There should be atleast 5 candles touching the +- 0.75% of the line within 7 days
# Out:
# {'IDFCFIRSTB': 6,
#  'SBIN': 6,
#  'VBL': 6,
#  'ADANIPORTS': 5,
#  'AMARAJABAT': 5,
#  'AXISBANK': 5,
#  'BAJAJ-AUTO': 5,
#  'HDFCLIFE': 5,
#  'HEROMOTOCO': 5,
#  'HAL': 5,
#  'ITC': 5,
#  'L&TFH': 5,
#  'NAM-INDIA': 5,
#  'PFC': 5,
#  'SRTRANSFIN': 5,
#  'SUNPHARMA': 5}

# %% [markdown]
# ## 44-SMA
# If you find a `Green` candle taking support on 44 days `Simple Moving Average` line and stock is in uptrend, you can take the trade and set Risk to Reward ratio as 1:2

# %%
budget = 40000 # Total Budget
risk = 400 # Risk per trade
df = In.show_full_stats(budget = budget,risk=risk, diff = 100, nifty='nifty_100') # Show only stocks undder your budget and  whose recent candle's lowest is not more than 151 rupees above the moving average line
df[(df['RSI Value'] < 70) & (df['CCI Value'] < 200)]
# Out:
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:768: RuntimeWarning: invalid value encountered in double_scalars
#   dip[i] = 100 * (self._dip[i] / self._trs[i])
# /home/admin1/anaconda3/envs/finance/lib/python3.7/site-packages/ta/trend.py:772: RuntimeWarning: invalid value encountered in double_scalars
#   din[i] = 100 * (self._din[i] / self._trs[i])
#          DATE     OPEN     HIGH      LOW    CLOSE    52W H    52W L  \
# 11 2021-10-08   781.90   785.00   776.00   781.95   820.70   439.05
# 3  2021-10-08   646.15   667.55   645.00   661.15   699.15   315.20
# 10 2021-10-08   739.70   747.00   733.50   739.90   901.00   341.15
# 4  2021-10-08  1418.50  1447.00  1418.50  1439.95  1547.85   781.85
# 2  2021-10-08  1705.25  1731.50  1698.40  1723.85  1788.00  1018.05
# 7  2021-10-08  3995.00  4038.00  3974.00  4006.80  4272.55  2100.20
# 8  2021-10-08   560.80   565.00   558.40   563.80   590.00   345.75
# 1  2021-10-08  1522.00  1569.45  1511.45  1547.90  1717.20   303.00
# 9  2021-10-08   695.15   699.55   688.90   695.50   753.00   394.00
# 5  2021-10-08  3913.30  4026.10  3872.00  3934.80  4070.00  2540.05
# 0  2021-10-08  1596.00  1616.80  1591.65  1598.80  1694.30   733.45
# 6  2021-10-08  1306.30  1338.00  1294.05  1322.15  1377.75   800.25
#
#         SYMBOL   Diff  CCI Value  RSI Value MACD Signal        ADX  \
# 11    AXISBANK   1.04     -58.07  49.906973   No Signal  15.046549
# 3        WIPRO   1.42       2.81  56.936449   No Signal  25.766788
# 10  ADANIPORTS   1.69     -64.65  50.376606   No Signal  13.858816
# 4        TECHM   2.16      -7.91  54.084650   No Signal  30.077916
# 2         INFY   2.49      57.88  56.298196   No Signal  16.892538
# 7     JUBLFOOD   5.43    -118.80  49.227563   No Signal  24.709516
# 8       MARICO  12.94      20.61  57.249587   No Signal  27.450260
# 1     ADANIENT  18.11     118.31  57.346299   No Signal  14.931846
# 9   BHARTIARTL  22.06     -51.77  54.298428   No Signal  33.556919
# 5        ALKEM  41.36      35.60  56.467016   No Signal  27.311446
# 0       GRASIM  41.55     -25.17  51.117151   No Signal  23.424199
# 6      HCLTECH  87.13      87.90  64.013958   No Signal  46.595024
#
#           Direction  Ichi         ATR Triple Candle Double Candle  \
# 11      Rising High     0   17.810714       Unknown       Unknown
# 3       Rising High     0   15.896429       Unknown       Unknown
# 10  Undeterministic     0   17.760714       Unknown       Unknown
# 4   Undeterministic     0   42.035714     V Pattern       Unknown
# 2       Rising High     0   36.321429       Unknown       Unknown
# 7   Undeterministic     0  119.985714       Unknown       Unknown
# 8       Rising High     0   12.128571       Unknown       Unknown
# 1   Undeterministic     0   57.771429       Unknown       Unknown
# 9   Undeterministic     0   19.228571       Unknown       Unknown
# 5       Rising High     0  109.985714       Unknown       Unknown
# 0       Rising High     1   41.564286       Unknown       Unknown
# 6       Rising High     0   40.221429       Unknown       Unknown
#
#       Recent Candle      Index  Expected Change %  Max Config Risk
# 11       Green Doji   Nifty 50               3.17           398.69
# 3     Unknown Green   Nifty 50               9.56           383.45
# 10  Inverted Hammer   Nifty 50               5.86           394.62
# 4     Unknown Green   Nifty 50              10.24           370.86
# 2     Unknown Green   Nifty 50               6.72           349.55
# 7   Inverted Hammer  Nifty 100               5.14           311.79
# 8     Unknown Green  Nifty 100               2.73           393.89
# 1     Unknown Green  Nifty 100              10.50           330.04
# 9        Green Doji   Nifty 50               3.44           397.27
# 5   Inverted Hammer  Nifty 100               8.04           324.00
# 0   Inverted Hammer   Nifty 50               3.71           390.09
# 6     Unknown Green   Nifty 50               8.44           396.00

# %% [markdown]
# ## Golden Crossover
# When 44 days `SMA` Crosses 200 days `SMA` from below and you find a `Green` candle within 15 days taking support on `44` days line set Risk to Reward ratio as 1:5

# %%
for name in In.data['nifty_200']:
    df = In.open_downloaded_stock(name)
    if In.has_golden_crossover(df,lookback=21):
        print(name)
# Out:
# ESCORTS
# ITC
# INDUSTOWER
# KOTAKBANK
# ZEEL

# %% [markdown]
# ## RSI Signal: Oversold / Overbought Stocks
# Buy when RSI is less than 30 sell when greater than 70

# %%
for name in In.data['nifty_500']:
    df = In.open_downloaded_stock(name)
    if In.get_RSI(df,signal_only=True) == "Buy":
        print(name)

# %% [markdown]
# ## MACD Signal
# It is the strategy when MACD (Blue) Line cuts the Signal (Red) line from below then it is a buy signal. When the blue line cuts from upside down, it is sell signal

# %%
for name in In.data['nifty_200']:
    df = In.open_downloaded_stock(name)
    if In.macd_signal(df) == 'Buy':
        print(name)
# Out:
# APOLLOTYRE
# SRF
# UBL

# %% [markdown]
# ## CCI Signal : Rally
# **Faster than MACD Signal works closely with Stochastic RSI**
#
# When CCI values comes from below  -100 to above -100, buy signal and when it comes from above +100 to below +100, sell signal

# %%
for name in In.data['nifty_100']:
    df = In.open_downloaded_stock(name)
    if In.get_CCI(df, signal_only = True) == 'Buy':
        print((name, In.get_index(name)))
# Out:
# ('ADANIPORTS', 'Nifty 50')

# %% [markdown]
# # <font color='teal'>Intraday Strategies</font>
# # See documentations for Intraday strategies

# %% [markdown]
# ## Narrow Range 7
# If recent candle's range is lowest among 6 other days then the future candle might break it's low/high

# %%
for name in In.data['nifty_100']:
    if Intra.NR7_strategy(name):
        print(name)
# Out:
# ABBOTINDIA
# AXISBANK
# BAJFINANCE
# BAJAJFINSV
# BAJAJHLDNG
# BERGEPAINT
# CADILAHC
# CIPLA
# GRASIM
# HDFC
# IGL
# JUBLFOOD
# LT
# ULTRACEMCO

# %% [markdown]
# ## Whole Number Open
# When Open == Low / High in Whole number as `xxx.00` within 15 minutes

# %%
Intra.whole_number_strategy(nifty=200, min_val=101, max_val=5000, print_results = True)
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_29547/2151900994.py in <module>
# ----> 1 Intra.whole_number_strategy(nifty=200, min_val=101, max_val=5000, print_results = True)
#
# ~/Desktop/ML Study/Finance/helpers/intraday.py in whole_number_strategy(self, nifty, min_val, max_val, return_list, print_results)
#      30
#      31         url = f"https://www.nseindia.com/api/equity-stockIndices?index=NIFTY%20{nifty}"
# ---> 32         df = pd.DataFrame(NSE.get_live_nse_data(url).json()['data'])
#      33
#      34         df['Equal'] = df.apply(lambda row: True if (row['open'] == row['dayHigh'] or row['open'] == row['dayLow']) else False, axis=1)
#
# ~/anaconda3/envs/finance/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/anaconda3/envs/finance/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/envs/finance/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/envs/finance/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# ## `%` Change probability
# Gives the stock names which have the highest probability of providing you `x%` in intraday atleast on both long or short side based on the previous `N` days record

# %%
# Gives you top 10 stocks from Nifty 500 which have the highest probability of giving atleast 0.99% on your investment based on the Long/Buy position. Data is based on past 60 trading days
# Test it for different time duration, index, % change and Long / Short criteria based on overall market trend

Intra.prob_by_percent_change(symbol = None, index = 200, time_period = 20, change_percent=0.099, sort_by='Long Probability', top_k = 10)
# Out:
# {'ATGL': {'Long Probability': 0.9, 'Short Probability': 0.75},
#  'INDUSTOWER': {'Long Probability': 0.9, 'Short Probability': 0.7},
#  'INDHOTEL': {'Long Probability': 0.85, 'Short Probability': 0.5},
#  'JSWENERGY': {'Long Probability': 0.85, 'Short Probability': 0.7},
#  'M&MFIN': {'Long Probability': 0.85, 'Short Probability': 0.6},
#  'YESBANK': {'Long Probability': 0.85, 'Short Probability': 0.6},
#  'ZEEL': {'Long Probability': 0.85, 'Short Probability': 0.6},
#  'IBULHSGFIN': {'Long Probability': 0.8, 'Short Probability': 0.55},
#  'IRCTC': {'Long Probability': 0.8, 'Short Probability': 0.65},
#  'TATAMOTORS': {'Long Probability': 0.8, 'Short Probability': 0.5}}

# %% [markdown]
# # <font color='Teal'>Live Data</font>
#
#
# ## Market Sentiment: TICK, TRIN (Arm's Index) & 52W High-Low touching shares

# %%
MS.get_live_sentiment()
# Out:
# {'Latest Updated on': '08/10/2021 16:14:59',
#  'Up': 789,
#  'Down': 730,
#  'TICK': 59,
#  'Volume Up': 1930.45,
#  'Volume Down': 576.67,
#  'TRIN': 0.323,
#  '52W High': 112,
#  '52W Low': 1}

# %% [markdown]
# ## Indices Based
# Buy or Sell stock based on which indices are performing highest in first 5 mins. Buy or sell stocks only for those indices which arevperforming the greatest

# %%
NSE.current_indices_status(10) # Live as of market is open. works post market also
# Out:
#                      index  percentChange                   key  variation
# 8                INDIA VIX          -3.11  BROAD MARKET INDICES      -0.50
# 26            NIFTY REALTY          -2.21      SECTORAL INDICES     -11.75
# 10       NIFTY SMALLCAP 50           2.02  BROAD MARKET INDICES     110.20
# 20                NIFTY IT           1.96      SECTORAL INDICES     698.15
# 24          NIFTY PSU BANK           1.65      SECTORAL INDICES      41.35
# 7       NIFTY SMALLCAP 100           1.23  BROAD MARKET INDICES     137.70
# 35  NIFTY50 PR 2X LEVERAGE           1.17      STRATEGY INDICES     110.00
# 34  NIFTY50 TR 2X LEVERAGE           1.17      STRATEGY INDICES     149.00
# 39          NIFTY ALPHA 50           0.99      STRATEGY INDICES     323.00
# 21             NIFTY MEDIA           0.88      SECTORAL INDICES      19.65

# %%
NSE.open_nse_index('NIFTY REALTY')
# Out:
# ---------------------------------------------------------------------------
# JSONDecodeError                           Traceback (most recent call last)
# /tmp/ipykernel_29547/4277680808.py in <module>
# ----> 1 NSE.open_nse_index('NIFTY REALTY')
#
# ~/Desktop/ML Study/Finance/helpers/nse_data.py in open_nse_index(self, index_name, show_n)
#      55         url = f"https://www.nseindia.com/api/equity-stockIndices?index={index_name}"
#      56
# ---> 57         df = pd.DataFrame(self.get_live_nse_data(url).json()['data'])
#      58         df['absolute_change'] = df['pChange'].apply(lambda x: abs(x))
#      59         df['Index'] = df['symbol'].apply(lambda x: In.get_index(x))
#
# ~/anaconda3/envs/finance/lib/python3.7/site-packages/requests/models.py in json(self, **kwargs)
#     908                     # used.
#     909                     pass
# --> 910         return complexjson.loads(self.text, **kwargs)
#     911
#     912     @property
#
# ~/anaconda3/envs/finance/lib/python3.7/json/__init__.py in loads(s, encoding, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     346             parse_int is None and parse_float is None and
#     347             parse_constant is None and object_pairs_hook is None and not kw):
# --> 348         return _default_decoder.decode(s)
#     349     if cls is None:
#     350         cls = JSONDecoder
#
# ~/anaconda3/envs/finance/lib/python3.7/json/decoder.py in decode(self, s, _w)
#     335
#     336         """
# --> 337         obj, end = self.raw_decode(s, idx=_w(s, 0).end())
#     338         end = _w(s, end).end()
#     339         if end != len(s):
#
# ~/anaconda3/envs/finance/lib/python3.7/json/decoder.py in raw_decode(self, s, idx)
#     353             obj, end = self.scan_once(s, idx)
#     354         except StopIteration as err:
# --> 355             raise JSONDecodeError("Expecting value", s, err.value) from None
#     356         return obj, end
#
# JSONDecodeError: Expecting value: line 1 column 1 (char 0)

# %% [markdown]
# # <font color='teal'>Back Testing</font>
# # Back Testing Stratagies to get the best Win %, Max Return Investment etc
# Pass in the parameters dict for all. Check Docstring of each individual function for how a strategy works in buying or selling.

# %% [markdown]
# ## CCI
# `BT.backtest('cci', stocks=['DIVISLAB'])` , for individual stock data performance to tell how much a stock would have gained or lost

# %%
cci_parameters = {'buying_thresh':-100, 'selling_thresh':100, 'window':20, 'cols':('OPEN','CLOSE','LOW','HIGH', 'DATE')} # check documentation of BT.cci()

# Using the CCI strategy, Return top gaining stocks which have traded atleast 365 recent days and are currently in nifty-500
BT.backtest('cci', min_days = 365, top_n=15, stocks = 'nifty_50', **cci_parameters)
# Out:
#             win%  wins  losses   ROI  \
# TITAN        1.0     5       0  5.01
# UPL          1.0     4       0  5.44
# ITC          1.0     4       0  3.63
# TATASTEEL    1.0     3       0  8.61
# BAJFINANCE   1.0     3       0  6.03
# JSWSTEEL     1.0     3       0  4.30
# ICICIBANK    1.0     3       0  3.91
# INFY         1.0     3       0  2.79
# WIPRO        1.0     3       0  2.04
# DIVISLAB     1.0     2       0  7.81
# NTPC         1.0     2       0  5.48
# TCS          1.0     2       0  3.33
# ADANIPORTS   1.0     2       0  1.87
# LT           1.0     2       0  1.78
# COALINDIA    1.0     1       0  6.21
#
#                                                           p&l  \
# TITAN       [77.90000000000009, 85.75, 18.700000000000045,...
# UPL         [15.800000000000011, 37.39999999999998, 62.0, ...
# ITC         [14.599999999999994, 4.849999999999994, 6.5500...
# TATASTEEL   [99.05000000000007, 63.60000000000002, 51.7999...
# BAJFINANCE    [558.0, 210.85000000000036, 227.85000000000036]
# JSWSTEEL    [31.350000000000023, 18.900000000000034, 8.100...
# ICICIBANK                    [61.0, 3.7999999999999545, 5.75]
# INFY            [26.0, 10.049999999999955, 57.34999999999991]
# WIPRO                         [5.5, 0.9499999999999886, 19.0]
# DIVISLAB               [343.5999999999999, 276.5500000000002]
# NTPC                                 [6.5, 5.900000000000006]
# TCS                                 [67.54999999999973, 95.0]
# ADANIPORTS                           [5.899999999999977, 7.5]
# LT                                  [7.099999999999909, 48.0]
# COALINDIA                                 [9.099999999999994]
#
#                                                      buy_date  \
# TITAN       [2020-09-29 00:00:00, 2020-11-05 00:00:00, 202...
# UPL         [2020-07-20 00:00:00, 2020-09-11 00:00:00, 202...
# ITC         [2020-06-23 00:00:00, 2020-07-23 00:00:00, 202...
# TATASTEEL   [2021-02-03 00:00:00, 2021-03-26 00:00:00, 202...
# BAJFINANCE  [2021-01-20 00:00:00, 2021-03-03 00:00:00, 202...
# JSWSTEEL    [2020-09-29 00:00:00, 2021-02-03 00:00:00, 202...
# ICICIBANK   [2021-02-01 00:00:00, 2021-03-04 00:00:00, 202...
# INFY        [2020-08-27 00:00:00, 2020-11-05 00:00:00, 202...
# WIPRO       [2020-09-01 00:00:00, 2021-02-26 00:00:00, 202...
# DIVISLAB    [2020-10-05 00:00:00, 2021-08-25 00:00:00, 202...
# NTPC               [2021-03-31 00:00:00, 2021-08-02 00:00:00]
# TCS         [2020-08-28 00:00:00, 2020-11-04 00:00:00, 202...
# ADANIPORTS  [2020-09-15 00:00:00, 2020-11-02 00:00:00, 202...
# LT                 [2021-03-04 00:00:00, 2021-08-13 00:00:00]
# COALINDIA                               [2021-07-01 00:00:00]
#
#                                                     sell_date  \
# TITAN       [2020-10-15 00:00:00, 2020-11-11 00:00:00, 202...
# UPL         [2020-07-27 00:00:00, 2020-09-23 00:00:00, 202...
# ITC         [2020-07-07 00:00:00, 2020-08-12 00:00:00, 202...
# TATASTEEL   [2021-03-08 00:00:00, 2021-03-31 00:00:00, 202...
# BAJFINANCE  [2021-02-05 00:00:00, 2021-05-10 00:00:00, 202...
# JSWSTEEL    [2020-10-27 00:00:00, 2021-02-15 00:00:00, 202...
# ICICIBANK   [2021-02-02 00:00:00, 2021-04-29 00:00:00, 202...
# INFY        [2020-09-16 00:00:00, 2020-11-26 00:00:00, 202...
# WIPRO       [2020-09-07 00:00:00, 2021-04-15 00:00:00, 202...
# DIVISLAB           [2020-11-10 00:00:00, 2021-08-31 00:00:00]
# NTPC               [2021-05-12 00:00:00, 2021-09-16 00:00:00]
# TCS                [2020-09-08 00:00:00, 2020-11-27 00:00:00]
# ADANIPORTS         [2020-10-09 00:00:00, 2020-11-13 00:00:00]
# LT                 [2021-06-03 00:00:00, 2021-08-16 00:00:00]
# COALINDIA                               [2021-09-21 00:00:00]
#
#                                              buy_price  \
# TITAN       [1145.0, 1224.15, 1518.0, 1505.0, 1714.65]
# UPL                       [440.0, 492.6, 611.0, 809.0]
# ITC                    [185.4, 197.65, 207.45, 208.05]
# TATASTEEL               [644.9, 730.4, 1114.2, 1399.0]
# BAJFINANCE                   [4968.0, 5364.15, 6189.0]
# JSWSTEEL                         [277.0, 386.2, 694.0]
# ICICIBANK                      [552.0, 618.75, 633.75]
# INFY                          [960.0, 1109.9, 1277.65]
# WIPRO                    [271.0, 417.95, 561.0, 650.4]
# DIVISLAB                     [3080.0, 4863.45, 5250.5]
# NTPC                                    [107.7, 118.6]
# TCS                           [2268.4, 2610.0, 3836.0]
# ADANIPORTS                      [355.1, 360.0, 735.85]
# LT                                    [1473.0, 1626.0]
# COALINDIA                                      [146.6]
#
#                                           sell_price          hold_period  \
# TITAN       [1222.9, 1309.9, 1536.7, 1536.0, 1857.2]  [16, 6, 24, 27, 12]
# UPL                    [455.8, 530.0, 673.0, 821.75]      [7, 12, 26, 20]
# ITC                    [200.0, 202.5, 214.0, 211.05]       [14, 20, 9, 9]
# TATASTEEL                    [743.95, 794.0, 1166.0]          [33, 5, 10]
# BAJFINANCE                 [5526.0, 5575.0, 6416.85]          [16, 68, 7]
# JSWSTEEL                      [308.35, 405.1, 702.1]         [28, 12, 17]
# ICICIBANK                     [613.0, 622.55, 639.5]          [1, 56, 16]
# INFY                        [986.0, 1119.95, 1335.0]         [20, 21, 29]
# WIPRO                          [276.5, 418.9, 580.0]           [6, 48, 1]
# DIVISLAB                            [3423.6, 5140.0]              [36, 6]
# NTPC                                  [114.2, 124.5]             [42, 45]
# TCS                                [2335.95, 2705.0]             [11, 23]
# ADANIPORTS                            [361.0, 367.5]             [24, 11]
# LT                                  [1480.1, 1674.0]              [91, 3]
# COALINDIA                                    [155.7]                 [82]
#
#            buys sells days
# TITAN         5     5  408
# UPL           4     4  409
# ITC           4     4  409
# TATASTEEL     4     3  409
# BAJFINANCE    3     3  409
# JSWSTEEL      3     3  409
# ICICIBANK     3     3  409
# INFY          3     3  409
# WIPRO         4     3  409
# DIVISLAB      3     2  409
# NTPC          2     2  409
# TCS           3     2  409
# ADANIPORTS    3     2  409
# LT            2     2  409
# COALINDIA     1     1  409

# %% [markdown]
# ## MA
# Moving Average Strategy

# %%
BT.backtest('ma',stocks='nifty_50',top_n=15)
# Out:
#             win%  wins  losses   ROI  \
# TATAMOTORS  1.00     5       0  7.51
# TCS         0.75     7       1  4.69
# ICICIBANK   0.71     6       1  4.42
# ULTRACEMCO  0.56     7       2  4.94
# BAJAJFINSV  0.50     6       2  6.08
# TATASTEEL   0.50     6       2  4.93
# RELIANCE    0.43     5       2  4.80
# WIPRO       0.43     5       2  3.24
# HCLTECH     0.43     5       2  2.73
# TATACONSUM  0.40     7       3  3.61
# INFY        0.40     7       3  2.76
# GRASIM      0.33     4       2  4.60
# ASIANPAINT  0.33     4       2  3.23
# TECHM       0.33     4       2  2.63
# JSWSTEEL    0.33     4       2  2.57
#
#                                                           p&l  \
# TATAMOTORS  [11.741000000000014, 8.158999999999992, 7.9600...
# TCS         [159.10050000000024, 75.42100000000028, 86.465...
# ICICIBANK   [31.14349999999996, 21.98950000000002, 35.5215...
# ULTRACEMCO  [-85.94999999999982, 266.65999999999985, 175.4...
# BAJAJFINSV  [334.3199999999997, -174.0, -261.75, 608.06000...
# TATASTEEL   [-33.64999999999998, 36.615999999999985, 52.23...
# RELIANCE    [123.0, 152.73250000000007, 90.54500000000007,...
# WIPRO       [15.920000000000016, 13.730999999999938, 13.53...
# HCLTECH     [42.5859999999999, 46.466499999999996, -31.149...
# TATACONSUM  [32.27499999999998, 40.19799999999992, -25.350...
# INFY        [-28.950000000000045, 39.10349999999994, 28.45...
# GRASIM      [-28.399999999999977, 62.18500000000006, 73.03...
# ASIANPAINT  [-122.0, 103.48000000000002, 94.02750000000015...
# TECHM       [54.824499999999944, 56.117999999999824, -42.9...
# JSWSTEEL    [27.879999999999995, 39.80000000000001, 39.170...
#
#                                                      buy_date  \
# TATAMOTORS  [2020-07-29 00:00:00, 2020-10-01 00:00:00, 202...
# TCS         [2020-04-30 00:00:00, 2020-07-27 00:00:00, 202...
# ICICIBANK   [2020-08-19 00:00:00, 2020-10-07 00:00:00, 202...
# ULTRACEMCO  [2020-07-16 00:00:00, 2020-07-20 00:00:00, 202...
# BAJAJFINSV  [2020-08-05 00:00:00, 2020-08-19 00:00:00, 202...
# TATASTEEL   [2020-09-10 00:00:00, 2020-10-22 00:00:00, 202...
# RELIANCE    [2020-04-20 00:00:00, 2020-09-09 00:00:00, 202...
# WIPRO       [2020-09-08 00:00:00, 2020-11-23 00:00:00, 202...
# HCLTECH     [2020-07-03 00:00:00, 2020-09-08 00:00:00, 202...
# TATACONSUM  [2020-04-16 00:00:00, 2020-11-06 00:00:00, 202...
# INFY        [2020-04-30 00:00:00, 2020-06-15 00:00:00, 202...
# GRASIM      [2020-07-21 00:00:00, 2020-07-30 00:00:00, 202...
# ASIANPAINT  [2020-04-23 00:00:00, 2020-07-17 00:00:00, 202...
# TECHM       [2020-10-30 00:00:00, 2020-11-12 00:00:00, 202...
# JSWSTEEL    [2020-09-29 00:00:00, 2020-12-23 00:00:00, 202...
#
#                                                     sell_date  \
# TATAMOTORS  [2020-08-07 00:00:00, 2020-10-07 00:00:00, 202...
# TCS         [2020-06-02 00:00:00, 2020-07-28 00:00:00, 202...
# ICICIBANK   [2020-08-28 00:00:00, 2020-10-12 00:00:00, 202...
# ULTRACEMCO  [2020-07-16 00:00:00, 2020-07-29 00:00:00, 202...
# BAJAJFINSV  [2020-08-10 00:00:00, 2020-08-31 00:00:00, 202...
# TATASTEEL   [2020-09-21 00:00:00, 2020-11-10 00:00:00, 202...
# RELIANCE    [2020-04-22 00:00:00, 2020-09-10 00:00:00, 202...
# WIPRO       [2020-09-11 00:00:00, 2020-12-03 00:00:00, 202...
# HCLTECH     [2020-07-15 00:00:00, 2020-09-14 00:00:00, 202...
# TATACONSUM  [2020-04-28 00:00:00, 2020-12-01 00:00:00, 202...
# INFY        [2020-05-14 00:00:00, 2020-06-26 00:00:00, 202...
# GRASIM      [2020-07-24 00:00:00, 2020-08-24 00:00:00, 202...
# ASIANPAINT  [2020-05-04 00:00:00, 2020-08-07 00:00:00, 202...
# TECHM       [2020-11-09 00:00:00, 2020-12-01 00:00:00, 202...
# JSWSTEEL    [2020-10-16 00:00:00, 2021-01-04 00:00:00, 202...
#
#                                                     buy_price  \
# TATAMOTORS                [107.2, 134.4, 138.0, 315.7, 302.0]
# TCS         [1912.55, 2163.0, 2259.9, 2440.0, 2665.0, 3188...
# ICICIBANK   [370.0, 381.8, 529.85, 601.95, 633.1, 660.3, 7...
# ULTRACEMCO  [3829.95, 3869.0, 4014.15, 4078.0, 5793.25, 66...
# BAJAJFINSV  [6228.0, 6375.0, 6396.75, 6080.6, 9025.0, 9911...
# TATASTEEL   [420.15, 408.0, 663.5, 697.9, 729.95, 736.75, ...
# RELIANCE    [1230.0, 2121.0, 2212.8, 2007.2, 1997.0, 1984....
# WIPRO       [279.5, 348.5, 353.9, 365.7, 436.65, 439.0, 43...
# HCLTECH     [572.4, 712.4, 841.75, 842.0, 963.0, 972.0, 98...
# TATACONSUM  [322.75, 509.2, 602.7, 590.0, 628.5, 623.65, 6...
# INFY        [682.0, 695.15, 926.4, 1144.8, 1140.25, 1277.9...
# GRASIM        [611.4, 621.85, 712.2, 1407.4, 1537.25, 1557.9]
# ASIANPAINT  [1822.0, 1697.1, 1955.0, 2196.95, 2513.95, 304...
# TECHM       [809.4, 840.65, 993.0, 998.5, 1001.7, 1063.4, ...
# JSWSTEEL           [278.8, 364.0, 391.7, 415.3, 703.5, 722.6]
#
#                                                    sell_price  \
# TATAMOTORS  [118.94100000000002, 142.559, 145.96, 345.948,...
# TCS         [2071.6505, 2238.4210000000003, 2346.365500000...
# ICICIBANK   [401.14349999999996, 403.78950000000003, 565.3...
# ULTRACEMCO  [3744.0, 4135.66, 4189.5685, 4491.6215, 6372.5...
# BAJAJFINSV  [6562.32, 6201.0, 6135.0, 6688.660000000001, 9...
# TATASTEEL   [386.5, 444.616, 715.7375, 781.3804999999999, ...
# RELIANCE    [1353.0, 2273.7325, 2303.3450000000003, 1975.5...
# WIPRO       [295.42, 362.23099999999994, 367.4319999999999...
# HCLTECH     [614.9859999999999, 758.8665, 810.6, 917.62, 8...
# TATACONSUM  [355.025, 549.3979999999999, 577.35, 627.81, 6...
# INFY        [653.05, 734.2534999999999, 954.8569999999999,...
# GRASIM      [583.0, 684.0350000000001, 785.2330000000002, ...
# ASIANPAINT  [1700.0, 1800.58, 2049.0275, 2138.8, 2756.6304...
# TECHM       [864.2244999999999, 896.7679999999998, 950.05,...
# JSWSTEEL      [306.68, 403.8, 430.87, 452.115, 680.85, 675.4]
#
#                                        hold_period buys sells days
# TATAMOTORS                        [9, 6, 4, 27, 9]    5     5  408
# TCS                 [33, 1, 12, 7, 35, 30, 21, 13]    9     8  409
# ICICIBANK                 [9, 5, 3, 20, 22, 12, 9]    7     7  409
# ULTRACEMCO           [0, 9, 6, 13, 3, 0, 58, 0, 6]    9     9  409
# BAJAJFINSV              [5, 12, 7, 4, 12, 5, 3, 6]    8     8  409
# TATASTEEL               [11, 19, 4, 8, 5, 9, 0, 1]    8     8  409
# RELIANCE                    [2, 1, 9, 4, 8, 7, 95]    7     7  409
# WIPRO                      [3, 10, 5, 13, 1, 5, 3]    8     7  409
# HCLTECH                  [12, 6, 5, 28, 86, 36, 7]    7     7  409
# TATACONSUM     [12, 25, 4, 11, 7, 5, 28, 18, 4, 4]   10    10  408
# INFY        [14, 11, 12, 3, 21, 36, 17, 26, 1, 21]   10    10  409
# GRASIM                     [3, 25, 23, 71, 12, 16]    6     6  409
# ASIANPAINT                  [11, 21, 3, 2, 45, 14]    7     6  409
# TECHM                     [10, 19, 13, 43, 13, 13]    7     6  409
# JSWSTEEL                   [17, 12, 28, 14, 6, 31]    6     6  409

# %% [markdown]
# ## RSI

# %%
BT.backtest('rsi',stocks='nifty_200', top_n = 30)
# Out:
#             win%  wins  losses    ROI                           p&l  \
# BAJFINANCE   1.0     2       0  44.81  [1082.0, 2451.8999999999996]
# BHEL         1.0     2       0  12.18     [4.700000000000003, 6.25]
# MARUTI       1.0     2       0  10.11               [1181.0, 198.0]
# TATASTEEL    1.0     1       0  41.92                       [153.0]
# JINDALSTEL   1.0     1       0  36.20          [62.349999999999994]
# SAIL         1.0     1       0  35.06          [12.149999999999999]
# INDUSINDBK   1.0     1       0  25.76                       [223.5]
# MUTHOOTFIN   1.0     1       0  23.70                       [246.0]
# VOLTAS       1.0     1       0  21.75          [213.45000000000005]
# ABFRL        1.0     1       0  21.52          [42.650000000000006]
# BEL          1.0     1       0  20.97                        [26.0]
# COROMANDEL   1.0     1       0  20.95          [126.45000000000005]
# HINDPETRO    1.0     1       0  19.47           [48.75000000000003]
# MARICO       1.0     1       0  19.42                        [67.0]
# INDHOTEL     1.0     1       0  18.18                        [20.0]
# DLF          1.0     1       0  17.02          [43.599999999999966]
# PEL          1.0     1       0  16.67          [210.04999999999995]
# CADILAHC     1.0     1       0  16.10                        [71.0]
# TATAMOTORS   1.0     1       0  16.02           [47.10000000000002]
# BERGEPAINT   1.0     1       0  14.84          [107.55000000000007]
# GODREJIND    1.0     1       0  14.84                        [54.0]
# CHOLAFIN     1.0     1       0  14.46                        [72.0]
# GAIL         1.0     1       0  14.44          [20.350000000000023]
# SBICARD      1.0     1       0  14.26                       [139.0]
# BAJAJHLDNG   1.0     1       0  13.60                       [450.0]
# ICICIGI      1.0     1       0  12.70                       [178.0]
# PIIND        1.0     1       0  12.12                       [261.0]
# NATCOPHARM   1.0     1       0  11.85           [96.54999999999995]
# LUPIN        1.0     1       0  11.78                       [107.0]
# HAL          1.0     1       0   9.95                        [78.0]
#
#                                               buy_date  \
# BAJFINANCE  [2020-09-28 00:00:00, 2021-04-15 00:00:00]
# BHEL        [2020-09-29 00:00:00, 2021-08-09 00:00:00]
# MARUTI      [2020-09-28 00:00:00, 2021-03-02 00:00:00]
# TATASTEEL                        [2020-09-29 00:00:00]
# JINDALSTEL                       [2020-09-24 00:00:00]
# SAIL        [2020-09-28 00:00:00, 2021-09-22 00:00:00]
# INDUSINDBK                       [2021-04-15 00:00:00]
# MUTHOOTFIN                       [2020-09-24 00:00:00]
# VOLTAS                           [2021-08-30 00:00:00]
# ABFRL                            [2021-08-25 00:00:00]
# BEL                              [2021-03-30 00:00:00]
# COROMANDEL                       [2020-03-12 00:00:00]
# HINDPETRO                        [2021-08-25 00:00:00]
# MARICO                           [2020-09-25 00:00:00]
# INDHOTEL                         [2021-03-30 00:00:00]
# DLF                              [2021-04-15 00:00:00]
# PEL                              [2020-09-28 00:00:00]
# CADILAHC    [2021-02-25 00:00:00, 2021-08-02 00:00:00]
# TATAMOTORS                       [2021-07-30 00:00:00]
# BERGEPAINT  [2021-03-02 00:00:00, 2021-08-27 00:00:00]
# GODREJIND                        [2020-11-05 00:00:00]
# CHOLAFIN                         [2021-07-23 00:00:00]
# GAIL                             [2021-08-02 00:00:00]
# SBICARD                          [2021-06-25 00:00:00]
# BAJAJHLDNG                       [2021-04-01 00:00:00]
# ICICIGI                          [2021-02-02 00:00:00]
# PIIND                            [2021-02-03 00:00:00]
# NATCOPHARM                       [2021-02-22 00:00:00]
# LUPIN       [2020-11-12 00:00:00, 2021-08-02 00:00:00]
# HAL                              [2020-09-25 00:00:00]
#
#                                              sell_date         buy_price  \
# BAJFINANCE  [2020-11-12 00:00:00, 2021-08-31 00:00:00]  [3178.0, 4708.1]
# BHEL        [2020-12-09 00:00:00, 2021-10-07 00:00:00]    [32.25, 57.65]
# MARUTI      [2020-12-10 00:00:00, 2021-06-10 00:00:00]  [6579.0, 7060.0]
# TATASTEEL                        [2020-11-18 00:00:00]           [365.0]
# JINDALSTEL                       [2020-11-26 00:00:00]          [172.25]
# SAIL                             [2020-11-27 00:00:00]    [34.65, 111.8]
# INDUSINDBK                       [2021-09-21 00:00:00]           [867.5]
# MUTHOOTFIN                       [2021-01-07 00:00:00]          [1038.0]
# VOLTAS                           [2021-09-08 00:00:00]           [981.2]
# ABFRL                            [2021-10-05 00:00:00]          [198.15]
# BEL                              [2021-05-26 00:00:00]           [124.0]
# COROMANDEL                       [2020-06-22 00:00:00]          [603.55]
# HINDPETRO                        [2021-10-04 00:00:00]          [250.35]
# MARICO                           [2020-12-16 00:00:00]           [345.0]
# INDHOTEL                         [2021-05-25 00:00:00]           [110.0]
# DLF                              [2021-06-10 00:00:00]           [256.1]
# PEL                              [2020-11-17 00:00:00]          [1260.0]
# CADILAHC                         [2021-04-13 00:00:00]    [441.0, 590.0]
# TATAMOTORS                       [2021-10-07 00:00:00]           [294.0]
# BERGEPAINT                       [2021-05-27 00:00:00]   [724.8, 789.35]
# GODREJIND                        [2020-11-25 00:00:00]           [364.0]
# CHOLAFIN                         [2021-09-06 00:00:00]           [498.0]
# GAIL                             [2021-10-08 00:00:00]          [140.95]
# SBICARD                          [2021-09-06 00:00:00]           [975.0]
# BAJAJHLDNG                       [2021-07-08 00:00:00]          [3310.0]
# ICICIGI                          [2021-06-30 00:00:00]          [1402.0]
# PIIND                            [2021-04-13 00:00:00]          [2154.0]
# NATCOPHARM                       [2021-04-15 00:00:00]           [815.0]
# LUPIN                            [2021-01-07 00:00:00]   [908.0, 1114.8]
# HAL                              [2020-12-14 00:00:00]           [784.0]
#
#                   sell_price hold_period buys sells days
# BAJFINANCE  [4260.0, 7160.0]   [45, 138]    2     2  409
# BHEL           [36.95, 63.9]    [71, 59]    2     2  409
# MARUTI      [7760.0, 7258.0]   [73, 100]    2     2  409
# TATASTEEL            [518.0]        [50]    1     1  409
# JINDALSTEL           [234.6]        [63]    1     1  409
# SAIL                  [46.8]        [60]    2     1  409
# INDUSINDBK          [1091.0]       [159]    1     1  409
# MUTHOOTFIN          [1284.0]       [105]    1     1  409
# VOLTAS             [1194.65]         [9]    1     1  409
# ABFRL                [240.8]        [41]    1     1  409
# BEL                  [150.0]        [57]    1     1  409
# COROMANDEL           [730.0]       [102]    1     1  409
# HINDPETRO            [299.1]        [40]    1     1  409
# MARICO               [412.0]        [82]    1     1  409
# INDHOTEL             [130.0]        [56]    1     1  409
# DLF                  [299.7]        [56]    1     1  409
# PEL                [1470.05]        [50]    1     1  409
# CADILAHC             [512.0]        [47]    2     1  409
# TATAMOTORS           [341.1]        [69]    1     1  408
# BERGEPAINT          [832.35]        [86]    2     1  409
# GODREJIND            [418.0]        [20]    1     1  409
# CHOLAFIN             [570.0]        [45]    1     1  409
# GAIL                 [161.3]        [67]    1     1  409
# SBICARD             [1114.0]        [73]    1     1  391
# BAJAJHLDNG          [3760.0]        [98]    1     1  409
# ICICIGI             [1580.0]       [148]    1     1  409
# PIIND               [2415.0]        [69]    1     1  409
# NATCOPHARM          [911.55]        [52]    1     1  409
# LUPIN               [1015.0]        [56]    2     1  409
# HAL                  [862.0]        [80]    1     1  409

# %% [markdown]
# ## MACD

# %%
BT.backtest('macd', top_n=5, stocks=['BAJFINANCE','SHREECEM',"COALINDIA"]) # Individual stocks. If no sells have been made, it'll be empty
# Out:
#             win%  wins  losses   ROI  \
# COALINDIA   0.00     6       6  0.28
# SHREECEM   -0.12     7       9  1.31
# BAJFINANCE -0.17     5       7  4.52
#
#                                                           p&l  \
# COALINDIA   [3.6500000000000057, -12.099999999999994, -3.7...
# SHREECEM    [2684.0, -639.0, 35.650000000001455, -351.0, -...
# BAJFINANCE  [-58.0, -132.0, -131.8499999999999, 1540.0, -1...
#
#                                                      buy_date  \
# COALINDIA   [2020-05-28 00:00:00, 2020-06-23 00:00:00, 202...
# SHREECEM    [2020-05-21 00:00:00, 2020-06-24 00:00:00, 202...
# BAJFINANCE  [2020-08-26 00:00:00, 2020-10-07 00:00:00, 202...
#
#                                                     sell_date  \
# COALINDIA   [2020-06-16 00:00:00, 2020-07-01 00:00:00, 202...
# SHREECEM    [2020-06-19 00:00:00, 2020-06-26 00:00:00, 202...
# BAJFINANCE  [2020-09-07 00:00:00, 2020-10-14 00:00:00, 202...
#
#                                                     buy_price  \
# COALINDIA   [130.85, 144.95, 133.7, 130.3, 115.1, 126.0, 1...
# SHREECEM    [19156.0, 22750.0, 22814.35, 21920.0, 21974.0,...
# BAJFINANCE  [3665.0, 3400.0, 3368.2, 3330.0, 5228.0, 5218....
#
#                                                    sell_price  \
# COALINDIA   [134.5, 132.85, 129.9, 135.5, 124.6, 132.5, 14...
# SHREECEM    [21840.0, 22111.0, 22850.0, 21569.0, 21645.0, ...
# BAJFINANCE  [3607.0, 3268.0, 3236.35, 4870.0, 5070.0, 5420...
#
#                                                   hold_period buys sells days
# COALINDIA      [19, 8, 12, 23, 37, 21, 7, 11, 25, 31, 10, 13]   13    12  409
# SHREECEM    [29, 2, 1, 2, 8, 5, 28, 42, 10, 20, 22, 1, 33,...   16    16  409
# BAJFINANCE        [12, 7, 1, 42, 1, 20, 34, 7, 12, 11, 28, 4]   12    12  409

# %% [markdown]
# # <font color='teal'>Risk Management</font>

# %%
# You have a total budget of 40K, and a risk apetite of rs 400 per trade
# You can set manual such as # entry = 3980.1, stop_loss=3780.5

In.get_particulars('CYIENT',30000,300, entry = 1123, stop_loss=1103)
# Out:
# {'Buying Price': 1123,
#  'Stop-Loss %': 1.78,
#  'Target %': 3.56,
#  'Quantity': 15,
#  'Stop-Loss Price': 1103,
#  'Trigger Price': 1162.98,
#  'Risk Per Share': 20,
#  'Profit Per Share': 39.98,
#  'Max loss on this config': 300,
#  'Max Gain on this config': 599.7,
#  'Price To Profit Ratio': 28.07,
#  'Index': 'Nifty 500'}

# %%
In.get_particulars('GODREJIND',30000,300, entry = 589,stop_loss=565)
# Out:
# {'Buying Price': 589,
#  'Stop-Loss %': 4.07,
#  'Target %': 8.15,
#  'Quantity': 12,
#  'Stop-Loss Price': 565,
#  'Trigger Price': 636.98,
#  'Risk Per Share': 24,
#  'Profit Per Share': 47.98,
#  'Max loss on this config': 288,
#  'Max Gain on this config': 575.71,
#  'Price To Profit Ratio': 12.27,
#  'Index': 'Nifty 200'}

# %%
In.get_particulars('TCS',30000,300, entry = 3970,stop_loss=3890)
# Out:
# {'Buying Price': 3970,
#  'Stop-Loss %': 2.02,
#  'Target %': 4.03,
#  'Quantity': 3,
#  'Stop-Loss Price': 3890,
#  'Trigger Price': 4129.92,
#  'Risk Per Share': 80,
#  'Profit Per Share': 159.92,
#  'Max loss on this config': 240,
#  'Max Gain on this config': 479.76,
#  'Price To Profit Ratio': 24.81,
#  'Index': 'Nifty 50'}
